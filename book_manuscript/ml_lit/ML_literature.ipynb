# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import ml_lit_anal as ml
import re
import nltk
import pickle
import operator
import google_scholar_parser as gs
import pandas as pd
import networkx as nx
import graph_tool.all as gt
import itertools
import matplotlib.pyplot as plt
import numpy as np
import collections
import IPython.display
import seaborn
import ggplot
import math

# %% [markdown]
# ## A generative model of the machine learning literature
#
# "Let's build a generative model of the machine learning literature" Andrew Ng, lecture on GDA and Naive Bayes
#
# The idea of this analysis is to show how machine learning relates to various scientific and technical fields. In its treatment of the literature, it draws both on citation analysis techniques developed  in various fields, as well as text mining, social netowrk analysis and indeed machine learning itself to explore this rather large literature.
#
# ### Loading the literature and cleaning the topics
#
# I downloaded from Thomson ISI Web of Science all the references returned by the query 'machine learning.' I also downloaded the cited references.
#
# Other possible queries such as 'data mining' return too many references to handle -- over 2 million, so I stuck with machine learning, which return aroudn 25,000 references.

# %%
df = ml.load_records('data/machine_learning_WOS/')
print('There are %s records in the dataset'%df.shape[0])

#clean topics
df = ml.clean_topics(df)
df = ml.clean_fields(df)
# Out:
# There are 28619 records in the dataset

# %%
print('%s topic fields are null'%sum(df.topics.isnull()))
print('%s abstract fields are null'%sum(df.AB.isnull()))
print('%s keywords Plus fields are null'%sum(df.ID.isnull()))
print('%s author fields are null'%sum(df.AF.isnull()))
# Out:
# 9871 topic fields are null
# 1008 abstract fields are null
# 10692 keywords Plus fields are null
# 27 author fields are null

# %% [markdown]
# The publication years profile is typical in some ways but shows enormous growth from the late 1980s onwards. Was this around the time that artificial intelligence started to seem unpopular?

# %%
plt.figure(figsize=(8,4))
plt.title('Machine learning publications (Web of Science)')

df.PY.hist(bins=len(df.PY.unique()))
plt.box(on=False)

# %% [markdown]
# There are a lot of missing keywords (the WoS DE field). It should be possible to fill in some of the missing topic fields by using keywords from the abstracts. I'll attempt this a bit later.

# %% [markdown]
# ## Fields of research in the literature

# %%
#actually this is more about fields than topics

all_fields = sorted([e  for el in df.fields.dropna() for e in el])
fields_set = set(all_fields)
field_counts = {e:all_fields.count(e) for e in fields_set}

# %% [markdown]
# Many different fields of research or disciplines are included in the results, and they help make sense of the multi-disciplinary nature of machine learning techniques.

# %%
print('%s different fields appear in the machine learning literature'%len(fields_set))
field_counts_s = sorted(field_counts.iteritems(), key=lambda(k,v):(-v,k))
field_counts_s[0:30]
# Out:
# 139 different fields appear in the machine learning literature
# [('computer science', 18810),
#  ('engineering', 7818),
#  ('biochemistry & molecular biology', 1950),
#  ('mathematics', 1672),
#  ('mathematical & computational biology', 1599),
#  ('automation & control systems', 1402),
#  ('imaging science & photographic technology', 1066),
#  ('telecommunications', 1033),
#  ('biotechnology & applied microbiology', 999),
#  ('operations research & management science', 978),
#  ('medical informatics', 832),
#  ('neurosciences & neurology', 678),
#  ('science & technology - other topics', 659),
#  ('chemistry', 626),
#  ('radiology, nuclear medicine & medical imaging', 594),
#  ('robotics', 584),
#  ('optics', 521),
#  ('environmental sciences & ecology', 479),
#  ('information science & library science', 433),
#  ('remote sensing', 423),
#  ('physics', 396),
#  ('pharmacology & pharmacy', 354),
#  ('acoustics', 312),
#  ('genetics & heredity', 312),
#  ('business & economics', 306),
#  ('instruments & instrumentation', 287),
#  ('biophysics', 253),
#  ('materials science', 235),
#  ('health care sciences & services', 229),
#  ('psychology', 223)]

# %% [markdown]
# The literature does reach back into the 1950s, but the real growth is in the 1990s-2000s. From 2005 onwards, several thousand publications a year appear.
#
# We can see also the distribution of fields. Computer science totally dominates the fields. That only goes to show perhaps that machine learning is a computer science-driven set of techniques. But other fields such as automation and control systems,  biochemistry/molecular biology, management science, robotics, telecommunications and imaging science are important components. This already shows something of the wide dissemination of machine learning techniques.

# %%
#the problem is that computer science clutters everything -- get rid of it?
figure = plt.figure(figsize=(16,12))
plt.subplot(122)

plt.hist(df.PY.dropna(), bins=80, alpha=0.6)
plt.title('Machine Learning Publications by Year')
plt.subplot(1,2,1)
#this doesn't work -- TBA
major_fields = {f:v for f,v in field_counts.iteritems() if v > 3 or f is not 'computer science'}
print(len(field_counts), len(major_fields))
heights = major_fields.values()
ind= np.arange(len(heights))
plt.barh(ind, heights)
width =0.2
plt.title('Machine Learning Publications by Discipline')
xticks = plt.yticks(ind+width/2., major_fields.keys() )
# Out:
# (139, 139)

# %% [markdown]
# ### Some network exploration could be useful for the relation between the disciplines
#
# What disciplines connect the others up?

# %%
df = ml.clean_fields(df)
gr_f = nx.Graph()
gr_f.add_edges_from([i for de in df.fields.dropna() for i in itertools.combinations(de,2)])

# %%
f_g = gt.Graph(directed = False)
f_g.add_vertex(n=len(fields_set))
v_f = f_g.new_vertex_property('string')
field_list = list(fields_set)
# add fields as node properties
for v_i in range(0, f_g.num_vertices()):
    v_f[f_g.vertex(v_i)] = field_list[v_i]
f_g.vertex_properties['field'] = v_f

# add cofields as edges
#edges = [f_g.add_edge(field_list.index(s), field_list.index(t)) 
 #                     for de in df.fields.dropna() for s,t in itertools.combinations(de,2)]

e_w = f_g.new_edge_property('int')

for de in df.fields.dropna():
    for s,t in itertools.combinations(de,2):
        s_i = field_list.index(s)
        t_i = field_list.index(t)
        if f_g.edge(s_i,t_i) is not None:
            e = f_g.edge(s_i, t_i)
            e_w[e] +=1
        else:
            e = f_g.add_edge(s_i, t_i)
            e_w[e] = 0
f_g.edge_properties['cofield'] = e_w

# %%
print f_g.num_edges()
f_g.num_vertices()
# Out:
# 877
# 139

# %%
v_comm = gt.community_structure(f_g, 1000, 5)
#v_comm = gt.betweenness(f_g)

# %%
import numpy
u = gt.GraphView(f_g, vfilt=gt.label_largest_component(f_g))
deg = u.degree_property_map('total', weight = f_g.edge_properties['cofield'])
deg.fa = 2*(numpy.sqrt(deg.fa)*0.5  + 0.4)
edg = f_g.edge_properties['cofield']
edg.fa = (numpy.sqrt(edg.fa)*0.6+1)
ebet = gt.betweenness(f_g)[1]

# %%
pos, int = gt.interactive_window(u, pos=gt.radial_tree_layout(f_g, f_g.vertex(1)),
                         vertex_size = deg, 
                         vertex_fill_color = v_comm, 
                         vertex_text = f_g.vertex_properties['field'],
                         vertex_text_position = 0.2,
                         vertex_font_size = 9,
                         vertex_font_family = 'sans serif',
                         edge_pen_width = edg,
                         edge_color=ebet,
                         output_size = (800,1200)
                         )

# %%
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x7ff40d25ebd0, at 0x7ff40ccce410>

# %%
gt.graph_draw(f_g, pos=pos, 
              vertex_size = deg, 
                        vertex_fill_color = v_comm, 
                        vertex_text = f_g.vertex_properties['field'],
                        vertex_text_position = 0.2,
                        vertex_font_size = 9,
                        vertex_font_family = 'sans serif',
                        edge_pen_width = edg,
                        output_size = (800,1200),
              output = 'ml_fields.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-3acdeee6ab7e> in <module>()
#       8                         edge_pen_width = edg,
#       9                         output_size = (800,1200),
# ---> 10               output = 'ml_fields.png')
#
# /usr/lib/python2.7/dist-packages/graph_tool/draw/cairo_draw.pyc in graph_draw(g, pos, vprops, eprops, vorder, eorder, nodesfirst, output_size, fit_view, inline, mplfig, output, fmt, **kwargs)
#     951                                        vprops.get("font_size",
#     952                                                   _vdefaults["font_size"]),
# --> 953                                        cr)
#     954         else:
#     955             offset, zoom = [0, 0], 1
#
# /usr/lib/python2.7/dist-packages/graph_tool/draw/cairo_draw.pyc in fit_to_view(g, pos, geometry, size, pen_width, M, text, font_family, font_size, cr)
#    1123     x_range, y_range, x_delta, y_delta = get_bb(g, pos, size, pen_width,
#    1124                                                 1, text, font_family,
# -> 1125                                                 font_size, cr)
#    1126     dx = (x_range[1] - x_range[0])
#    1127     dy = (y_range[1] - y_range[0])
#
# /usr/lib/python2.7/dist-packages/graph_tool/draw/cairo_draw.pyc in get_bb(g, pos, size, pen_width, size_scale, text, font_family, font_size, cr)
#    1071             uniform = (not isinstance(font_size, PropertyMap) and
#    1072                        not isinstance(font_family, PropertyMap))
# -> 1073             size = np.ones(len(pos_x.fa)) * size
#    1074         else:
#    1075             uniform = False
#
# ValueError: operands could not be broadcast together with shapes (139,) (135,)

# %%
i = IPython.display.Image(filename='ml_fields.png')
i

# %%
core = ml.trim_nodes(gr_f, 8)
#core = ml.trim_edges(core, 3)
len(core)

plt.figure(figsize=(18,12))
plt.title('Fields and their relations in machine learning literature', fontsize=18)
nx.draw_graphviz(core, width=0.4,
                 font_size=9,
                 alpha = 0.7,
                 node_size = [s*5000 for s in nx.degree_centrality(core).values()],
                 node_color = [s for s in nx.degree(core).values()])
# Out:
# 65 nodes in graph
# 586 edges in graph
# /usr/local/lib/python2.7/dist-packages/pygraphviz/agraph.py:1281: RuntimeWarning: Fontconfig warning: "/etc/fonts/conf.d/50-user.conf", line 9: reading configurations from ~/.fonts.conf is deprecated.
#
#   warnings.warn("".join(errors),RuntimeWarning)

# %%
degree_c = nx.degree_centrality(core)
degree_cs = ml.sorted_map(degree_c)
degree_cs
# Out:
# [('computer science', 0.921875),
#  ('engineering', 0.890625),
#  ('mathematics', 0.609375),
#  ('environmental sciences & ecology', 0.53125),
#  ('mathematical & computational biology', 0.515625),
#  ('imaging science & photographic technology', 0.484375),
#  ('radiology, nuclear medicine & medical imaging', 0.484375),
#  ('optics', 0.4375),
#  ('biochemistry & molecular biology', 0.421875),
#  ('science & technology - other topics', 0.421875),
#  ('neurosciences & neurology', 0.40625),
#  ('remote sensing', 0.40625),
#  ('instruments & instrumentation', 0.390625),
#  ('medical informatics', 0.390625),
#  ('automation & control systems', 0.375),
#  ('physics', 0.375),
#  ('chemistry', 0.359375),
#  ('genetics & heredity', 0.328125),
#  ('materials science', 0.328125),
#  ('telecommunications', 0.328125),
#  ('agriculture', 0.3125),
#  ('biophysics', 0.296875),
#  ('biotechnology & applied microbiology', 0.296875),
#  ('research & experimental medicine', 0.296875),
#  ('transportation', 0.296875),
#  ('information science & library science', 0.28125),
#  ('public, environmental & occupational health', 0.28125),
#  ('business & economics', 0.265625),
#  ('education & educational research', 0.265625),
#  ('geology', 0.265625),
#  ('pharmacology & pharmacy', 0.265625),
#  ('psychology', 0.25),
#  ('robotics', 0.25),
#  ('operations research & management science', 0.234375),
#  ('acoustics', 0.21875),
#  ('life sciences & biomedicine - other topics', 0.21875),
#  ('energy & fuels', 0.203125),
#  ('geography', 0.203125),
#  ('oncology', 0.203125),
#  ('physiology', 0.203125),
#  ('social sciences - other topics', 0.203125),
#  ('meteorology & atmospheric sciences', 0.1875),
#  ('nuclear science & technology', 0.1875),
#  ('oceanography', 0.1875),
#  ('astronomy & astrophysics', 0.171875),
#  ('forestry', 0.171875),
#  ('mechanics', 0.171875),
#  ('medical laboratory technology', 0.171875),
#  ('physical geography', 0.171875),
#  ('spectroscopy', 0.171875),
#  ('cell biology', 0.15625),
#  ('crystallography', 0.15625),
#  ('health care sciences & services', 0.15625),
#  ('linguistics', 0.15625),
#  ('surgery', 0.15625),
#  ('water resources', 0.15625),
#  ('cardiovascular system & cardiology', 0.140625),
#  ('behavioral sciences', 0.125),
#  ('immunology', 0.125),
#  ('plant sciences', 0.125),
#  ('rehabilitation', 0.125),
#  ('toxicology', 0.125),
#  ('general & internal medicine', 0.109375),
#  ('sociology', 0.109375),
#  ('infectious diseases', 0.078125)]

# %%
closeness_c = nx.closeness_centrality(core)
closeness_cs = ml.sorted_map(closeness_c)
closeness_cs
# Out:
# [('computer science', 0.927536231884058),
#  ('engineering', 0.9014084507042254),
#  ('mathematics', 0.7191011235955056),
#  ('environmental sciences & ecology', 0.6808510638297872),
#  ('mathematical & computational biology', 0.6736842105263158),
#  ('imaging science & photographic technology', 0.6597938144329897),
#  ('radiology, nuclear medicine & medical imaging', 0.6597938144329897),
#  ('optics', 0.64),
#  ('biochemistry & molecular biology', 0.6336633663366337),
#  ('science & technology - other topics', 0.6336633663366337),
#  ('neurosciences & neurology', 0.6274509803921569),
#  ('remote sensing', 0.6274509803921569),
#  ('instruments & instrumentation', 0.6213592233009708),
#  ('medical informatics', 0.6213592233009708),
#  ('automation & control systems', 0.6153846153846154),
#  ('physics', 0.6153846153846154),
#  ('chemistry', 0.6095238095238096),
#  ('genetics & heredity', 0.5981308411214953),
#  ('materials science', 0.5981308411214953),
#  ('telecommunications', 0.5981308411214953),
#  ('agriculture', 0.5925925925925926),
#  ('biophysics', 0.5871559633027523),
#  ('biotechnology & applied microbiology', 0.5871559633027523),
#  ('research & experimental medicine', 0.5871559633027523),
#  ('public, environmental & occupational health', 0.5818181818181818),
#  ('transportation', 0.5818181818181818),
#  ('information science & library science', 0.5765765765765766),
#  ('pharmacology & pharmacy', 0.5765765765765766),
#  ('business & economics', 0.5714285714285714),
#  ('education & educational research', 0.5714285714285714),
#  ('geology', 0.5714285714285714),
#  ('psychology', 0.5714285714285714),
#  ('robotics', 0.5714285714285714),
#  ('operations research & management science', 0.5663716814159292),
#  ('life sciences & biomedicine - other topics', 0.5614035087719298),
#  ('acoustics', 0.5565217391304348),
#  ('physiology', 0.5565217391304348),
#  ('energy & fuels', 0.5517241379310345),
#  ('geography', 0.5517241379310345),
#  ('nuclear science & technology', 0.5517241379310345),
#  ('oncology', 0.5517241379310345),
#  ('social sciences - other topics', 0.5517241379310345),
#  ('forestry', 0.5470085470085471),
#  ('medical laboratory technology', 0.5470085470085471),
#  ('meteorology & atmospheric sciences', 0.5470085470085471),
#  ('astronomy & astrophysics', 0.5423728813559322),
#  ('crystallography', 0.5423728813559322),
#  ('health care sciences & services', 0.5423728813559322),
#  ('mechanics', 0.5423728813559322),
#  ('physical geography', 0.5423728813559322),
#  ('linguistics', 0.5378151260504201),
#  ('surgery', 0.5378151260504201),
#  ('water resources', 0.5378151260504201),
#  ('behavioral sciences', 0.5333333333333333),
#  ('cardiovascular system & cardiology', 0.5333333333333333),
#  ('immunology', 0.5333333333333333),
#  ('oceanography', 0.5333333333333333),
#  ('spectroscopy', 0.5333333333333333),
#  ('toxicology', 0.5333333333333333),
#  ('rehabilitation', 0.5289256198347108),
#  ('sociology', 0.5203252032520326),
#  ('general & internal medicine', 0.5161290322580645),
#  ('infectious diseases', 0.5079365079365079),
#  ('plant sciences', 0.49612403100775193),
#  ('cell biology', 0.48854961832061067)]

# %%
between_c = nx.betweenness_centrality(core)
between_cs = ml.sorted_map(between_c)
between_cs
# Out:
# [('computer science', 0.17642189039270706),
#  ('engineering', 0.1457021859199017),
#  ('mathematics', 0.047097200848737905),
#  ('environmental sciences & ecology', 0.03615343168828287),
#  ('mathematical & computational biology', 0.02970218315838565),
#  ('radiology, nuclear medicine & medical imaging', 0.02264869956176378),
#  ('neurosciences & neurology', 0.022167498469566643),
#  ('imaging science & photographic technology', 0.020667124865368498),
#  ('biochemistry & molecular biology', 0.01832492027554911),
#  ('medical informatics', 0.015246151689275813),
#  ('optics', 0.013920247443208548),
#  ('science & technology - other topics', 0.012193558112523525),
#  ('remote sensing', 0.012125160088622087),
#  ('genetics & heredity', 0.010714611157076863),
#  ('chemistry', 0.010060069216914878),
#  ('public, environmental & occupational health', 0.009355866631762725),
#  ('biophysics', 0.009087459623724366),
#  ('agriculture', 0.009014728913467657),
#  ('instruments & instrumentation', 0.008206279173909259),
#  ('automation & control systems', 0.008138016035862675),
#  ('physics', 0.007944190785755584),
#  ('education & educational research', 0.0073413306631284975),
#  ('research & experimental medicine', 0.007077783127970291),
#  ('information science & library science', 0.006392371942375414),
#  ('biotechnology & applied microbiology', 0.006343153694523124),
#  ('psychology', 0.006160134014097113),
#  ('transportation', 0.005649529868279869),
#  ('business & economics', 0.005403925255952096),
#  ('materials science', 0.005165488087469345),
#  ('telecommunications', 0.005118354472183104),
#  ('pharmacology & pharmacy', 0.004416910154487793),
#  ('geology', 0.003946429792455703),
#  ('physiology', 0.0036983531138000333),
#  ('acoustics', 0.0035588796298008578),
#  ('life sciences & biomedicine - other topics', 0.002791020777214857),
#  ('robotics', 0.0026726547910021297),
#  ('operations research & management science', 0.002594289875705731),
#  ('oncology', 0.002178026373503547),
#  ('surgery', 0.002135185003488575),
#  ('social sciences - other topics', 0.002122274111011612),
#  ('plant sciences', 0.0018738576396950066),
#  ('cell biology', 0.0018071480082033028),
#  ('linguistics', 0.0017412307532167336),
#  ('astronomy & astrophysics', 0.0016167191840295383),
#  ('geography', 0.001597861188634998),
#  ('oceanography', 0.0015485936050937314),
#  ('health care sciences & services', 0.0015471761621315195),
#  ('forestry', 0.0015104281102356566),
#  ('immunology', 0.0014039780382948085),
#  ('rehabilitation', 0.0013809097487233373),
#  ('energy & fuels', 0.0013248699424732336),
#  ('water resources', 0.0010933563240110857),
#  ('meteorology & atmospheric sciences', 0.0010646573444192489),
#  ('nuclear science & technology', 0.0010231152825957515),
#  ('medical laboratory technology', 0.000960050476419524),
#  ('mechanics', 0.0006296327598252624),
#  ('general & internal medicine', 0.0005722080498866212),
#  ('spectroscopy', 0.0005538073410534895),
#  ('physical geography', 0.00044939903570855955),
#  ('cardiovascular system & cardiology', 0.00043048469387755103),
#  ('crystallography', 0.00038788137308795573),
#  ('behavioral sciences', 0.0003236016628873772),
#  ('infectious diseases', 0.0003141534391534391),
#  ('toxicology', 0.00014762849584278154),
#  ('sociology', 0.0)]

# %%
eigen_c = nx.eigenvector_centrality(core)
eigen_cs = ml.sorted_map(eigen_c)

# %%
pr = nx.pagerank(core)
pr_s = ml.sorted_map(pr)

# %%
n1 = {x[0] for x in degree_cs[:10]}
n2 = {x[0] for x in closeness_cs[:10]}
n3 = {x[0] for x in between_cs[:10]}
n4 = {x[0] for x in eigen_cs[:10]}
n5 = {x[0] for x in pr_s[:10]}
names = n1 | n2 | n3 | n4 | n5
table =[[name, degree_c[name], closeness_c[name], between_c[name], eigen_c[name], pr[name]] for name in names]
elite_group = pd.DataFrame(data = table, columns = ['field','degree', 'closeness', 'betweenness', 'eigenvector', 'pagerank'])
elite_group = elite_group.set_index('field')
elite_group
# Out:
#                                                  degree  closeness  \
# field
# mathematical & computational biology           0.515625   0.673684
# medical informatics                            0.390625   0.621359
# engineering                                    0.890625   0.901408
# imaging science & photographic technology      0.484375   0.659794
# science & technology - other topics            0.421875   0.633663
# optics                                         0.437500   0.640000
# environmental sciences & ecology               0.531250   0.680851
# neurosciences & neurology                      0.406250   0.627451
# computer science                               0.921875   0.927536
# mathematics                                    0.609375   0.719101
# radiology, nuclear medicine & medical imaging  0.484375   0.659794
# biochemistry & molecular biology               0.421875   0.633663
# instruments & instrumentation                  0.390625   0.621359
#
#                                                betweenness  eigenvector  \
# field
# mathematical & computational biology              0.029702     0.200063
# medical informatics                               0.015246     0.152518
# engineering                                       0.145702     0.286319
# imaging science & photographic technology         0.020667     0.188030
# science & technology - other topics               0.012194     0.176844
# optics                                            0.013920     0.176767
# environmental sciences & ecology                  0.036153     0.189346
# neurosciences & neurology                         0.022167     0.143687
# computer science                                  0.176422     0.288574
# mathematics                                       0.047097     0.219620
# radiology, nuclear medicine & medical imaging     0.022649     0.184317
# biochemistry & molecular biology                  0.018325     0.161441
# instruments & instrumentation                     0.008206     0.167257
#
#                                                pagerank
# field
# mathematical & computational biology           0.026265
# medical informatics                            0.020499
# engineering                                    0.044734
# imaging science & photographic technology      0.024555
# science & technology - other topics            0.021515
# optics                                         0.022228
# environmental sciences & ecology               0.027268
# neurosciences & neurology                      0.021795
# computer science                               0.046761
# mathematics                                    0.030671
# radiology, nuclear medicine & medical imaging  0.024759
# biochemistry & molecular biology               0.022017
# instruments & instrumentation                  0.019877

# %%
p = elite_group[['degree', 'closeness', 'betweenness', 'eigenvector', 'pagerank']].plot(kind='barh')

p = plt.title('Centrality measures for fields in machine learning literature')

# %% [markdown]
# Boundary spanners have low degree, high betweenness (bottlenecks or bridges) and high eigenvector centrality (actor connected to many actors who are connected). Here it looks mathematics and psychology could be playing something of these roles. Molecular biology and automation and control systems have spanning type positions too.

# %% [markdown]
# ## Authors in ML literature

# %%
df.af = df.AF.dropna().str.lower().str.strip()
df.af = df.af.str.split('; ')
af_all = [d for de in df.af for d in de if d is not np.nan]
af_set = set(af_all)
print "There %s authors listed and unique authors number %s" % (len(af_all), len(af_set))
af_counts = {de:af_all.count(de) for de in af_set}
af_counts_sorted = sorted(af_counts.iteritems(), key = operator.itemgetter(1), reverse=True)
af_counts_sorted[0:20]
# Out:
# There 98535 authors listed and unique authors number 62785
# [('mueller, klaus-robert', 43),
#  ('zhou, zhi-hua', 42),
#  ('dzeroski, s', 41),
#  ('nanni, loris', 38),
#  ('bratko, i', 36),
#  ('pedrycz, witold', 36),
#  ('huellermeier, eyke', 33),
#  ('king, rd', 33),
#  ('lumini, alessandra', 32),
#  ('santos, igor', 32),
#  ('wang, wei', 30),
#  ('wozniak, michal', 28),
#  ('dzeroski, saso', 28),
#  ('esposito, f', 26),
#  ('hong, tp', 25),
#  ('polat, kemal', 25),
#  ('xu, hua', 25),
#  ('kononenko, i', 25),
#  ('sugiyama, masashi', 24),
#  ('larranaga, pedro', 24)]

# %%
# these still need cleaning -- can see some duplicates
#To check out some of these

sq =gs.ScholarQuerier(author = 'Ross D King', count=50)
sq.query('')
print({a['title']:a['num_citations'] for a in sq.articles})
{a['title']:a['url'] for a in sq.articles}
# Out:
# {u'Theories for mutagenicity: A study in first-order and feature-based induction': 355, u'Application of metabolomics to plant genotype discrimination using statistics and machine learning': 231, u'Mutagenesis: ILP experiments in a non-determinate biological domain': 190, u'Relating chemical activity to structure: an examination of ILP successes': 130, u'Drug design by machine learning: The use of inductive logic programming to model the structure-activity relationships of trimethoprim analogues binding to  &hellip;': 269, u'Carcinogenesis predictions using ILP': 124, u'Identification and application of the concepts important for accurate and reliable protein secondary structure prediction': 424, u'Statlog: comparison of classification algorithms on large real-world problems': 183, u'Finding Frequent Substructures in Chemical Compounds.': 325, u'Identification and analysis of functional elements in 1% of the human genome by the ENCODE pilot project': 2605, u'Hierarchical metabolomics demonstrates substantial compositional similarity between genetically modified and conventional potato crops': 278, u'Intensive blood-glucose control with sulphonylureas or insulin compared with conventional treatment and risk of complications in patients with type 2 diabetes ( &hellip;': 12125, u'Protein secondary structure prediction using logic-based machine learning': 258, u'The predictive toxicology evaluation challenge': 132, u'Machine learning approach for the prediction of protein secondary structure': 102, u'Functional genomic hypothesis generation and experimentation by a robot scientist': 341, u'The automation of science': 171, u'Cascaded multiple classifiers for secondary structure prediction': 367, u'Structure-activity relationships derived by machine learning: The use of atoms and their bond connectivities to predict mutagenicity by inductive logic programming': 254, u'Knowledge discovery in multi-label phenotype data': 224}
# {u'Application of metabolomics to plant genotype discrimination using statistics and machine learning': u'http://bioinformatics.oxfordjournals.org/content/18/suppl_2/S241.short',
#  u'Carcinogenesis predictions using ILP': u'http://link.springer.com/chapter/10.1007/3540635149_56',
#  u'Cascaded multiple classifiers for secondary structure prediction': u'http://journals.cambridge.org/abstract_S0961836800993854',
#  u'Drug design by machine learning: The use of inductive logic programming to model the structure-activity relationships of trimethoprim analogues binding to  &hellip;': u'http://www.pnas.org/content/89/23/11322.short',
#  u'Finding Frequent Substructures in Chemical Compounds.': u'http://www.aaai.org/Papers/KDD/1998/KDD98-005',
#  u'Functional genomic hypothesis generation and experimentation by a robot scientist': u'http://www.nature.com/nature/journal/v427/n6971/abs/nature02236.html',
#  u'Hierarchical metabolomics demonstrates substantial compositional similarity between genetically modified and conventional potato crops': u'http://www.pnas.org/content/102/40/14458.short',
#  u'Identification and analysis of functional elements in 1% of the human genome by the ENCODE pilot project': u'http://www.nature.com/nature/journal/vaop/ncurrent/full/nature05874.html',
#  u'Identification and application of the concepts important for accurate and reliable protein secondary structure prediction': u'http://onlinelibrary.wiley.com/doi/10.1002/pro.5560051116/abstract',
#  u'Intensive blood-glucose control with sulphonylureas or insulin compared with conventional treatment and risk of complications in patients with type 2 diabetes ( &hellip;': u'http://discovery.ucl.ac.uk/1310755/',
#  u'Knowledge discovery in multi-label phenotype data': u'http://link.springer.com/chapter/10.1007/3-540-44794-6_4',
#  u'Machine learning approach for the prediction of protein secondary structure': u'http://www.sciencedirect.com/science/article/pii/S002228360580333X',
#  u'Mutagenesis: ILP experiments in a non-determinate biological domain': u'http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.57.377&rep=rep1&type=pdf',
#  u'Protein secondary structure prediction using logic-based machine learning': u'http://peds.oxfordjournals.org/content/5/7/647.short',
#  u'Relating chemical activity to structure: an examination of ILP successes': u'http://link.springer.com/article/10.1007/BF03037232',
#  u'Statlog: comparison of classification algorithms on large real-world problems': u'http://www.tandfonline.com/doi/abs/10.1080/08839519508945477',
#  u'Structure-activity relationships derived by machine learning: The use of atoms and their bond connectivities to predict mutagenicity by inductive logic programming': u'http://www.pnas.org/content/93/1/438.short',
#  u'The automation of science': u'http://www.sciencemag.org/content/324/5923/85.short',
#  u'The predictive toxicology evaluation challenge': u'http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.75.4469&rep=rep1&type=pdf',
#  u'Theories for mutagenicity: A study in first-order and feature-based induction': u'http://www.sciencedirect.com/science/article/pii/0004370295001220'}

# %% [markdown]
# There are some interesting differences here:
#
#    -  Klaus Mueller works on medical decisions
#    -  dzeroski works on induction
#    -  zhou, zhi-hua at nanjing works on facial recognition
#    - Ross King works on synthetic biology and proteins, and in particular, the automation of science using AI

# %% [markdown]
# ## Who has been cited most in the machine learning literature?
#
# Within the machine learning references, we can look just at the times cited field provided by Web of Science.  It seems that Breiman's RandomForests paper is the most important, followed by a wireless paper, then two papers in ecology, a methods paper, then the newer technique of Gaussian processes, followed by a text categorisation paper, then molecular biology paper, then three more methods papers, followed by some face detection articles and cancer-related papers.

# %%
df[['AU', 'TI', 'TC', 'PY', 'ID', 'DE']][df.TC>500].sort('TC', ascending=False)
# Out:
#                                                       AU  \
# 17863                                         Breiman, L
# 21848                                          Haykin, S
# 3652   Elith, J; Graham, CH; Anderson, RP; Dudik, M; ...
# 3805            Phillips, SJ; Anderson, RP; Schapire, RE
# 3591                                          Fawcett, T
# 18165                       Rasmussen, CE; Williams, CKI
# 22378                                      Sebastiani, F
# 3692   Krogan, NJ; Cagney, G; Yu, HY; Zhong, GQ; Guo,...
# 2846               Kaelbling, LP; Littman, ML; Moore, AW
# 24611              Friedman, J; Hastie, T; Tibshirani, R
# 16098                               Belkin, M; Niyogi, P
# 18726                   Rowley, HA; Baluja, S; Kanade, T
# 17658  Shipp, MA; Ross, KN; Tamayo, P; Weng, AP; Kuto...
# 17589                   Yang, MH; Kriegman, DJ; Ahuja, N
# 19367                          COOPER, GF; HERSKOVITS, E
# 15282                                          Demsar, J
# 22388                 Dudoit, S; Fridlyand, J; Speed, TP
# 22963               GEMAN, S; BIENENSTOCK, E; DOURSAT, R
# 10512                            Smola, AJ; Scholkopf, B
# 24529  Furey, TS; Cristianini, N; Duffy, N; Bednarski...
# 17840                             Rahm, E; Bernstein, PA
# 18924                                        Bradley, AP
# 24457                                 Viola, P; Jones, M
# 21741                                   Xu, R; Wunsch, D
# 18540         Lecun, Y; Bottou, L; Bengio, Y; Haffner, P
# 22331                       de Castro, LN; Von Zuben, FJ
# 18863                               Blum, AL; Langley, P
# 22983                                  LIN, CT; LEE, CSG
# 2679                           Chen, MS; Han, JW; Yu, PS
# 22309  Kanungo, T; Mount, DM; Netanyahu, NS; Piatko, ...
# 19294                                          HOLTE, RC
# 4867                               Pawlak, Z; Skowron, A
# 21014  Lanckriet, GRG; Cristianini, N; Bartlett, P; E...
# 10591                 Kall, L; Krogh, A; Sonnhammer, ELL
#
#                                                       TI    TC    PY  \
# 17863                                     Random forests  4281  2001
# 21848  Cognitive radio: Brain-empowered wireless comm...  2757  2005
# 3652   Novel methods improve prediction of species' d...  1574  2006
# 3805   Maximum entropy modeling of species geographic...  1531  2006
# 3591                     An introduction to ROC analysis  1488  2006
# 18165            Gaussian Processes for Machine Learning  1320  2005
# 22378  Machine learning in automated text categorization  1296  2002
# 3692   Global landscape of protein complexes in the y...  1257  2006
# 2846                    Reinforcement learning: A survey  1255  1996
# 24611  Additive logistic regression: A statistical vi...  1248  2000
# 16098  Laplacian eigenmaps for dimensionality reducti...  1213  2003
# 18726                Neural network-based face detection  1175  1998
# 17658  Diffuse large B-cell lymphoma outcome predicti...  1124  2002
# 17589                Detecting faces in images: A survey  1097  2002
# 19367  A BAYESIAN METHOD FOR THE INDUCTION OF PROBABI...  1064  1992
# 15282  Statistical comparisons of classifiers over mu...  1018  2006
# 22388  Comparison of discrimination methods for the c...   987  2002
# 22963      NEURAL NETWORKS AND THE BIAS VARIANCE DILEMMA   952  1992
# 10512            A tutorial on support vector regression   870  2004
# 24529  Support vector machine classification and vali...   869  2000
# 17840  A survey of approaches to automatic schema mat...   824  2001
# 18924  The use of the area under the roc curve in the...   813  1997
# 24457  Rapid object detection using a boosted cascade...   750  2001
# 21741                    Survey of clustering algorithms   736  2005
# 18540  Gradient-based learning applied to document re...   697  1998
# 22331  Learning and optimization using the clonal sel...   690  2002
# 18863  Selection of relevant features and examples in...   690  1997
# 22983  NEURAL-NETWORK-BASED FUZZY-LOGIC CONTROL AND D...   636  1991
# 2679   Data mining: An overview from a database persp...   629  1996
# 22309  An efficient k-means clustering algorithm: Ana...   562  2002
# 19294  VERY SIMPLE CLASSIFICATION RULES PERFORM WELL ...   507  1993
# 4867                             Rudiments of rough sets   505  2007
# 21014  Learning the kernel matrix with semidefinite p...   501  2004
# 10591  A combined transmembrane topology and signal p...   501  2004
#
#                                                       ID  \
# 17863                                                NaN
# 21848          NANOTUBE ELECTRONICS; SPECTRUM ESTIMATION
# 3652   CLIMATE-CHANGE; LOGISTIC-REGRESSION; DISTRIBUT...
# 3805   OPERATING CHARACTERISTIC CURVES; GENERALIZED A...
# 3591                         CLASSIFICATION; CURVE; AREA
# 18165  SUPPORT VECTOR MACHINES; SPLINE FUNCTIONS; BAY...
# 22378  PROBABILISTIC INFORMATION-RETRIEVAL; DOCUMENT ...
# 3692   INTERACTION NETWORK; MASS-SPECTROMETRY; RNA-PO...
# 2846                                          ALGORITHMS
# 24611                                     CLASSIFICATION
# 16098                                                NaN
# 18726                                                NaN
# 17658  NON-HODGKINS-LYMPHOMA; NF-KAPPA-B; PROGNOSTIC-...
# 17589  NEURAL-NETWORK; PATTERN DETECTION; STATISTICAL...
# 19367  GRAPHICAL STRUCTURES; INFLUENCE DIAGRAMS; BELI...
# 15282          CLASSIFICATION LEARNING ALGORITHMS; TESTS
# 22388           OLIGONUCLEOTIDE ARRAYS; PATTERNS; CANCER
# 22963  MULTILAYER FEEDFORWARD NETWORKS; PROJECTION PU...
# 10512  PATTERN-RECOGNITION; ENTROPY NUMBERS; MACHINES...
# 24529  GENE-EXPRESSION; OLIGONUCLEOTIDE ARRAYS; OVARI...
# 17840                    HETEROGENEOUS DATABASES; SYSTEM
# 18924                                          DIAGNOSIS
# 24457                                   VISUAL-ATTENTION
# 21741  HIDDEN MARKOV-MODELS; K-MEANS ALGORITHM; GENE-...
# 18540  NEURAL-NETWORK; DESCENT; ARCHITECTURE; ALGORIT...
# 22331               CROSS-REACTIVITY; MATURATION; MEMORY
# 18863  IRRELEVANT ATTRIBUTES; LEARNABILITY; ALGORITHM...
# 22983                                              MODEL
# 2679                                                 NaN
# 22309                                            THEOREM
# 19294                                                NaN
# 4867   BEHAVIORAL-PATTERN IDENTIFICATION; INCOMPLETE ...
# 21014                                                NaN
# 10591  INTEGRAL MEMBRANE-PROTEINS; SEQUENCE CLEAVAGE ...
#
#                                                       DE
# 17863               classification; regression; ensemble
# 21848  awareness; channel-state estimation and predic...
# 3652                                                 NaN
# 3805   maximum entropy; distribution; modeling; niche...
# 3591   ROC analysis; classifier evaluation; evaluatio...
# 18165                                                NaN
# 22378  algorithms; experimentation; theory; machine l...
# 3692                                                 NaN
# 2846                                                 NaN
# 24611  classification; tree; nonparametric estimation...
# 16098                                                NaN
# 18726  face detection; pattern recognition; computer ...
# 17658                                                NaN
# 17589  face detection; face recognition; object recog...
# 19367  PROBABILISTIC NETWORKS; BAYESIAN BELIEF NETWOR...
# 15282  comparative studies; statistical methods; Wilc...
# 22388  cancer; discriminant analysis; microarray expe...
# 22963                                                NaN
# 10512  machine learning; support vector machines; reg...
# 24529                                                NaN
# 17840  schema matching; schema integration; graph mat...
# 18924  the ROC curve; the area under the ROC curve (A...
# 24457                                                NaN
# 21741  adaptive resonance theory (ART); clustering; c...
# 18540  convolutional neural networks; document recogn...
# 22331  clonal selection principle; evolutionary algor...
# 18863  relevant features; relevant examples; machine ...
# 22983  CONNECTIONIST; DISTRIBUTED REPRESENTATION; DEF...
# 2679   data mining; knowledge discovery; association ...
# 22309  pattern recognition; machine learning; data mi...
# 19294  EMPIRICAL LEARNING; ACCURACY COMPLEXITY TRADEO...
# 4867   vague concepts; information and decision syste...
# 21014  kernel methods; learning kernels; transduction...
# 10591  transmembrane protein; signal peptide; topolog...

# %%
df.ix[df.TC.idxmax(), 51:]
# Out:
# SP                                                          NaN
# SU                                                          NaN
# TC                                                         4281
# TI                                               Random forests
# UT                                          WOS:000170489900001
# VL                                                           45
# WC                    Computer Science, Artificial Intelligence
# Z9                                                         4457
# ﻿PT                                                           J
# cited_refs    [amit y, 1997, neural comput, v9, p1545, doi 1...
# topics                   [classification, regression, ensemble]
# fields                                       [computer science]
# Name: 17863, dtype: object

# %% [markdown]
# But this doesn't say who has been cited most  in the literature. There are around 350,000 unique references cited in these papers, amongst 650,000 total citations.

# %%
all_refs = [ref for refs in df.cited_refs for ref in refs]
ref_collection = collections.Counter(all_refs)
ref_collection.most_common(n=20)
# Out:
# [('quinlan j. r., 1993, c4 5 programs machin', 1701),
#  ('breiman l, 2001, mach learn, v45, p5, doi 10.1023/a:1010933404324', 1394),
#  ('vapnik vn, 1998, stat learning theory', 1384),
#  ('vapnik v. n, 1995, nature stat learning', 1344),
#  ('mitchell t, 1997, machine learning', 1201),
#  ('witten i. h., 2005, data mining practica', 1063),
#  ('nan', 1033),
#  ('cortes c, 1995, mach learn, v20, p273, doi 10.1023/a:1022627411411', 1009),
#  ('breiman l, 1984, classification regre', 982),
#  ('quinlan j. r., 1986, machine learning, v1, doi 10.1023/a:1022643204877',
#   840),
#  ('cristianini n., 2000, intro support vector', 801),
#  ('breiman l, 1996, mach learn, v24, p123, doi 10.1007/bf00058655', 748),
#  ('chang c.-c., 2001, libsvm lib support v', 678),
#  ('duda r. o., 2001, pattern classificati', 636),
#  ('burges cjc, 1998, data min knowl disc, v2, p121, doi 10.1023/a:1009715923555',
#   616),
#  ('bishop c.m., 1995, neural networks patt', 528),
#  ('freund y, 1997, j comput syst sci, v55, p119, doi 10.1006/jcss.1997.1504',
#   512),
#  ('goldberg de, 1989, genetic algorithms s', 512),
#  ('hastie t, 2001, elements stat learni', 495),
#  ('bishop c. m., 2006, pattern recognition', 493)]

# %%
sq =gs.ScholarQuerier(author = 'Ross J Quinlan', count=50)
sq.query('')
print(ml.sorted_map({a['title']:a['num_citations'] for a in sq.articles}))
{a['title']:a['url'] for a in sq.articles}
# Out:
# [(u'C4. 5: programs for machine learning', 22286), (u'Induction of decision trees', 12413), (u'Learning logical definitions from relations', 1958), (u'Simplifying decision trees', 1442), (u'Learning efficient classification procedures and their application to chess end games', 1389), (u'Bagging, boosting, and C4. 5', 1330), (u'Improved use of continuous attributes in C4. 5', 1099), (u'Cited by 938', 938), (u'Top 10 algorithms in data mining', 831), (u'FOIL: A midterm report', 565), (u'Generating Production Rules from Decision Trees.', 457), (u'Combining Instance-Based and Model-Based Learning.', 377), (u'The effect of noise on concept learning', 363), (u'Unknown attribute values in induction.', 361), (u'Decision trees and decision-making', 319), (u'Cited by 303', 303), (u'Cited by 235', 235), (u'Inductive knowledge acquisition: a case study', 203), (u'Inferno: A cautious approach to uncertain inference', 195), (u'Induction of logic programs: FOIL and related systems', 194)]
# {u'Bagging, boosting, and C4. 5': u'http://www.cs.ecu.edu/~dingq/CSCI6905/readings/BaggingBoosting.pdf',
#  u'C4. 5: programs for machine learning': u'http://books.google.com/books?hl=en&lr=&id=HExncpjbYroC&oi=fnd&pg=PR7&dq=+Ross+J+Quinlan&ots=nKr8iTx_1j&sig=9s5BuDdObVNRu2hmmZUfbilN7U8',
#  u'Cited by 235': u'http://scholar.google.com/scholar?cites=17708554099668242973&as_sdt=2005&sciodt=1,5&hl=en&num=20',
#  u'Cited by 303': u'http://scholar.google.com/scholar?cites=14591131946535439496&as_sdt=2005&sciodt=1,5&hl=en&num=20',
#  u'Cited by 938': u'http://scholar.google.com/scholar?cites=8617689792676967274&as_sdt=2005&sciodt=1,5&hl=en&num=20',
#  u'Combining Instance-Based and Model-Based Learning.': u'http://cs.ecs.baylor.edu/~hamerly/courses/5325_11s/papers/ibl/quinlan1993combining.pdf',
#  u'Decision trees and decision-making': u'http://ieeexplore.ieee.org/xpls/abs_all.jsp?arnumber=52545',
#  u'FOIL: A midterm report': u'http://link.springer.com/chapter/10.1007/3-540-56602-3_124',
#  u'Generating Production Rules from Decision Trees.': u'http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.98.9054&rep=rep1&type=pdf',
#  u'Improved use of continuous attributes in C4. 5': u'http://arxiv.org/abs/cs/9603103',
#  u'Induction of decision trees': u'http://link.springer.com/article/10.1023/A:1022643204877',
#  u'Induction of logic programs: FOIL and related systems': u'http://link.springer.com/article/10.1007/BF03037228',
#  u'Inductive knowledge acquisition: a case study': u'http://dl.acm.org/citation.cfm?id=33438',
#  u'Inferno: A cautious approach to uncertain inference': u'http://oai.dtic.mil/oai/oai?verb=getRecord&metadataPrefix=html&identifier=ADA125684',
#  u'Learning efficient classification procedures and their application to chess end games': u'http://link.springer.com/chapter/10.1007/978-3-662-12405-5_15',
#  u'Learning logical definitions from relations': u'http://link.springer.com/article/10.1007/BF00117105',
#  u'Simplifying decision trees': u'http://www.sciencedirect.com/science/article/pii/S0020737387800536',
#  u'The effect of noise on concept learning': u'http://books.google.com/books?hl=en&lr=&id=f9RylgKpHZsC&oi=fnd&pg=PA149&dq=+Ross+J+Quinlan&ots=Ve3L5uK1Jz&sig=1QXuJYLgh7PYsS_ee5gYG8cbqFU',
#  u'Top 10 algorithms in data mining': u'http://link.springer.com/article/10.1007/s10115-007-0114-2',
#  u'Unknown attribute values in induction.': u'http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.35.69&rep=rep1&type=pdf'}

# %% [markdown]
# ##  Co-authorship networks in ML
#
# How tightly networked are the publications in terms of co-writing? This might need to be done over time.

# %%
au_g = ml.wos_author_graph(df)
# Out:
# Adding nodes for authors ...
# Adding edges for co-authors...
# Author graph has 51697 authors and 215353 co-author connects

# %%
pos, sel = gt.graph_draw(au_g)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/lib/python2.7/dist-packages/gi/overrides/GLib.pyc in <lambda>(data)
#     627
#     628     if cb_num_args == 0:
# --> 629         return (lambda data: callback(*data), user_data)
#     630     if cb_num_args == 2:
#     631         return (lambda a1, a2, data: callback(a1, a2, *data), user_data)
#
# /usr/lib/python2.7/dist-packages/graph_tool/draw/gtk_draw.pyc in layout_callback(self)
#     322         if self.vertex_matrix is not None:
#     323             self.vertex_matrix.update()
# --> 324         self.regenerate_surface(lazy=False)
#     325         self.queue_draw()
#     326         ps = ungroup_vector_property(self.pos, [0, 1])
#
# /usr/lib/python2.7/dist-packages/graph_tool/draw/gtk_draw.pyc in regenerate_surface(self, lazy, timeout)
#     399             cr.set_matrix(self.tmatrix)
#     400             cairo_draw(self.g, self.pos, cr, self.vprops, self.eprops,
# --> 401                        self.vorder, self.eorder, self.nodesfirst, **self.kwargs)
#     402             self.smatrix = cairo.Matrix()
#     403             self.smatrix.translate(-self.get_allocated_width(),
#
# /usr/lib/python2.7/dist-packages/graph_tool/draw/cairo_draw.pyc in cairo_draw(g, pos, cr, vprops, eprops, vorder, eorder, nodesfirst, vcmap, ecmap, loop_angle, parallel_distance, fit_view, **kwargs)
#     451     libgraph_tool_draw.cairo_draw(g._Graph__graph, _prop("v", g, pos),
#     452                                   _prop("v", g, vorder), _prop("e", g, eorder),
# --> 453                                   nodesfirst, vattrs, eattrs, vdefs, edefs, cr)
#     454     cr.restore()
#     455
#
# KeyboardInterrupt:

# %%
v_comm = gt.community_structure(au_g, 1000, 5)
gt.graph_draw(au_g, pos=pos, vertex_color = v_comm,output = '../figure/ml_author_net_2000.png')
# Out:
# <PropertyMap object with key type 'Vertex' and value type 'vector<double>', for Graph 0x16332210, at 0x14cbb8d0>

# %%
i =IPython.display.Image('../figure/ml_author_net_2000.png')
print('This is the author community network prior up to 2000')

# %% [markdown]
# ## The techniques and topics in the literature
#
# This relies on the 'DE' in the Web of Science records

# %%
# topics seem to be in the DE field


de_all = [d for de in df.topics.dropna() for d in de]

de_set = set(de_all)
print "All topics has %s and unique topics number %s" % (len(de_all), len(de_set))
# Out:
# All topics has 89645 and unique topics number 34407

# %%
de_counts = {de:de_all.count(de) for de in de_set}

# %% [markdown]
# The problem is that the topics mix techniques and application: principal component analysis stands alongside face recognition. So we need to sort those out first.
# I've only considered a manual way to do this.

# %%
# to see how topics are distributed

de_counts_sorted = sorted(de_counts.iteritems(), key = operator.itemgetter(1), reverse=True)
de_counts_sorted[0:50]
# Out:
# [('machine learning', 7607),
#  ('support vector machine', 1792),
#  ('classification', 1164),
#  ('data mining', 974),
#  ('neural network', 868),
#  ('feature selection', 649),
#  ('decision tree', 513),
#  ('pattern recognition', 408),
#  ('clustering', 322),
#  ('artificial intelligence', 322),
#  ('random forest', 260),
#  ('genetic algorithms', 226),
#  ('natural language processing', 226),
#  ('bioinformatics', 219),
#  ('reinforcement learning', 216),
#  ('prediction', 214),
#  ('feature extraction', 212),
#  ('genetic algorithm', 202),
#  ('neural networks', 176),
#  ('boosting', 168),
#  ('text mining', 163),
#  ('semi-supervised learning', 158),
#  ('algorithms', 158),
#  ('information retrieval', 148),
#  ('genetic programming', 147),
#  ('knowledge discovery', 143),
#  ('supervised learning', 141),
#  ('regression', 140),
#  ('optimization', 139),
#  ('kernel methods', 139),
#  ('knowledge acquisition', 137),
#  ('computer vision', 136),
#  ('bayesian networks', 135),
#  ('image processing', 127),
#  ('text classification', 127),
#  ('support vector regression', 126),
#  ('information extraction', 124),
#  ('pattern classification', 122),
#  ('ensemble learning', 117),
#  ('dimensionality reduction', 117),
#  ('learning', 115),
#  ('intrusion detection', 111),
#  ('anomaly detection', 104),
#  ('fuzzy logic', 103),
#  ('adaboost', 100),
#  ('rough sets', 100),
#  ('active learning', 99),
#  ('rough set', 97),
#  ('logistic regression', 97),
#  ('unsupervised learning', 95)]

# %% [markdown]
# The most frequent ones are techniques, but there are also lots of applications here - text classification, computer vision, intrusion detection, etc. To sort out the techniques, I classified by the hand the top 1000

# %%
techniques_domains = pickle.load(open('technique_classification.pyd', 'r'))

# %%
tech_s = sorted([tech for tech, cl in techniques_domains.iteritems() if cl == 'y'])

print(len(tech_s))
tech_cleaned = [re.sub('\(.+\)', '',t) for t in tech_s]

tech_cleaned[:30]
tech_cleaned.remove('artificial intelligence')
tech_cleaned.remove('machine learning')
tech_cleaned.remove('data mining')
tech_cleaned.remove('pattern recognition')

print('Number of different techniques in the literature: %d'%len(set(tech_cleaned)))
tech_cleaned[0:30]
#tech_cleaned.count('decision tree')
# Out:
# 459
# Number of different techniques in the literature: 454
# ['abductive networks',
#  'abstraction',
#  'active learning',
#  'adaboost',
#  'adaptive control',
#  'adaptive learning',
#  'adaptive systems',
#  'algorithm selection',
#  'approximation',
#  'artificial immune systems',
#  'artificial neural network',
#  'artificial neural network ',
#  'association rule',
#  'association rule mining',
#  'association rules',
#  'associative classification',
#  'auc',
#  'automatic classification',
#  'backpropagation',
#  'bagging',
#  'bayesian',
#  'bayesian belief networks',
#  'bayesian classifier',
#  'bayesian classifiers',
#  'bayesian inference',
#  'bayesian methods',
#  'bayesian network',
#  'bias',
#  'binary classification',
#  'blind signal separation']

# %% [markdown]
# ### Domains
#
# If techniques are removed, we are left with domains

# %%
domains = sorted([tech for tech, cl in techniques_domains.iteritems() if cl == 'n'])
domains[:40]
# Out:
# ['accelerometer',
#  'accelerometers',
#  'accuracy',
#  'activity recognition',
#  'adaptation',
#  'adaptive',
#  'adaptive resonance theory',
#  'adaptive signal processing',
#  'adme',
#  'admet',
#  'affective computing',
#  'agent',
#  'agents',
#  'aging',
#  'airs',
#  'algorithm',
#  'alignment',
#  "alzheimer's disease",
#  'ambient intelligence',
#  'amino acid composition',
#  'analogy',
#  'anfis',
#  'ann',
#  'annotation',
#  'anomaly detection',
#  'ant colony optimization',
#  'applications',
#  'architecture',
#  'artificial immune system',
#  'artmap',
#  'attribute reduction',
#  'attribute selection',
#  'automatic image annotation',
#  'automation',
#  'autonomous agents',
#  'autonomous navigation',
#  'bankruptcy prediction',
#  'bci',
#  'benchmark',
#  'bioinformatic']

# %% [markdown]
# # A network of techniques
#
# The idea here is to see how techniques are connected to each other. There are roughly 500 techniques across 23000 references. Some of these references have multiple techniques. Not all techniques are techniques. Some name problems. So as well as removing domains, we need to remove problems.

# %%
# classify references by techniques
tech_gr = nx.DiGraph()

#construct technique edge list 

# find techniques in a reference and add co-present techniques
# as edges to graph

tech_cleaned.append('nn classifier')
for topics in df.topics.dropna():
    techs = [t for t in topics if tech_cleaned.count(t) > 0]
    edges = [c for c in itertools.combinations(techs,2)]
    for subject_id, object_id in edges:
        if tech_gr.has_edge(subject_id, object_id):
            tech_gr[subject_id][object_id]['weight'] += 1
        else:
            tech_gr.add_edge(subject_id, object_id, weight=1)

tech_gr.size()
# Out:
# 4635

# %%
tech_core = trim_degrees(tech_gr,13 )
tech_core= trim_edges(tech_core, 10)
print tech_core.size()

nx.draw_spring(tech_core, k=0.4,width = 0.2,alph=0.5, figsize=(10,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-17ae42b956c0> in <module>()
# ----> 1 tech_core = trim_degrees(tech_gr,13 )
#       2 tech_core= trim_edges(tech_core, 10)
#       3 print tech_core.size()
#       4
#       5 nx.draw_spring(tech_core, k=0.4,width = 0.2,alph=0.5, figsize=(10,10))
#
# NameError: name 'trim_degrees' is not defined

# %%
tech_degree_c = nx.degree_centrality(tech_core)
tech_degree_cs = ml.sorted_map(tech_degree_c)
tech_degree_cs[:10]
# Out:
# [('classification', 0.7333333333333333),
#  ('support vector machine', 0.7333333333333333),
#  ('neural network', 0.3333333333333333),
#  ('decision tree', 0.2),
#  ('feature selection', 0.2),
#  ('genetic algorithm', 0.2),
#  ('boosting', 0.13333333333333333),
#  ('feature extraction', 0.13333333333333333),
#  ('prediction', 0.13333333333333333),
#  ('regression', 0.13333333333333333)]

# %%
tech_closeness_c = nx.closeness_centrality(tech_core)
tech_closeness_cs = sorted_map(tech_closeness_c)
tech_closeness_cs[:10]
# Out:
# [('classification', 0.75),
#  ('support vector machine', 0.6521739130434783),
#  ('feature selection', 0.5357142857142857),
#  ('decision tree', 0.5172413793103449),
#  ('prediction', 0.5172413793103449),
#  ('boosting', 0.46875),
#  ('clustering', 0.4411764705882353),
#  ('feature extraction', 0.4411764705882353),
#  ('genetic programming', 0.4411764705882353),
#  ('optimization', 0.4411764705882353)]

# %%
tech_between_c = nx.betweenness_centrality(tech_core)
tech_between_cs = sorted_map(tech_between_c)
tech_between_cs[:10]
# Out:
# [('classification', 0.7380952380952381),
#  ('support vector machine', 0.4285714285714286),
#  ('boosting', 0.13333333333333336),
#  ('feature selection', 0.0380952380952381),
#  ('genetic algorithm', 0.004761904761904762),
#  ('bagging', 0.0),
#  ('clustering', 0.0),
#  ('decision tree', 0.0),
#  ('feature extraction', 0.0),
#  ('genetic programming', 0.0)]

# %%
tech_eigen_c = nx.eigenvector_centrality(tech_core)
tech_eigen_cs = sorted_map(tech_eigen_c)
tech_eigen_cs[:10]
# Out:
# [('classification', 0.5420751035645175),
#  ('support vector machine', 0.5254496358830248),
#  ('feature selection', 0.38572455726503596),
#  ('neural network', 0.269881214078494),
#  ('decision tree', 0.23417140871318876),
#  ('genetic algorithm', 0.21563519951155427),
#  ('prediction', 0.164089678158054),
#  ('regression', 0.1541950134766508),
#  ('clustering', 0.12849584456387564),
#  ('feature extraction', 0.08994709119471296)]

# %%
tech_pr = nx.pagerank(tech_core)
tech_pr_s = sorted_map(tech_pr)

# %%
n1 = {x[0] for x in tech_degree_cs[:10]}
n2 = {x[0] for x in tech_closeness_cs[:10]}
n3 = {x[0] for x in tech_between_cs[:10]}
n4 = {x[0] for x in tech_eigen_cs[:10]}
n5 = {x[0] for x in tech_pr_s[:10]}
names = n1 | n2 | n3 | n4 | n5
table =[[name, tech_degree_c[name], tech_closeness_c[name], tech_between_c[name], tech_eigen_c[name], tech_pr[name]] for name in names]
tech_group = pd.DataFrame(data = table, columns = ['technique','degree', 'closeness', 'betweenness', 'eigenvector', 'pagerank'])
tech_group = tech_group.set_index('technique')
tech_group
# Out:
#                           degree  closeness  betweenness  eigenvector  pagerank
# technique
# genetic programming     0.066667   0.441176     0.000000     0.083522  0.023787
# classification          0.666667   0.750000     0.738095     0.542075  0.246499
# decision tree           0.133333   0.517241     0.000000     0.234171  0.048946
# feature extraction      0.066667   0.441176     0.000000     0.089947  0.024895
# prediction              0.133333   0.517241     0.000000     0.164090  0.036992
# boosting                0.133333   0.468750     0.133333     0.080360  0.053163
# regression              0.066667   0.441176     0.000000     0.154195  0.035981
# clustering              0.066667   0.441176     0.000000     0.128496  0.031547
# support vector machine  0.533333   0.652174     0.428571     0.525450  0.189913
# genetic algorithm       0.200000   0.428571     0.004762     0.215635  0.056652
# neural network          0.133333   0.416667     0.000000     0.269881  0.062055
# optimization            0.066667   0.441176     0.000000     0.070673  0.021570
# feature selection       0.200000   0.535714     0.038095     0.385725  0.086653
# bagging                 0.066667   0.326087     0.000000     0.016192  0.035865

# %%
tech_group[['degree', 'betweenness', 'closeness', 'eigenvector', 'pagerank']].plot(kind='barh',figsize=(10,10))

# %% [markdown]
# The highest degree centralities are machine learning, classification, support vector machine and data-mining. There is a bit of mixture here - machine learning or data mining are whole areas of technique, whereas support bector machine or neural network are particular techniques. If these were taken out, the network starts to look at bit different. Also some techniques are almost synonous -- feature selection and feature extraction are almost the same thing. If they were added together, their closeness centrality would be greater than many of the others.
#
# It is really striking how important support vector machines, as well as neural networks and decision trees. They figure heavily.
#
# Classification is really important -- it is second to machine learning on most measures of centrality.
#
# In terms of boundary spanning, it seems that feature extraction, feature selection suddenly figure more in the eigenvector measure -- does that mean that they are linking different subgraphs more?

# %% [markdown]
# ## Cliques and clusters in the techniques

# %%
print(len(tech_gr))
len(nx.connected_component_subgraphs(tech_gr.to_undirected()))
# Out:
# 422
# 1

# %% [markdown]
# As it looks from above, this is one hairball of a graph of techniques

# %%
svm = nx.ego_graph(tech_gr.to_undirected(), 'support vector machine', radius=2)
nx.average_clustering(svm)
# Out:
# 0.3530765745019574

# %%
neural = nx.ego_graph(tech_gr.to_undirected(), 'neural network', radius=2)
print(len(neural))
nx.average_clustering(neural)
# Out:
# 416
# 0.3541360296708294

# %% [markdown]
# ### Trim the edges based on weights

# %%
def trim_edges(g, weight=1):
    g2 = nx.Graph()
    [g2.add_edge(f,to, edata) for f, to, edata in g.edges(data=True) if edata['weight']>weight]
    return g2

def island_method(g, iterations=5):
    weights = [edata['weight'] for f, to, edata in g.edges(data=True)]
    mn = int(min(weights))
    mx = int(max(weights))
    step = int((mx-mn)/iterations)
    return [[threshold, trim_edges(g, threshold)] for threshold in range(mn,mx,step)]

# %%
islands = island_method(tech_gr)
len(islands)
for i in islands:
    print i[0], len(i[1]), len(nx.connected_component_subgraphs(i[1]))
# Out:
# 1 321 6
# 9 18 2
# 17 8 1
# 25 4 1
# 33 4 1
# 41 2 1

# %%
l = nx.fruchterman_reingold_layout(islands[1][1], k=0.4)
nx.draw_spring(islands[1][1], layout = l, alpha=0.7)

# %%
nx.draw_spring(islands[2][1], k=0.3,alpha=0.7)

# %% [markdown]
# This is produced used the island method of splitting giant components in to smaller areas of stronger relationality. In this case, there are only two connected subgraphs, so it is not possible to raise the water level much.
#
# No real surprises here, but it is interesting that pattern recognition survives alongside classification and feature selection. As usual, the only 2 techniques are neural network and support vector machine. It would be interesting perhaps to see what happens if take the fields such as data mining and artificial intelligence out.

# %%
len(nx.connected_component_subgraphs(tech_gr.to_undirected()))
# Out:
# 1

# %%
tech_trimmed = trim_edges(tech_gr,1)
len(tech_trimmed)
gs=nx.connected_component_subgraphs(tech_trimmed)
gs[0].size()
tech_gr.size()
sorted(tech_gr.edges(data=True))
# Out:
# [('abductive networks', 'feature ranking', {'weight': 1}),
#  ('abductive networks', 'feature selection', {'weight': 1}),
#  ('abductive networks', 'learning systems', {'weight': 1}),
#  ('abductive networks', 'mutual information', {'weight': 1}),
#  ('abductive networks', 'prediction', {'weight': 2}),
#  ('abductive networks', 'spectral analysis', {'weight': 2}),
#  ('abstraction', 'classification', {'weight': 1}),
#  ('abstraction', 'feature selection', {'weight': 1}),
#  ('abstraction', 'generalization', {'weight': 1}),
#  ('abstraction', 'inference', {'weight': 1}),
#  ('abstraction', 'multistrategy learning', {'weight': 1}),
#  ('abstraction', 'online learning', {'weight': 1}),
#  ('abstraction', 'optimization', {'weight': 1}),
#  ('abstraction', 'pattern matching', {'weight': 1}),
#  ('active learning', 'adaboost', {'weight': 1}),
#  ('active learning', 'bootstrapping', {'weight': 1}),
#  ('active learning', 'classification', {'weight': 5}),
#  ('active learning', 'ensemble learning', {'weight': 1}),
#  ('active learning', 'gaussian processes', {'weight': 1}),
#  ('active learning', 'graphical models', {'weight': 1}),
#  ('active learning', 'imputation', {'weight': 1}),
#  ('active learning', 'instance-based learning', {'weight': 1}),
#  ('active learning', 'kernel', {'weight': 1}),
#  ('active learning', 'mixture of experts', {'weight': 1}),
#  ('active learning', 'multiclass classification', {'weight': 1}),
#  ('active learning', 'multistrategy learning', {'weight': 1}),
#  ('active learning', 'named entity recognition', {'weight': 2}),
#  ('active learning', 'optimization', {'weight': 2}),
#  ('active learning', 'pattern classification', {'weight': 1}),
#  ('active learning', 'prior knowledge', {'weight': 1}),
#  ('active learning', 'selective sampling', {'weight': 4}),
#  ('active learning', 'semi-supervised learning', {'weight': 2}),
#  ('active learning', 'semisupervised learning', {'weight': 1}),
#  ('active learning', 'supervised learning', {'weight': 1}),
#  ('active learning', 'support vector machine', {'weight': 3}),
#  ('active learning', 'uncertainty', {'weight': 1}),
#  ('adaboost', 'bagging', {'weight': 2}),
#  ('adaboost', 'boosting', {'weight': 1}),
#  ('adaboost', 'c4.5', {'weight': 1}),
#  ('adaboost', 'cart', {'weight': 1}),
#  ('adaboost', 'classification', {'weight': 2}),
#  ('adaboost', 'classifier', {'weight': 1}),
#  ('adaboost', 'computational complexity', {'weight': 2}),
#  ('adaboost', 'ensemble learning', {'weight': 2}),
#  ('adaboost', 'feature selection', {'weight': 1}),
#  ('adaboost', 'information gain', {'weight': 1}),
#  ('adaboost', 'k-means clustering', {'weight': 1}),
#  ('adaboost', 'lda', {'weight': 1}),
#  ('adaboost', 'learning', {'weight': 1}),
#  ('adaboost', 'learning vector quantization', {'weight': 1}),
#  ('adaboost', 'linear discriminant analysis', {'weight': 2}),
#  ('adaboost', 'linear programming', {'weight': 1}),
#  ('adaboost', 'maximum entropy', {'weight': 1}),
#  ('adaboost', 'optimization', {'weight': 1}),
#  ('adaboost', 'random forest', {'weight': 1}),
#  ('adaboost', 'regularization', {'weight': 1}),
#  ('adaboost', 'segmentation', {'weight': 2}),
#  ('adaboost', 'supervised learning', {'weight': 1}),
#  ('adaboost', 'support vector machine', {'weight': 4}),
#  ('adaptive control', 'evolutionary computation', {'weight': 1}),
#  ('adaptive learning', 'cross validation', {'weight': 1}),
#  ('adaptive learning', 'feature selection', {'weight': 1}),
#  ('adaptive learning', 'pattern classification', {'weight': 1}),
#  ('adaptive systems', 'feature selection', {'weight': 1}),
#  ('adaptive systems', 'optimization', {'weight': 1}),
#  ('adaptive systems', 'pattern classification', {'weight': 1}),
#  ('adaptive systems', 'reinforcement learning', {'weight': 1}),
#  ('algorithm selection', 'classification', {'weight': 1}),
#  ('algorithm selection', 'classifiers', {'weight': 1}),
#  ('algorithm selection', 'combinatorial optimization', {'weight': 1}),
#  ('algorithm selection', 'constraint satisfaction', {'weight': 1}),
#  ('algorithm selection', 'meta-learning', {'weight': 1}),
#  ('approximation', 'classification', {'weight': 2}),
#  ('approximation', 'error bounds', {'weight': 1}),
#  ('approximation', 'radial basis functions', {'weight': 1}),
#  ('artificial immune systems', 'backpropagation', {'weight': 1}),
#  ('artificial immune systems', 'classification', {'weight': 2}),
#  ('artificial immune systems', 'classification algorithms', {'weight': 1}),
#  ('artificial immune systems', 'classifier ensembles', {'weight': 1}),
#  ('artificial immune systems', 'data reduction', {'weight': 1}),
#  ('artificial immune systems', 'optimization', {'weight': 3}),
#  ('artificial immune systems', 'rule extraction', {'weight': 2}),
#  ('association rule', 'associative classification', {'weight': 1}),
#  ('association rule', 'fuzzy set', {'weight': 1}),
#  ('association rule', 'kernel function', {'weight': 1}),
#  ('association rule', 'missing value', {'weight': 2}),
#  ('association rule mining', 'clustering', {'weight': 1}),
#  ('association rule mining', 'support vector machine', {'weight': 2}),
#  ('association rules', 'classification', {'weight': 1}),
#  ('association rules', 'classification and regression trees', {'weight': 1}),
#  ('association rules', 'classification rules', {'weight': 1}),
#  ('association rules', 'clustering', {'weight': 2}),
#  ('association rules', 'data clustering', {'weight': 1}),
#  ('association rules', 'feature extraction', {'weight': 1}),
#  ('association rules', 'feature selection', {'weight': 1}),
#  ('association rules', 'loss function', {'weight': 1}),
#  ('association rules', 'missing values', {'weight': 1}),
#  ('association rules', 'particle swarm optimization', {'weight': 1}),
#  ('associative classification', 'clustering', {'weight': 1}),
#  ('associative classification', 'genetic algorithm', {'weight': 1}),
#  ('associative classification', 'simulated annealing', {'weight': 2}),
#  ('associative classification', 'sparsity', {'weight': 1}),
#  ('auc', 'boosting', {'weight': 1}),
#  ('auc', 'bootstrapping', {'weight': 1}),
#  ('auc', 'cross validation', {'weight': 2}),
#  ('auc', 'density estimation', {'weight': 1}),
#  ('auc', 'multivariate statistics', {'weight': 1}),
#  ('auc', 'pruning', {'weight': 1}),
#  ('auc', 'roc', {'weight': 1}),
#  ('auc', 'roc curve', {'weight': 2}),
#  ('auc', 'variable importance', {'weight': 1}),
#  ('automatic classification', 'active learning', {'weight': 1}),
#  ('automatic classification', 'bagging', {'weight': 1}),
#  ('automatic classification', 'boosting', {'weight': 1}),
#  ('automatic classification', 'clustering', {'weight': 1}),
#  ('automatic classification', 'feature selection', {'weight': 2}),
#  ('automatic classification', 'perceptron', {'weight': 1}),
#  ('automatic classification', 'rule induction', {'weight': 1}),
#  ('automatic classification', 'semisupervised learning', {'weight': 1}),
#  ('backpropagation', 'classification', {'weight': 1}),
#  ('backpropagation', 'feature selection', {'weight': 3}),
#  ('backpropagation', 'multi-instance learning', {'weight': 1}),
#  ('bagging', 'adaboost', {'weight': 3}),
#  ('bagging', 'binary classification', {'weight': 1}),
#  ('bagging', 'boosting', {'weight': 17}),
#  ('bagging', 'cart', {'weight': 3}),
#  ('bagging', 'class imbalance', {'weight': 1}),
#  ('bagging', 'classification', {'weight': 3}),
#  ('bagging', 'classification tree', {'weight': 1}),
#  ('bagging', 'decision tree', {'weight': 1}),
#  ('bagging', 'decision tree learning', {'weight': 1}),
#  ('bagging', 'ensemble learning', {'weight': 2}),
#  ('bagging', 'ensembles', {'weight': 3}),
#  ('bagging', 'feature selection', {'weight': 2}),
#  ('bagging', 'generalization', {'weight': 1}),
#  ('bagging', 'genetic algorithm', {'weight': 1}),
#  ('bagging', 'information gain', {'weight': 1}),
#  ('bagging', 'kullback-leibler divergence', {'weight': 1}),
#  ('bagging', 'meta-learning', {'weight': 1}),
#  ('bagging', 'multiple classifier systems', {'weight': 1}),
#  ('bagging', 'nearest neighbor', {'weight': 1}),
#  ('bagging', 'negative correlation learning', {'weight': 1}),
#  ('bagging', 'online learning', {'weight': 1}),
#  ('bagging', 'particle swarm optimization', {'weight': 1}),
#  ('bagging', 'prediction', {'weight': 2}),
#  ('bagging', 'random forest', {'weight': 2}),
#  ('bagging', 'random subspace', {'weight': 2}),
#  ('bagging', 'stacking', {'weight': 1}),
#  ('bagging', 'support vector machine', {'weight': 2}),
#  ('bagging', 'time series', {'weight': 1}),
#  ('bayesian', 'classification', {'weight': 1}),
#  ('bayesian', 'decision tree', {'weight': 3}),
#  ('bayesian', 'ensemble', {'weight': 1}),
#  ('bayesian', 'extreme learning machine', {'weight': 1}),
#  ('bayesian', 'fuzzy logic', {'weight': 1}),
#  ('bayesian', 'gaussian process', {'weight': 1}),
#  ('bayesian', 'multilayer perceptron', {'weight': 1}),
#  ('bayesian', 'radial basis function', {'weight': 1}),
#  ('bayesian', 'random forest', {'weight': 1}),
#  ('bayesian', 'support vector machine', {'weight': 3}),
#  ('bayesian', 'support vector regression', {'weight': 1}),
#  ('bayesian belief networks', 'decision support', {'weight': 1}),
#  ('bayesian belief networks', 'inference', {'weight': 1}),
#  ('bayesian classifier', 'nearest neighbor', {'weight': 2}),
#  ('bayesian classifier', 'neural network', {'weight': 1}),
#  ('bayesian classifier', 'novelty detection', {'weight': 1}),
#  ('bayesian classifier', 'online learning', {'weight': 1}),
#  ('bayesian classifier', 'smoothing', {'weight': 1}),
#  ('bayesian classifier', 'support vector machine', {'weight': 3}),
#  ('bayesian classifiers', 'ensemble methods', {'weight': 1}),
#  ('bayesian classifiers', 'markov chains', {'weight': 1}),
#  ('bayesian inference', 'concept learning', {'weight': 1}),
#  ('bayesian inference', 'gaussian process', {'weight': 1}),
#  ('bayesian inference', 'gaussian processes', {'weight': 1}),
#  ('bayesian inference', 'markov chain monte carlo', {'weight': 2}),
#  ('bayesian inference', 'semisupervised learning', {'weight': 1}),
#  ('bayesian inference', 'smoothing', {'weight': 1}),
#  ('bayesian inference', 'support vector machine', {'weight': 1}),
#  ('bayesian methods', 'classification algorithms', {'weight': 1}),
#  ('bayesian methods', 'graphical model', {'weight': 1}),
#  ('bayesian methods', 'information theory', {'weight': 1}),
#  ('bayesian methods', 'machine learning algorithms', {'weight': 1}),
#  ('bayesian methods', 'markov chain monte carlo', {'weight': 1}),
#  ('bayesian methods', 'similarity measures', {'weight': 1}),
#  ('bayesian network', 'classification', {'weight': 1}),
#  ('bayesian network', 'decision tree', {'weight': 2}),
#  ('bayesian network', 'discriminant analysis', {'weight': 1}),
#  ('bayesian network', 'evolutionary computation', {'weight': 2}),
#  ('bayesian network', 'inference', {'weight': 1}),
#  ('bayesian network', 'logistic regression', {'weight': 1}),
#  ('bayesian network', 'markov blanket', {'weight': 1}),
#  ('bayesian network', 'nearest neighbour', {'weight': 1}),
#  ('bayesian network', 'neural network', {'weight': 1}),
#  ('bayesian network', 'overfitting', {'weight': 1}),
#  ('bayesian network', 'petri nets', {'weight': 1}),
#  ('bayesian network', 'prediction', {'weight': 1}),
#  ('bayesian network', 'similarity measures', {'weight': 1}),
#  ('bayesian network', 'structure learning', {'weight': 2}),
#  ('bayesian network', 'supervised classification', {'weight': 1}),
#  ('bayesian network', 'survival analysis', {'weight': 1}),
#  ('bias', 'concept learning', {'weight': 2}),
#  ('bias', 'convex optimization', {'weight': 1}),
#  ('bias', 'cross-validation', {'weight': 1}),
#  ('bias', 'learning classifier systems', {'weight': 1}),
#  ('bias', 'optimization', {'weight': 1}),
#  ('bias', 'overfitting', {'weight': 1}),
#  ('bias', 'reinforcement learning', {'weight': 1}),
#  ('bias', 'spectral analysis', {'weight': 1}),
#  ('binary classification', 'adaboost', {'weight': 1}),
#  ('binary classification', 'boosting', {'weight': 1}),
#  ('binary classification', 'class imbalance', {'weight': 1}),
#  ('binary classification', 'clustering', {'weight': 1}),
#  ('binary classification', 'discretization', {'weight': 1}),
#  ('binary classification', 'discriminant analysis', {'weight': 1}),
#  ('binary classification', 'feature selection', {'weight': 1}),
#  ('binary classification', 'global optimization', {'weight': 1}),
#  ('binary classification', 'incremental learning', {'weight': 1}),
#  ('binary classification', 'linear programming', {'weight': 1}),
#  ('binary classification', 'neural network', {'weight': 1}),
#  ('binary classification', 'parameter tuning', {'weight': 1}),
#  ('binary classification', 'regularization', {'weight': 1}),
#  ('binary classification', 'statistical machine learning', {'weight': 1}),
#  ('binary classification', 'support vector machine', {'weight': 1}),
#  ('binary classification', 'uncertainty', {'weight': 2}),
#  ('blind signal separation', 'independent component analysis', {'weight': 16}),
#  ('boosting', 'active learning', {'weight': 1}),
#  ('boosting', 'adaboost', {'weight': 9}),
#  ('boosting', 'approximation', {'weight': 1}),
#  ('boosting', 'bagging', {'weight': 7}),
#  ('boosting', 'c4.5', {'weight': 1}),
#  ('boosting', 'cart', {'weight': 2}),
#  ('boosting', 'class imbalance', {'weight': 1}),
#  ('boosting', 'classification', {'weight': 12}),
#  ('boosting', 'classification rules', {'weight': 1}),
#  ('boosting', 'classification tree', {'weight': 1}),
#  ('boosting', 'clustering', {'weight': 1}),
#  ('boosting', 'co-training', {'weight': 2}),
#  ('boosting', 'conditional random field', {'weight': 1}),
#  ('boosting', 'conditional random fields', {'weight': 1}),
#  ('boosting', 'convex optimization', {'weight': 1}),
#  ('boosting', 'decision tree', {'weight': 1}),
#  ('boosting', 'decision tree learning', {'weight': 1}),
#  ('boosting', 'density estimation', {'weight': 1}),
#  ('boosting', 'dynamic time warping', {'weight': 1}),
#  ('boosting', 'ensemble learning', {'weight': 2}),
#  ('boosting', 'ensemble methods', {'weight': 3}),
#  ('boosting', 'ensembles', {'weight': 3}),
#  ('boosting', 'feature selection', {'weight': 2}),
#  ('boosting', 'fuzzy logic', {'weight': 1}),
#  ('boosting', 'generalization', {'weight': 1}),
#  ('boosting', 'genetic algorithm', {'weight': 1}),
#  ('boosting', 'kernel machines', {'weight': 1}),
#  ('boosting', 'lasso', {'weight': 2}),
#  ('boosting', 'learning', {'weight': 1}),
#  ('boosting', 'linear discriminant analysis', {'weight': 1}),
#  ('boosting', 'linear programming', {'weight': 2}),
#  ('boosting', 'logistic regression', {'weight': 3}),
#  ('boosting', 'multiple classifier systems', {'weight': 1}),
#  ('boosting', 'negative correlation learning', {'weight': 1}),
#  ('boosting', 'neural network', {'weight': 2}),
#  ('boosting', 'optimization', {'weight': 1}),
#  ('boosting', 'prediction', {'weight': 2}),
#  ('boosting', 'radial basis functions', {'weight': 1}),
#  ('boosting', 'random forest', {'weight': 2}),
#  ('boosting', 'random subspace', {'weight': 1}),
#  ('boosting', 'regression', {'weight': 3}),
#  ('boosting', 'roc', {'weight': 1}),
#  ('boosting', 'selective sampling', {'weight': 1}),
#  ('boosting', 'semi-supervised learning', {'weight': 2}),
#  ('boosting', 'smoothing', {'weight': 1}),
#  ('boosting', 'stacking', {'weight': 1}),
#  ('boosting', 'statistical inference', {'weight': 1}),
#  ('boosting', 'statistical machine learning', {'weight': 1}),
#  ('boosting', 'support vector machine', {'weight': 4}),
#  ('boosting', 'survival analysis', {'weight': 1}),
#  ('boosting', 'uncertainty', {'weight': 1}),
#  ('boosting', 'unlabeled data', {'weight': 1}),
#  ('boosting', 'variable selection', {'weight': 1}),
#  ('bootstrap', 'data compression', {'weight': 1}),
#  ('bootstrap', 'ensemble classifiers', {'weight': 1}),
#  ('bootstrap', 'feature selection', {'weight': 1}),
#  ('bootstrapping', 'cross validation', {'weight': 1}),
#  ('bootstrapping', 'cross-validation', {'weight': 1}),
#  ('bootstrapping', 'expectation maximization', {'weight': 1}),
#  ('bootstrapping', 'machine learning classifiers', {'weight': 1}),
#  ('bootstrapping', 'semi-supervised learning', {'weight': 1}),
#  ('bootstrapping', 'unlabeled data', {'weight': 1}),
#  ('c4.5', 'backpropagation', {'weight': 1}),
#  ('c4.5', 'cart', {'weight': 1}),
#  ('c4.5', 'decision tree', {'weight': 2}),
#  ('c4.5', 'discretization', {'weight': 1}),
#  ('c4.5', 'feature selection', {'weight': 2}),
#  ('c4.5', 'fuzzy c-means', {'weight': 1}),
#  ('c4.5', 'fuzzy decision tree', {'weight': 1}),
#  ('c4.5', 'genetic algorithm', {'weight': 1}),
#  ('c4.5', 'k-means', {'weight': 1}),
#  ('c4.5', 'machine learning algorithms', {'weight': 1}),
#  ('c4.5', 'optimization', {'weight': 1}),
#  ('c5.0', 'self-organizing map', {'weight': 2}),
#  ('c5.0', 'spectral analysis', {'weight': 1}),
#  ('cart', 'boosting', {'weight': 1}),
#  ('cart', 'ensemble methods', {'weight': 1}),
#  ('cart', 'ensembles', {'weight': 1}),
#  ('cart', 'features', {'weight': 1}),
#  ('cart', 'random forest', {'weight': 1}),
#  ('cart', 'roc curve', {'weight': 1}),
#  ('cart', 'sampling', {'weight': 1}),
#  ('case-based reasoning', 'association rule', {'weight': 1}),
#  ('case-based reasoning', 'automatic classification', {'weight': 1}),
#  ('case-based reasoning', 'classification', {'weight': 1}),
#  ('case-based reasoning', 'classifier systems', {'weight': 1}),
#  ('case-based reasoning', 'clustering', {'weight': 1}),
#  ('case-based reasoning', 'collaborative filtering', {'weight': 1}),
#  ('case-based reasoning', 'conceptual clustering', {'weight': 1}),
#  ('case-based reasoning', 'decision tree', {'weight': 1}),
#  ('case-based reasoning', 'decision tree induction', {'weight': 1}),
#  ('case-based reasoning', 'dynamic time warping', {'weight': 1}),
#  ('case-based reasoning', 'explanation', {'weight': 2}),
#  ('case-based reasoning', 'feature weighting', {'weight': 4}),
#  ('case-based reasoning', 'fuzzy logic', {'weight': 2}),
#  ('case-based reasoning', 'genetic algorithm', {'weight': 1}),
#  ('case-based reasoning', 'genetic programming', {'weight': 1}),
#  ('case-based reasoning', 'indexing', {'weight': 1}),
#  ('case-based reasoning', 'information filtering', {'weight': 1}),
#  ('case-based reasoning', 'instance selection', {'weight': 1}),
#  ('case-based reasoning', 'k-nearest neighbors', {'weight': 1}),
#  ('case-based reasoning', 'lazy learning', {'weight': 3}),
#  ('case-based reasoning', 'learning', {'weight': 1}),
#  ('case-based reasoning', 'missing value', {'weight': 1}),
#  ('case-based reasoning', 'neural network', {'weight': 1}),
#  ('case-based reasoning', 'optimization', {'weight': 1}),
#  ('case-based reasoning', 'ranking', {'weight': 1}),
#  ('case-based reasoning', 'reinforcement learning', {'weight': 1}),
#  ('case-based reasoning', 'rule induction', {'weight': 3}),
#  ('case-based reasoning', 'sensitivity', {'weight': 1}),
#  ('case-based reasoning', 'similarity measure', {'weight': 1}),
#  ('case-based reasoning', 'simulated annealing', {'weight': 1}),
#  ('categorization', 'classification', {'weight': 2}),
#  ('categorization', 'classifier', {'weight': 1}),
#  ('categorization', 'discretization', {'weight': 1}),
#  ('categorization', 'hidden markov models', {'weight': 1}),
#  ('categorization', 'learning', {'weight': 1}),
#  ('categorization', 'uncertainty', {'weight': 1}),
#  ('class imbalance', 'binary classification', {'weight': 1}),
#  ('class imbalance', 'classification', {'weight': 2}),
#  ('class imbalance', 'clustering', {'weight': 1}),
#  ('class imbalance', 'genetic algorithm', {'weight': 1}),
#  ('class imbalance', 'kernel principal component analysis', {'weight': 1}),
#  ('class imbalance', 'scoring', {'weight': 1}),
#  ('classification', 'active learning', {'weight': 1}),
#  ('classification', 'adaboost', {'weight': 2}),
#  ('classification', 'approximation', {'weight': 1}),
#  ('classification', 'association rule', {'weight': 1}),
#  ('classification', 'association rule mining', {'weight': 1}),
#  ('classification', 'association rules', {'weight': 6}),
#  ('classification', 'associative classification', {'weight': 1}),
#  ('classification', 'auc', {'weight': 1}),
#  ('classification', 'backpropagation', {'weight': 1}),
#  ('classification', 'bagging', {'weight': 1}),
#  ('classification', 'bayesian', {'weight': 1}),
#  ('classification', 'bayesian classifier', {'weight': 1}),
#  ('classification', 'bayesian methods', {'weight': 2}),
#  ('classification', 'bayesian network', {'weight': 3}),
#  ('classification', 'bias', {'weight': 1}),
#  ('classification', 'binary classification', {'weight': 2}),
#  ('classification', 'boosting', {'weight': 9}),
#  ('classification', 'c4.5', {'weight': 3}),
#  ('classification', 'cart', {'weight': 1}),
#  ('classification', 'categorization', {'weight': 4}),
#  ('classification', 'class imbalance', {'weight': 4}),
#  ('classification', 'classification accuracy', {'weight': 1}),
#  ('classification', 'classification rules', {'weight': 1}),
#  ('classification', 'classification tree', {'weight': 2}),
#  ('classification', 'classifier', {'weight': 3}),
#  ('classification', 'classifier ensembles', {'weight': 1}),
#  ('classification', 'classifier fusion', {'weight': 2}),
#  ('classification', 'cluster analysis', {'weight': 3}),
#  ('classification', 'clustering', {'weight': 23}),
#  ('classification', 'clustering analysis', {'weight': 1}),
#  ('classification', 'combinatorial optimization', {'weight': 1}),
#  ('classification', 'concept drift', {'weight': 2}),
#  ('classification', 'conceptual clustering', {'weight': 1}),
#  ('classification', 'constraint satisfaction', {'weight': 1}),
#  ('classification', 'constructive induction', {'weight': 1}),
#  ('classification', 'correlation', {'weight': 2}),
#  ('classification', 'cost-sensitive learning', {'weight': 4}),
#  ('classification', 'cross validation', {'weight': 2}),
#  ('classification', 'cross-validation', {'weight': 5}),
#  ('classification', 'curse of dimensionality', {'weight': 1}),
#  ('classification', 'data clustering', {'weight': 1}),
#  ('classification', 'data reduction', {'weight': 4}),
#  ('classification', 'decision rules', {'weight': 3}),
#  ('classification', 'decision support', {'weight': 3}),
#  ('classification', 'decision tree', {'weight': 19}),
#  ('classification', 'decision tree learning', {'weight': 1}),
#  ('classification', 'denoising', {'weight': 1}),
#  ('classification', 'dimension reduction', {'weight': 1}),
#  ('classification', 'dimensionality reduction', {'weight': 3}),
#  ('classification', 'discretization', {'weight': 3}),
#  ('classification', 'discriminant analysis', {'weight': 3}),
#  ('classification', 'discrimination', {'weight': 3}),
#  ('classification', 'ensemble', {'weight': 3}),
#  ('classification', 'ensemble classifier', {'weight': 1}),
#  ('classification', 'ensemble classifiers', {'weight': 3}),
#  ('classification', 'ensemble learning', {'weight': 2}),
#  ('classification', 'ensemble methods', {'weight': 4}),
#  ('classification', 'ensembles', {'weight': 4}),
#  ('classification', 'ensembles of classifiers', {'weight': 3}),
#  ('classification', 'evolutionary computation', {'weight': 1}),
#  ('classification', 'evolutionary programming', {'weight': 2}),
#  ('classification', 'explanation', {'weight': 2}),
#  ('classification', 'extreme learning machine', {'weight': 1}),
#  ('classification', 'feature construction', {'weight': 2}),
#  ('classification', 'feature extraction', {'weight': 10}),
#  ('classification', 'feature ranking', {'weight': 1}),
#  ('classification', 'feature selection', {'weight': 30}),
#  ('classification', 'feature subset selection', {'weight': 1}),
#  ('classification', 'feature weighting', {'weight': 1}),
#  ('classification', 'function approximation', {'weight': 1}),
#  ('classification', 'fuzzy c-means', {'weight': 1}),
#  ('classification', 'fuzzy decision tree', {'weight': 1}),
#  ('classification', 'fuzzy set theory', {'weight': 2}),
#  ('classification', 'fuzzy sets', {'weight': 1}),
#  ('classification', 'gaussian mixture model', {'weight': 1}),
#  ('classification', 'generalization', {'weight': 2}),
#  ('classification', 'generalization error', {'weight': 1}),
#  ('classification', 'genetic algorithm', {'weight': 7}),
#  ('classification', 'genetic fuzzy systems', {'weight': 1}),
#  ('classification', 'genetic programming', {'weight': 5}),
#  ('classification', 'genetics-based machine learning', {'weight': 2}),
#  ('classification', 'graph matching', {'weight': 1}),
#  ('classification', 'graph theory', {'weight': 1}),
#  ('classification', 'heuristic search', {'weight': 1}),
#  ('classification', 'hierarchical clustering', {'weight': 1}),
#  ('classification', 'high-dimensional data', {'weight': 1}),
#  ('classification', 'incremental learning', {'weight': 3}),
#  ('classification', 'inductive learning', {'weight': 2}),
#  ('classification', 'inductive logic programming', {'weight': 2}),
#  ('classification', 'information gain', {'weight': 1}),
#  ('classification', 'information theory', {'weight': 3}),
#  ('classification', 'instance-based learning', {'weight': 4}),
#  ('classification', 'k-means', {'weight': 1}),
#  ('classification', 'k-means algorithm', {'weight': 1}),
#  ('classification', 'k-means clustering', {'weight': 1}),
#  ('classification', 'kernel', {'weight': 2}),
#  ('classification', 'kernel function', {'weight': 1}),
#  ('classification', 'kernel machines', {'weight': 2}),
#  ('classification', 'kernel principal component analysis', {'weight': 1}),
#  ('classification', 'knn', {'weight': 1}),
#  ('classification', 'kullback-leibler divergence', {'weight': 2}),
#  ('classification', 'lasso', {'weight': 3}),
#  ('classification', 'lazy learning', {'weight': 1}),
#  ('classification', 'lda', {'weight': 3}),
#  ('classification', 'learning', {'weight': 3}),
#  ('classification', 'learning algorithm', {'weight': 1}),
#  ('classification', 'learning algorithms', {'weight': 2}),
#  ('classification', 'learning classifier system', {'weight': 2}),
#  ('classification', 'learning classifier systems', {'weight': 1}),
#  ('classification', 'linear discriminant analysis', {'weight': 4}),
#  ('classification', 'linear programming', {'weight': 2}),
#  ('classification', 'locally linear embedding', {'weight': 2}),
#  ('classification', 'logistic regression', {'weight': 5}),
#  ('classification', 'machine learning algorithm', {'weight': 1}),
#  ('classification', 'machine-learning', {'weight': 4}),
#  ('classification', 'markov blanket', {'weight': 1}),
#  ('classification', 'meta-learning', {'weight': 1}),
#  ('classification', 'missing data', {'weight': 1}),
#  ('classification', 'missing values', {'weight': 1}),
#  ('classification', 'mixture models', {'weight': 1}),
#  ('classification', 'modelling', {'weight': 1}),
#  ('classification', 'multiclass', {'weight': 1}),
#  ('classification', 'multidimensional scaling', {'weight': 1}),
#  ('classification', 'multilayer perceptron', {'weight': 2}),
#  ('classification', 'multiple classifier systems', {'weight': 1}),
#  ('classification', 'naive bayes classifier', {'weight': 2}),
#  ('classification', 'named entity recognition', {'weight': 1}),
#  ('classification', 'nearest neighbor', {'weight': 3}),
#  ('classification', 'nearest neighbour', {'weight': 1}),
#  ('classification', 'neural nets', {'weight': 2}),
#  ('classification', 'neural network', {'weight': 10}),
#  ('classification', 'neuro-fuzzy systems', {'weight': 1}),
#  ('classification', 'nonparametric regression', {'weight': 1}),
#  ('classification', 'on-line learning', {'weight': 1}),
#  ('classification', 'one-class classification', {'weight': 1}),
#  ('classification', 'optimisation', {'weight': 1}),
#  ('classification', 'optimization', {'weight': 11}),
#  ('classification', 'pac learning', {'weight': 1}),
#  ('classification', 'parameter estimation', {'weight': 1}),
#  ('classification', 'parameter tuning', {'weight': 1}),
#  ('classification', 'particle swarm optimization', {'weight': 4}),
#  ('classification', 'pattern analysis', {'weight': 1}),
#  ('classification', 'pattern discovery', {'weight': 1}),
#  ('classification', 'patterns', {'weight': 3}),
#  ('classification', 'perceptron', {'weight': 1}),
#  ('classification', 'prediction', {'weight': 11}),
#  ('classification', 'predictive model', {'weight': 1}),
#  ('classification', 'prior knowledge', {'weight': 2}),
#  ('classification', 'probabilistic algorithms', {'weight': 1}),
#  ('classification', 'probabilistic graphical models', {'weight': 1}),
#  ('classification', 'pruning', {'weight': 2}),
#  ('classification', 'r', {'weight': 1}),
#  ('classification', 'radial basis function neural networks', {'weight': 1}),
#  ('classification', 'random forest', {'weight': 4}),
#  ('classification', 'ranking', {'weight': 2}),
#  ('classification', 'recognition', {'weight': 1}),
#  ('classification', 'regression', {'weight': 24}),
#  ('classification', 'regularization', {'weight': 4}),
#  ('classification', 'reproducing kernel hilbert space', {'weight': 1}),
#  ('classification', 'reproducing kernel hilbert spaces', {'weight': 2}),
#  ('classification', 'roc', {'weight': 3}),
#  ('classification', 'roc analysis', {'weight': 2}),
#  ('classification', 'roc curves', {'weight': 2}),
#  ('classification', 'rough set', {'weight': 5}),
#  ('classification', 'rough set theory', {'weight': 1}),
#  ('classification', 'rule extraction', {'weight': 1}),
#  ('classification', 'rule induction', {'weight': 8}),
#  ('classification', 'rule learning', {'weight': 2}),
#  ('classification', 'rule-based systems', {'weight': 1}),
#  ('classification', 'sampling', {'weight': 4}),
#  ('classification', 'segmentation', {'weight': 3}),
#  ('classification', 'selective sampling', {'weight': 1}),
#  ('classification', 'semi-supervised learning', {'weight': 5}),
#  ('classification', 'semidefinite programming', {'weight': 1}),
#  ('classification', 'semisupervised learning', {'weight': 1}),
#  ('classification', 'sensitivity', {'weight': 3}),
#  ('classification', 'singular value decomposition', {'weight': 1}),
#  ('classification', 'sparsity', {'weight': 2}),
#  ('classification', 'stacking', {'weight': 3}),
#  ('classification', 'statistical inference', {'weight': 2}),
#  ('classification', 'statistical learning', {'weight': 1}),
#  ('classification', 'statistical learning theory', {'weight': 1}),
#  ('classification', 'structural risk minimization', {'weight': 3}),
#  ('classification', 'structure learning', {'weight': 2}),
#  ('classification', 'supervised learning', {'weight': 4}),
#  ('classification', 'support vector machine', {'weight': 44}),
#  ('classification', 'time series', {'weight': 1}),
#  ('classification', 'time series analysis', {'weight': 1}),
#  ('classification', 'time series forecasting', {'weight': 1}),
#  ('classification', 'time series prediction', {'weight': 1}),
#  ('classification', 'training', {'weight': 2}),
#  ('classification', 'transduction', {'weight': 1}),
#  ('classification', 'uncertainty', {'weight': 2}),
#  ('classification', 'unlabeled data', {'weight': 1}),
#  ('classification', 'unsupervised learning', {'weight': 2}),
#  ('classification', 'variable importance', {'weight': 1}),
#  ('classification', 'variable selection', {'weight': 4}),
#  ('classification', 'visualization', {'weight': 6}),
#  ('classification', 'wavelet transform', {'weight': 1}),
#  ('classification', 'wavelets', {'weight': 1}),
#  ('classification accuracy', 'classifier', {'weight': 1}),
#  ('classification accuracy', 'cross-validation', {'weight': 1}),
#  ('classification accuracy', 'lda', {'weight': 1}),
#  ('classification accuracy', 'roc curves', {'weight': 1}),
#  ('classification algorithm', 'ensemble', {'weight': 1}),
#  ('classification algorithm', 'inductive learning', {'weight': 1}),
#  ('classification algorithm', 'information gain', {'weight': 1}),
#  ('classification algorithm', 'neural network', {'weight': 1}),
#  ('classification algorithm', 'roc', {'weight': 1}),
#  ('classification algorithm', 'rule extraction', {'weight': 1}),
#  ('classification algorithms', 'boosting', {'weight': 1}),
#  ('classification algorithms', 'data preprocessing', {'weight': 1}),
#  ('classification algorithms', 'ensemble classifiers', {'weight': 1}),
#  ('classification algorithms', 'feature selection', {'weight': 1}),
#  ('classification algorithms', 'machine learning algorithms', {'weight': 2}),
#  ('classification and regression trees', 'auc', {'weight': 1}),
#  ('classification and regression trees', 'classification', {'weight': 1}),
#  ('classification and regression trees', 'clustering', {'weight': 1}),
#  ('classification and regression trees', 'genetic programming', {'weight': 1}),
#  ('classification and regression trees', 'nearest neighbor', {'weight': 1}),
#  ('classification and regression trees', 'random forest', {'weight': 1}),
#  ('classification and regression trees',
#   'support vector regression',
#   {'weight': 1}),
#  ('classification rules', 'generalization', {'weight': 1}),
#  ('classification rules', 'prediction', {'weight': 1}),
#  ('classification rules', 'pruning', {'weight': 1}),
#  ('classification rules', 'rough set theory', {'weight': 1}),
#  ('classification tree', 'bootstrap', {'weight': 1}),
#  ('classification tree', 'cart', {'weight': 1}),
#  ('classification tree', 'cross validation', {'weight': 1}),
#  ('classification tree', 'discriminant analysis', {'weight': 1}),
#  ('classification tree', 'logistic regression', {'weight': 4}),
#  ('classification tree', 'neural net', {'weight': 1}),
#  ('classification tree', 'prediction error', {'weight': 1}),
#  ('classification tree', 'random forest', {'weight': 1}),
#  ('classification tree', 'support vector machine', {'weight': 1}),
#  ('classification tree', 'variable importance', {'weight': 1}),
#  ('classifier', 'algorithm selection', {'weight': 1}),
#  ('classifier', 'c4.5', {'weight': 1}),
#  ('classifier', 'clustering', {'weight': 1}),
#  ('classifier', 'conformal prediction', {'weight': 1}),
#  ('classifier', 'cross-validation', {'weight': 1}),
#  ('classifier', 'decision table', {'weight': 1}),
#  ('classifier', 'dimensionality reduction', {'weight': 1}),
#  ('classifier', 'feature extraction', {'weight': 1}),
#  ('classifier', 'feature selection', {'weight': 2}),
#  ('classifier', 'fuzzy c-means', {'weight': 1}),
#  ('classifier', 'generalization error', {'weight': 1}),
#  ('classifier', 'genetic algorithm', {'weight': 1}),
#  ('classifier', 'graph theory', {'weight': 1}),
#  ('classifier', 'high-dimensional data', {'weight': 1}),
#  ('classifier', 'independent component analysis', {'weight': 1}),
#  ('classifier', 'information theory', {'weight': 1}),
#  ('classifier', 'k-means', {'weight': 1}),
#  ('classifier', 'multilayer perceptron', {'weight': 1}),
#  ('classifier', 'optimization', {'weight': 1}),
#  ('classifier', 'random forest', {'weight': 1}),
#  ('classifier', 'regression', {'weight': 1}),
#  ('classifier', 'relevance vector machine', {'weight': 1}),
#  ('classifier', 'rough set', {'weight': 1}),
#  ('classifier', 'sampling', {'weight': 1}),
#  ('classifier', 'self-organizing map', {'weight': 1}),
#  ('classifier', 'support vector machine', {'weight': 5}),
#  ('classifier combination', 'adaboost', {'weight': 1}),
#  ('classifier combination', 'classifier', {'weight': 1}),
#  ('classifier combination', 'feature selection', {'weight': 1}),
#  ('classifier combination', 'information theory', {'weight': 2}),
#  ('classifier combination', 'mutual information', {'weight': 2}),
#  ('classifier combination', 'pattern classification', {'weight': 1}),
#  ('classifier design and evaluation', 'clustering', {'weight': 1}),
#  ('classifier design and evaluation',
#   'feature evaluation and selection',
#   {'weight': 3}),
#  ('classifier design and evaluation', 'feature extraction', {'weight': 1}),
#  ('classifier design and evaluation', 'pattern analysis', {'weight': 1}),
#  ('classifier design and evaluation', 'similarity measures', {'weight': 1}),
#  ('classifier ensemble', 'feature extraction', {'weight': 1}),
#  ('classifier ensemble', 'linear programming', {'weight': 1}),
#  ('classifier ensembles', 'boosting', {'weight': 1}),
#  ('classifier ensembles', 'classification', {'weight': 2}),
#  ('classifier ensembles', 'decision support systems', {'weight': 1}),
#  ('classifier ensembles', 'online learning', {'weight': 1}),
#  ('classifier ensembles', 'random subspace', {'weight': 1}),
#  ('classifier ensembles', 'stacking', {'weight': 1}),
#  ('classifier ensembles', 'supervised machine learning', {'weight': 1}),
#  ('classifier fusion', 'classification', {'weight': 1}),
#  ('classifier fusion', 'classifier ensembles', {'weight': 1}),
#  ('classifier fusion', 'incremental learning', {'weight': 2}),
#  ('classifier fusion', 'machine-learning', {'weight': 1}),
#  ('classifier fusion', 'stacking', {'weight': 1}),
#  ('classifier systems', 'automatic classification', {'weight': 1}),
#  ('classifier systems', 'classification', {'weight': 1}),
#  ('classifier systems', 'generalization', {'weight': 1}),
#  ('classifier systems', 'genetic programming', {'weight': 2}),
#  ('classifier systems', 'petri nets', {'weight': 1}),
#  ('classifier systems', 'reinforcement learning', {'weight': 1}),
#  ('classifiers', 'association rules', {'weight': 1}),
#  ('classifiers', 'auc', {'weight': 1}),
#  ('classifiers', 'discretization', {'weight': 1}),
#  ('classifiers', 'ensemble', {'weight': 1}),
#  ('classifiers', 'knn', {'weight': 1}),
#  ('classifiers', 'learning algorithms', {'weight': 2}),
#  ('classifiers', 'logistic regression', {'weight': 1}),
#  ('classifiers', 'neural net', {'weight': 1}),
#  ('classifiers', 'roc curves', {'weight': 2}),
#  ('classifiers', 'rule-based systems', {'weight': 1}),
#  ('classifiers', 'support vector machine', {'weight': 1}),
#  ('classifiers', 'visualization', {'weight': 1}),
#  ('cluster analysis', 'classification', {'weight': 4}),
#  ('cluster analysis', 'classification accuracy', {'weight': 1}),
#  ('cluster analysis', 'cross-validation', {'weight': 1}),
#  ('cluster analysis', 'data reduction', {'weight': 1}),
#  ('cluster analysis', 'denoising', {'weight': 1}),
#  ('cluster analysis', 'feature selection', {'weight': 1}),
#  ('cluster analysis', 'k-means', {'weight': 1}),
#  ('cluster analysis', 'lasso', {'weight': 1}),
#  ('cluster analysis', 'logistic regression', {'weight': 1}),
#  ('cluster analysis', 'multi-objective optimization', {'weight': 1}),
#  ('cluster analysis', 'ridge regression', {'weight': 1}),
#  ('cluster analysis', 'self-organizing map', {'weight': 1}),
#  ('cluster analysis', 'support vector machine', {'weight': 2}),
#  ('clustering', 'association rules', {'weight': 2}),
#  ('clustering', 'associative classification', {'weight': 1}),
#  ('clustering', 'categorization', {'weight': 2}),
#  ('clustering', 'classification', {'weight': 20}),
#  ('clustering', 'clustering algorithm', {'weight': 1}),
#  ('clustering', 'constructive induction', {'weight': 1}),
#  ('clustering', 'data fusion', {'weight': 1}),
#  ('clustering', 'decision support systems', {'weight': 1}),
#  ('clustering', 'decision tree', {'weight': 2}),
#  ('clustering', 'density estimation', {'weight': 1}),
#  ('clustering', 'differential evolution', {'weight': 1}),
#  ('clustering', 'dimension reduction', {'weight': 1}),
#  ('clustering', 'dimensionality reduction', {'weight': 1}),
#  ('clustering', 'discriminant analysis', {'weight': 1}),
#  ('clustering', 'ensemble learning', {'weight': 1}),
#  ('clustering', 'expectation maximization', {'weight': 1}),
#  ('clustering', 'expectation-maximization', {'weight': 1}),
#  ('clustering', 'feature extraction', {'weight': 2}),
#  ('clustering', 'feature ranking', {'weight': 1}),
#  ('clustering', 'feature selection', {'weight': 9}),
#  ('clustering', 'features', {'weight': 1}),
#  ('clustering', 'function approximation', {'weight': 1}),
#  ('clustering', 'fuzzy c-means', {'weight': 2}),
#  ('clustering', 'fuzzy rules', {'weight': 1}),
#  ('clustering', 'generalization', {'weight': 1}),
#  ('clustering', 'genetic programming', {'weight': 2}),
#  ('clustering', 'hidden markov model', {'weight': 1}),
#  ('clustering', 'hidden markov models', {'weight': 2}),
#  ('clustering', 'hierarchical classification', {'weight': 1}),
#  ('clustering', 'hierarchical clustering', {'weight': 1}),
#  ('clustering', 'inductive learning', {'weight': 1}),
#  ('clustering', 'inductive machine learning', {'weight': 1}),
#  ('clustering', 'information filtering', {'weight': 1}),
#  ('clustering', 'information theory', {'weight': 3}),
#  ('clustering', 'k-mean', {'weight': 1}),
#  ('clustering', 'k-means', {'weight': 9}),
#  ('clustering', 'k-means algorithm', {'weight': 4}),
#  ('clustering', 'k-means clustering', {'weight': 2}),
#  ('clustering', 'kernel method', {'weight': 1}),
#  ('clustering', 'knn', {'weight': 1}),
#  ('clustering', 'kullback-leibler divergence', {'weight': 1}),
#  ('clustering', 'linear programming', {'weight': 1}),
#  ('clustering', 'mixture models', {'weight': 1}),
#  ('clustering', 'multivariate statistics', {'weight': 1}),
#  ('clustering', 'neural network', {'weight': 2}),
#  ('clustering', 'neuro-fuzzy systems', {'weight': 2}),
#  ('clustering', 'optimisation', {'weight': 3}),
#  ('clustering', 'optimization', {'weight': 5}),
#  ('clustering', 'outlier detection', {'weight': 1}),
#  ('clustering', 'pattern analysis', {'weight': 2}),
#  ('clustering', 'pattern discovery', {'weight': 1}),
#  ('clustering', 'probabilistic algorithms', {'weight': 1}),
#  ('clustering', 'probabilistic graphical models', {'weight': 3}),
#  ('clustering', 'regularization', {'weight': 2}),
#  ('clustering', 'rough set', {'weight': 1}),
#  ('clustering', 'rule extraction', {'weight': 1}),
#  ('clustering', 'rule generation', {'weight': 1}),
#  ('clustering', 'rule induction', {'weight': 1}),
#  ('clustering', 'sampling', {'weight': 1}),
#  ('clustering', 'scalability', {'weight': 1}),
#  ('clustering', 'selective sampling', {'weight': 1}),
#  ('clustering', 'self-organizing map', {'weight': 1}),
#  ('clustering', 'semi-supervised learning', {'weight': 1}),
#  ('clustering', 'semisupervised learning', {'weight': 2}),
#  ('clustering', 'sensitivity', {'weight': 1}),
#  ('clustering', 'similarity measures', {'weight': 1}),
#  ('clustering', 'singular value decomposition', {'weight': 1}),
#  ('clustering', 'som', {'weight': 1}),
#  ('clustering', 'spectral clustering', {'weight': 1}),
#  ('clustering', 'statistical inference', {'weight': 4}),
#  ('clustering', 'statistical machine learning', {'weight': 1}),
#  ('clustering', 'supervised learning', {'weight': 2}),
#  ('clustering', 'supervised machine learning', {'weight': 1}),
#  ('clustering', 'support vector machine', {'weight': 1}),
#  ('clustering', 'symbolic regression', {'weight': 1}),
#  ('clustering', 'time series', {'weight': 2}),
#  ('clustering', 'time series analysis', {'weight': 2}),
#  ('clustering', 'uncertainty', {'weight': 1}),
#  ('clustering', 'unsupervised learning', {'weight': 5}),
#  ('clustering', 'wavelet', {'weight': 1}),
#  ('clustering algorithm', 'incremental learning', {'weight': 2}),
#  ('clustering algorithm', 'neural network', {'weight': 1}),
#  ('clustering algorithm', 'unsupervised learning', {'weight': 1}),
#  ('clustering algorithms', 'decision support systems', {'weight': 1}),
#  ('clustering algorithms', 'dynamic programming', {'weight': 1}),
#  ('clustering algorithms', 'hidden markov models', {'weight': 1}),
#  ('clustering algorithms', 'k-means', {'weight': 1}),
#  ('clustering algorithms', 'similarity measures', {'weight': 1}),
#  ('clustering analysis', 'decision support systems', {'weight': 1}),
#  ('clustering analysis', 'feature selection', {'weight': 1}),
#  ('clustering analysis', 'k-means algorithm', {'weight': 1}),
#  ('clustering analysis', 'particle swarm optimization', {'weight': 2}),
#  ('clustering analysis', 'self-organizing map', {'weight': 1}),
#  ('co-training', 'boosting', {'weight': 1}),
#  ('co-training', 'class imbalance', {'weight': 1}),
#  ('co-training', 'classification', {'weight': 2}),
#  ('co-training', 'classifier', {'weight': 1}),
#  ('co-training', 'ensemble learning', {'weight': 2}),
#  ('co-training', 'random forest', {'weight': 1}),
#  ('co-training', 'semi-supervised learning', {'weight': 5}),
#  ('co-training', 'semisupervised learning', {'weight': 1}),
#  ('co-training', 'support vector machine', {'weight': 1}),
#  ('co-training', 'unlabeled data', {'weight': 1}),
#  ('collaborative filtering', 'bayesian inference', {'weight': 1}),
#  ('collaborative filtering', 'case-based reasoning', {'weight': 1}),
#  ('collaborative filtering', 'collaborative filtering', {'weight': 1}),
#  ('collaborative filtering', 'cross-validation', {'weight': 1}),
#  ('collaborative filtering', 'ensemble methods', {'weight': 1}),
#  ('collaborative filtering', 'gradient descent', {'weight': 1}),
#  ('collaborative filtering', 'learning classifier systems', {'weight': 1}),
#  ('collaborative filtering', 'machine learning classifiers', {'weight': 1}),
#  ('collaborative filtering', 'mixture models', {'weight': 1}),
#  ('collaborative filtering', 'naive bayes classifier', {'weight': 1}),
#  ('collaborative filtering', 'ordinal regression', {'weight': 1}),
#  ('collaborative filtering', 'prediction error', {'weight': 1}),
#  ('collaborative filtering', 'ranking', {'weight': 2}),
#  ('collaborative filtering', 'self-organizing map', {'weight': 1}),
#  ('collaborative filtering', 'singular value decomposition', {'weight': 1}),
#  ('combinatorial optimization', 'algorithm selection', {'weight': 1}),
#  ('combinatorial optimization', 'constraint satisfaction', {'weight': 1}),
#  ('combinatorial optimization', 'dynamic programming', {'weight': 2}),
#  ('combinatorial optimization', 'fuzzy logic', {'weight': 1}),
#  ('combinatorial optimization', 'markov chains', {'weight': 1}),
#  ('combinatorial optimization', 'statistics', {'weight': 1}),
#  ('combinatorial optimization', 'supervised learning', {'weight': 1}),
#  ('combinatorial optimization', 'support vector machine', {'weight': 1}),
#  ('computational complexity', 'computational learning theory', {'weight': 1}),
#  ('computational complexity', 'logistic regression', {'weight': 1}),
#  ('computational complexity', 'ridge regression', {'weight': 1}),
#  ('computational complexity', 'sparsity', {'weight': 1}),
#  ('computational learning theory', 'classification', {'weight': 1}),
#  ('computational learning theory', 'computational complexity', {'weight': 1}),
#  ('computational learning theory', 'convex optimization', {'weight': 1}),
#  ('computational learning theory', 'online learning', {'weight': 2}),
#  ('computational learning theory', 'pac learning', {'weight': 1}),
#  ('computational learning theory', 'regression analysis', {'weight': 1}),
#  ('computational learning theory',
#   'structural risk minimization',
#   {'weight': 1}),
#  ('concept drift', 'active learning', {'weight': 1}),
#  ('concept drift', 'case-based reasoning', {'weight': 1}),
#  ('concept drift', 'class imbalance', {'weight': 1}),
#  ('concept drift', 'clustering', {'weight': 2}),
#  ('concept drift', 'computational complexity', {'weight': 1}),
#  ('concept drift', 'decision tree', {'weight': 2}),
#  ('concept drift', 'ensemble learning', {'weight': 1}),
#  ('concept drift', 'gaussian mixture models', {'weight': 1}),
#  ('concept drift', 'genetic algorithm', {'weight': 1}),
#  ('concept drift', 'incremental learning', {'weight': 2}),
#  ('concept drift', 'multiple classifier systems', {'weight': 2}),
#  ('concept drift', 'online learning', {'weight': 2}),
#  ('concept drift', 'semi-supervised learning', {'weight': 2}),
#  ('concept drift', 'unlabeled data', {'weight': 2}),
#  ('concept learning', 'adaboost', {'weight': 1}),
#  ('concept learning', 'bagging', {'weight': 1}),
#  ('concept learning', 'boosting', {'weight': 1}),
#  ('concept learning', 'classification', {'weight': 1}),
#  ('concept learning', 'computational learning theory', {'weight': 1}),
#  ('concept learning', 'conceptual clustering', {'weight': 1}),
#  ('concept learning', 'ensemble learning', {'weight': 1}),
#  ('concept learning', 'feature selection', {'weight': 1}),
#  ('concept learning', 'meta-learning', {'weight': 1}),
#  ('concept learning', 'over-fitting', {'weight': 1}),
#  ('concept learning', 'pac learning', {'weight': 1}),
#  ('concept learning', 'pattern discovery', {'weight': 1}),
#  ('concept learning', 'rule learning', {'weight': 1}),
#  ('concept learning', 'semi-supervised learning', {'weight': 1}),
#  ('conceptual clustering', 'case-based reasoning', {'weight': 1}),
#  ('conceptual clustering', 'fuzzy set', {'weight': 1}),
#  ('conceptual clustering', 'hierarchical clustering', {'weight': 1}),
#  ('conceptual clustering', 'indexing', {'weight': 1}),
#  ('conditional random field', 'active learning', {'weight': 1}),
#  ('conditional random field', 'named entity recognition', {'weight': 1}),
#  ('conditional random fields', 'classification', {'weight': 1}),
#  ('conditional random fields', 'support vector machine', {'weight': 2}),
#  ('conditional random fields', 'transfer learning', {'weight': 1}),
#  ('conformal prediction', 'classification', {'weight': 1}),
#  ('conformal prediction', 'regression', {'weight': 1}),
#  ('constraint satisfaction', 'combinatorial optimization', {'weight': 1}),
# ...
#  ('support vector machine', 'forecast', {'weight': 2}),
#  ('support vector machine', 'fuzzy c-means', {'weight': 1}),
#  ('support vector machine', 'fuzzy clustering', {'weight': 1}),
#  ('support vector machine', 'fuzzy logic', {'weight': 1}),
#  ('support vector machine', 'gaussian process', {'weight': 1}),
#  ('support vector machine', 'gaussian processes', {'weight': 1}),
#  ('support vector machine', 'generalization', {'weight': 2}),
#  ('support vector machine', 'genetic algorithm', {'weight': 14}),
#  ('support vector machine', 'genetic programming', {'weight': 1}),
#  ('support vector machine', 'hidden markov model', {'weight': 1}),
#  ('support vector machine', 'hidden markov models', {'weight': 1}),
#  ('support vector machine', 'hierarchical classification', {'weight': 1}),
#  ('support vector machine', 'incremental learning', {'weight': 4}),
#  ('support vector machine', 'inductive logic programming', {'weight': 1}),
#  ('support vector machine', 'information gain', {'weight': 1}),
#  ('support vector machine', 'instance-based learning', {'weight': 1}),
#  ('support vector machine', 'k-means', {'weight': 2}),
#  ('support vector machine', 'k-means algorithm', {'weight': 1}),
#  ('support vector machine', 'k-nearest neighbor', {'weight': 1}),
#  ('support vector machine', 'k-nearest neighbors', {'weight': 2}),
#  ('support vector machine', 'kernel', {'weight': 6}),
#  ('support vector machine', 'kernel function', {'weight': 13}),
#  ('support vector machine', 'kernel functions', {'weight': 2}),
#  ('support vector machine', 'kernel machines', {'weight': 1}),
#  ('support vector machine', 'kernel method', {'weight': 1}),
#  ('support vector machine', 'knn', {'weight': 2}),
#  ('support vector machine', 'lasso', {'weight': 1}),
#  ('support vector machine', 'lda', {'weight': 1}),
#  ('support vector machine', 'learning algorithm', {'weight': 1}),
#  ('support vector machine', 'learning vector quantization', {'weight': 1}),
#  ('support vector machine',
#   'least squares support vector machine',
#   {'weight': 3}),
#  ('support vector machine', 'linear discriminant analysis', {'weight': 1}),
#  ('support vector machine', 'linear programming', {'weight': 2}),
#  ('support vector machine', 'linear regression', {'weight': 1}),
#  ('support vector machine', 'machine-learning', {'weight': 2}),
#  ('support vector machine', 'manifold learning', {'weight': 2}),
#  ('support vector machine', 'mapreduce', {'weight': 1}),
#  ('support vector machine', 'maximum entropy', {'weight': 1}),
#  ('support vector machine', 'multi-label classification', {'weight': 1}),
#  ('support vector machine', 'multiclass', {'weight': 1}),
#  ('support vector machine', 'multilayer perceptron', {'weight': 1}),
#  ('support vector machine', 'multispectral', {'weight': 1}),
#  ('support vector machine', 'named entity recognition', {'weight': 1}),
#  ('support vector machine', 'nearest neighbor', {'weight': 3}),
#  ('support vector machine', 'nearest neighbour', {'weight': 1}),
#  ('support vector machine', 'neural net', {'weight': 1}),
#  ('support vector machine', 'neural network', {'weight': 19}),
#  ('support vector machine', 'online learning', {'weight': 1}),
#  ('support vector machine', 'optimization', {'weight': 1}),
#  ('support vector machine', 'ordinal regression', {'weight': 1}),
#  ('support vector machine', 'outlier detection', {'weight': 1}),
#  ('support vector machine', 'parameter tuning', {'weight': 2}),
#  ('support vector machine', 'particle swarm optimization', {'weight': 5}),
#  ('support vector machine', 'pattern classification', {'weight': 2}),
#  ('support vector machine', 'pca', {'weight': 3}),
#  ('support vector machine', 'posterior probability', {'weight': 2}),
#  ('support vector machine', 'prediction', {'weight': 15}),
#  ('support vector machine', 'r', {'weight': 1}),
#  ('support vector machine', 'radial basis function', {'weight': 1}),
#  ('support vector machine',
#   'radial basis function neural networks',
#   {'weight': 1}),
#  ('support vector machine', 'random forest', {'weight': 5}),
#  ('support vector machine', 'regression', {'weight': 6}),
#  ('support vector machine', 'regression analysis', {'weight': 1}),
#  ('support vector machine', 'reinforcement learning', {'weight': 1}),
#  ('support vector machine', 'relevance vector machine', {'weight': 6}),
#  ('support vector machine',
#   'reproducing kernel hilbert spaces',
#   {'weight': 1}),
#  ('support vector machine', 'ridge regression', {'weight': 2}),
#  ('support vector machine', 'roc', {'weight': 1}),
#  ('support vector machine', 'roc curve', {'weight': 1}),
#  ('support vector machine', 'rough set', {'weight': 1}),
#  ('support vector machine', 'rough set theory', {'weight': 1}),
#  ('support vector machine', 'rule extraction', {'weight': 1}),
#  ('support vector machine', 'self-organizing map', {'weight': 1}),
#  ('support vector machine', 'semidefinite programming', {'weight': 1}),
#  ('support vector machine', 'simulated annealing', {'weight': 1}),
#  ('support vector machine', 'stacking', {'weight': 1}),
#  ('support vector machine', 'statistical learning theory', {'weight': 2}),
#  ('support vector machine', 'statistical methods', {'weight': 1}),
#  ('support vector machine', 'statistics', {'weight': 3}),
#  ('support vector machine', 'supervised learning', {'weight': 3}),
#  ('support vector machine', 'support vector machine', {'weight': 10}),
#  ('support vector machine', 'support vector regression', {'weight': 6}),
#  ('support vector machine', 'time series prediction', {'weight': 1}),
#  ('support vector machine', 'training', {'weight': 1}),
#  ('support vector machine', 'transduction', {'weight': 1}),
#  ('support vector machine', 'uncertainty', {'weight': 2}),
#  ('support vector machine', 'unsupervised learning', {'weight': 1}),
#  ('support vector machine', 'visualization', {'weight': 1}),
#  ('support vector machine', 'wavelet', {'weight': 3}),
#  ('support vector regression', 'classification', {'weight': 1}),
#  ('support vector regression', 'clustering analysis', {'weight': 1}),
#  ('support vector regression', 'cross-validation', {'weight': 1}),
#  ('support vector regression', 'feature extraction', {'weight': 1}),
#  ('support vector regression', 'feature selection', {'weight': 5}),
#  ('support vector regression', 'gaussian process', {'weight': 1}),
#  ('support vector regression', 'generalization error', {'weight': 1}),
#  ('support vector regression', 'genetic algorithm', {'weight': 3}),
#  ('support vector regression', 'hierarchical clustering', {'weight': 1}),
#  ('support vector regression', 'k-means clustering', {'weight': 1}),
#  ('support vector regression', 'multilayer perceptron', {'weight': 1}),
#  ('support vector regression', 'neural network', {'weight': 3}),
#  ('support vector regression', 'nonparametric regression', {'weight': 1}),
#  ('support vector regression', 'particle swarm optimization', {'weight': 2}),
#  ('support vector regression', 'radial basis function network', {'weight': 1}),
#  ('support vector regression', 'regression', {'weight': 1}),
#  ('support vector regression', 'ridge regression', {'weight': 1}),
#  ('support vector regression', 'time series', {'weight': 1}),
#  ('support vector regression', 'time series prediction', {'weight': 1}),
#  ('survival analysis', 'classification', {'weight': 2}),
#  ('survival analysis', 'denoising', {'weight': 1}),
#  ('survival analysis', 'nearest neighbour', {'weight': 1}),
#  ('symbolic regression', 'genetic programming', {'weight': 3}),
#  ('symbolic regression', 'inductive learning', {'weight': 1}),
#  ('symbolic regression', 'symbolic regression', {'weight': 1}),
#  ('time series', 'classification', {'weight': 1}),
#  ('time series', 'clustering', {'weight': 1}),
#  ('time series', 'genetic algorithm', {'weight': 1}),
#  ('time series', 'neural network', {'weight': 1}),
#  ('time series', 'pattern analysis', {'weight': 1}),
#  ('time series', 'prediction', {'weight': 2}),
#  ('time series', 'regression', {'weight': 1}),
#  ('time series', 'similarity measure', {'weight': 1}),
#  ('time series', 'support vector machine', {'weight': 4}),
#  ('time series', 'time series forecasting', {'weight': 1}),
#  ('time series analysis', 'classification', {'weight': 1}),
#  ('time series analysis', 'clustering', {'weight': 1}),
#  ('time series analysis', 'dimension reduction', {'weight': 1}),
#  ('time series analysis', 'genetic programming', {'weight': 1}),
#  ('time series analysis', 'hidden markov models', {'weight': 1}),
#  ('time series analysis', 'probabilistic algorithms', {'weight': 1}),
#  ('time series analysis', 'regression', {'weight': 1}),
#  ('time series analysis', 'singular value decomposition', {'weight': 1}),
#  ('time series analysis', 'statistical pattern recognition', {'weight': 1}),
#  ('time series forecasting', 'curse of dimensionality', {'weight': 1}),
#  ('time series forecasting', 'lazy learning', {'weight': 1}),
#  ('time series forecasting', 'neural network ensemble', {'weight': 1}),
#  ('time series forecasting', 'regression', {'weight': 1}),
#  ('time series forecasting', 'support vector machine', {'weight': 2}),
#  ('time series prediction', 'statistical learning theory', {'weight': 1}),
#  ('time series prediction', 'support vector machine', {'weight': 1}),
#  ('training', 'classifier', {'weight': 1}),
#  ('training', 'expectation maximization', {'weight': 1}),
#  ('training', 'genetic algorithm', {'weight': 1}),
#  ('training', 'pruning', {'weight': 3}),
#  ('training', 'rule extraction', {'weight': 2}),
#  ('training', 'rule generation', {'weight': 1}),
#  ('training', 'variable selection', {'weight': 1}),
#  ('transduction', 'convex optimization', {'weight': 1}),
#  ('transduction', 'prediction', {'weight': 1}),
#  ('transduction', 'semidefinite programming', {'weight': 1}),
#  ('transductive learning', 'association rules', {'weight': 1}),
#  ('transductive learning', 'em algorithm', {'weight': 1}),
#  ('transductive learning', 'gaussian mixture model', {'weight': 1}),
#  ('transductive learning', 'inductive learning', {'weight': 1}),
#  ('transductive learning', 'loss function', {'weight': 1}),
#  ('transductive learning', 'nearest neighbor', {'weight': 1}),
#  ('transductive learning', 'semi-supervised learning', {'weight': 2}),
#  ('transductive learning', 'support vector machine', {'weight': 1}),
#  ('transductive learning', 'unlabeled data', {'weight': 1}),
#  ('transfer learning', 'adaboost', {'weight': 1}),
#  ('transfer learning', 'classification', {'weight': 1}),
#  ('transfer learning', 'evolutionary computation', {'weight': 1}),
#  ('transfer learning', 'feature selection', {'weight': 1}),
#  ('transfer learning', 'kernel learning', {'weight': 1}),
#  ('transfer learning', 'metric learning', {'weight': 1}),
#  ('transfer learning', 'multi-task learning', {'weight': 1}),
#  ('transfer learning', 'multiclass classification', {'weight': 1}),
#  ('transfer learning', 'neural network', {'weight': 1}),
#  ('transfer learning', 'prediction', {'weight': 1}),
#  ('transfer learning', 'reinforcement learning', {'weight': 2}),
#  ('transfer learning', 'similarity measure', {'weight': 1}),
#  ('transfer learning', 'spectral clustering', {'weight': 1}),
#  ('transfer learning', 'supervised learning', {'weight': 1}),
#  ('transfer learning', 'support vector machine', {'weight': 1}),
#  ('transfer learning', 'unlabeled data', {'weight': 1}),
#  ('transfer learning', 'unsupervised learning', {'weight': 1}),
#  ('uncertainty', 'binary classification', {'weight': 1}),
#  ('uncertainty', 'classification', {'weight': 2}),
#  ('uncertainty', 'decision tree', {'weight': 2}),
#  ('uncertainty', 'genetic algorithm', {'weight': 2}),
#  ('uncertainty', 'incremental learning', {'weight': 1}),
#  ('uncertainty', 'machine-learning', {'weight': 1}),
#  ('uncertainty', 'markov chain monte carlo', {'weight': 1}),
#  ('uncertainty', 'neural network', {'weight': 1}),
#  ('uncertainty', 'ordinal regression', {'weight': 1}),
#  ('uncertainty', 'prediction', {'weight': 1}),
#  ('uncertainty', 'pruning', {'weight': 1}),
#  ('uncertainty', 'sampling', {'weight': 1}),
#  ('uncertainty', 'selective sampling', {'weight': 1}),
#  ('unlabeled data', 'classification', {'weight': 1}),
#  ('unlabeled data', 'incremental learning', {'weight': 1}),
#  ('unlabeled data', 'missing values', {'weight': 1}),
#  ('unlabeled data', 'semi-supervised learning', {'weight': 1}),
#  ('unsupervised learning', 'classification', {'weight': 2}),
#  ('unsupervised learning', 'cluster analysis', {'weight': 1}),
#  ('unsupervised learning', 'clustering', {'weight': 6}),
#  ('unsupervised learning', 'clustering algorithm', {'weight': 1}),
#  ('unsupervised learning', 'cross-validation', {'weight': 1}),
#  ('unsupervised learning', 'dimension reduction', {'weight': 1}),
#  ('unsupervised learning', 'dimensionality reduction', {'weight': 1}),
#  ('unsupervised learning', 'em algorithm', {'weight': 2}),
#  ('unsupervised learning', 'expectation maximization', {'weight': 2}),
#  ('unsupervised learning', 'feature selection', {'weight': 1}),
#  ('unsupervised learning', 'fuzzy logic', {'weight': 1}),
#  ('unsupervised learning', 'hidden markov model', {'weight': 1}),
#  ('unsupervised learning', 'incremental learning', {'weight': 2}),
#  ('unsupervised learning', 'information theory', {'weight': 1}),
#  ('unsupervised learning', 'k-means algorithm', {'weight': 1}),
#  ('unsupervised learning', 'k-nearest neighbor', {'weight': 2}),
#  ('unsupervised learning', 'kernel learning', {'weight': 1}),
#  ('unsupervised learning', 'lasso', {'weight': 1}),
#  ('unsupervised learning', 'logistic regression', {'weight': 1}),
#  ('unsupervised learning', 'markov decision process', {'weight': 1}),
#  ('unsupervised learning', 'metric learning', {'weight': 1}),
#  ('unsupervised learning', 'mixture models', {'weight': 1}),
#  ('unsupervised learning', 'mutual information', {'weight': 1}),
#  ('unsupervised learning', 'neural nets', {'weight': 1}),
#  ('unsupervised learning', 'neural network', {'weight': 1}),
#  ('unsupervised learning', 'ridge regression', {'weight': 1}),
#  ('unsupervised learning', 'rule learning', {'weight': 1}),
#  ('unsupervised learning', 'som', {'weight': 1}),
#  ('unsupervised learning', 'statistical inference', {'weight': 1}),
#  ('unsupervised learning', 'statistical learning', {'weight': 1}),
#  ('unsupervised learning', 'statistics', {'weight': 1}),
#  ('unsupervised learning', 'supervised learning', {'weight': 3}),
#  ('unsupervised learning', 'unlabeled data', {'weight': 1}),
#  ('unsupervised machine learning', 'cluster analysis', {'weight': 1}),
#  ('unsupervised machine learning', 'hierarchical clustering', {'weight': 1}),
#  ('unsupervised machine learning',
#   'inductive logic programming',
#   {'weight': 1}),
#  ('variable selection', 'bias', {'weight': 1}),
#  ('variable selection', 'classification', {'weight': 2}),
#  ('variable selection', 'clustering', {'weight': 2}),
#  ('variable selection', 'function approximation', {'weight': 1}),
#  ('variable selection', 'genetic algorithm', {'weight': 1}),
#  ('variable selection', 'lasso', {'weight': 1}),
#  ('variable selection', 'mutual information', {'weight': 1}),
#  ('variable selection', 'random forest', {'weight': 1}),
#  ('variable selection', 'ridge regression', {'weight': 1}),
#  ('variable selection', 'spectral analysis', {'weight': 1}),
#  ('visualization', 'classification', {'weight': 1}),
#  ('visualization', 'clustering', {'weight': 2}),
#  ('visualization', 'ensemble classifiers', {'weight': 1}),
#  ('visualization', 'explanation', {'weight': 1}),
#  ('visualization', 'feature selection', {'weight': 1}),
#  ('visualization', 'machine-learning', {'weight': 1}),
#  ('wavelet', 'classification', {'weight': 1}),
#  ('wavelet', 'neural network', {'weight': 2}),
#  ('wavelet', 'pca', {'weight': 1}),
#  ('wavelet transform', 'denoising', {'weight': 1}),
#  ('wavelet transform', 'features', {'weight': 1}),
#  ('wavelet transform', 'support vector machine', {'weight': 4}),
#  ('wavelet transform', 'visualization', {'weight': 1}),
#  ('wavelets', 'classification', {'weight': 1}),
#  ('wavelets', 'kernel', {'weight': 1}),
#  ('wavelets', 'mutual information', {'weight': 1}),
#  ('wavelets', 'radial basis functions', {'weight': 1}),
#  ('wavelets', 'regression', {'weight': 1}),
#  ('wavelets', 'regularization', {'weight': 1}),
#  ('wavelets', 'support vector machine', {'weight': 2})]

# %%
classi =nx.ego_graph(tech_trimmed, 'logistic regression')
classi.size()
# Out:
# 71

# %%
layout = nx.fruchterman_reingold_layout(classi, k=0.5, weight= 'weight')
nx.draw(classi, layout, figsize(10,10))

# %% [markdown]
# # Linking fields and topics
#
# Can we link topics to fields?
#
# ## Idea A: use networks
#
# 1. clean up fields so each publication has the most distinctive fields - remove 'computer science'
# 2. clean up topics so that each publication has the most distinctive topics -- remove 'machine learning'
# 3. create bipartite network of fields & topics?
#
# ## Idea B: use association/correlations

# %%
# to create distinctive topics, drop machine learning
ftdf = df[['fields', 'topics']]
print(ftdf.shape)
ftdf.head()
# Out:
# (23240, 2)
#                               fields  \
# 0    [computer science, engineering]
# 1                 [computer science]
# 2                 [computer science]
# 3    [computer science, engineering]
# 4  [engineering, telecommunications]
#
#                                               topics
# 0  [spam detection, machine learning, web securit...
# 1                                                NaN
# 2  [machine learning, c4.5desicion tree, encoded ...
# 3   [brain mri images, nn classifier, decision tree]
# 4  [acoustic emission, creep material rupture, ne...

# %%
gr = nx.Graph()

#[i for i in itertools.combinations(de, 2) for de in df.topics[:100]]
gr.add_edges_from([i for de in df.topics.dropna()[0:200] for i in itertools.combinations(de,2)])

# %%
gr2 = nx.Graph()
[gr2.add_edge(f[0],t[0]) for f,t in zip(ftdf.fields, ftdf.topics) if f is not NaN and t is not NaN]
gr2.size()
# Out:
# 8958

# %%
print('topics network has %s edges and %s nodes'%(gr.number_of_edges(), gr.number_of_nodes()))
nx.average_degree_connectivity(gr)
#nx.draw_networkx(gr)
# Out:
# topics network has 1839 edges and 694 nodes
# {1: 65.11111111111111,
#  2: 35.6144578313253,
#  3: 36.29323308270677,
#  4: 32.34905660377358,
#  5: 27.657471264367818,
#  6: 34.2328431372549,
#  7: 31.665024630541872,
#  8: 17.85576923076923,
#  9: 33.01851851851852,
#  10: 17.833333333333332,
#  11: 21.836363636363636,
#  12: 24.805555555555557,
#  13: 18.615384615384617,
#  14: 14.723214285714286,
#  15: 29.866666666666667,
#  16: 28.75,
#  17: 14.676470588235293,
#  24: 19.25,
#  25: 8.08,
#  27: 17.25925925925926,
#  34: 13.911764705882353,
#  43: 13.0,
#  68: 10.514705882352942,
#  264: 5.617424242424242}

# %%
gr.remove_node('machine learning')

# %%
deg=nx.degree(gr)

# %%
deg['support vector machine']
deg_sorted = sorted(deg.iteritems(), key=lambda(k,v):(-v,k))
deg_sorted[:50]
# Out:
# [('support vector machine', 67),
#  ('classification', 42),
#  ('data mining', 33),
#  ('feature selection', 26),
#  ('neural network', 26),
#  ('clustering', 25),
#  ('feature extraction', 23),
#  ('decision tree', 17),
#  ('boosting', 16),
#  ('pattern recognition', 15),
#  ('algorithms', 14),
#  ('centroid-list', 14),
#  ('dbscan technique', 14),
#  ('ddbj', 14),
#  ('discernibility relation', 14),
#  ('distinction table', 14),
#  ('embl', 14),
#  ('feature-list', 14),
#  ('format binding', 14),
#  ('genbank', 14),
#  ('match algorithm', 14),
#  ('metroplis algorithm', 14),
#  ('multi objective ga', 14),
#  ('nsga ii', 14),
#  ('reduct', 14),
#  ('search & retrieve algorithm', 14),
#  ('computer vision', 13),
#  ('semi-supervised learning', 13),
#  ('pca', 12),
#  ('prediction', 12),
#  ('adaboost', 11),
#  ('classifiers', 11),
#  ('rough set', 11),
#  ('youtube', 11),
#  ('experimentation', 10),
#  ('learning', 10),
#  ('naive bayes classifier', 10),
#  ('sentiment analysis', 10),
#  ('tracking', 10),
#  ('information retrieval', 9),
#  ('intrusion detection', 9),
#  ('10-fald cross validation', 8),
#  ('bug priority', 8),
#  ('bug repositories', 8),
#  ('chebyshev expansion', 8),
#  ('cross-validation', 8),
#  ('discrete cosine transform (dct)', 8),
#  ('discrete fourier transform (dft)', 8),
#  ('factor analysis (fa)', 8),
#  ('feature reduction', 8)]

# %%
h=hist(deg.values(), 100)
loglog(h[1][1:], h[0])

# %%
#remove 1-degree nodes

g2 = gr.copy()
d = nx.degree(g2)
remove = 10
[g2.remove_node(n) for n in g2.nodes() if d[n] <= remove]
print g2.size()

nsizes = [n*10 for n in d.values() if n >remove]
# Out:
# 130

# %%
f = plt.figure(figsize=(10,10))

nx.draw_graphviz(g2, alpha=0.6, k=0.6,node_sizes = nsizes)
# Out:
# /usr/local/lib/python2.7/dist-packages/pygraphviz/agraph.py:1281: RuntimeWarning: Fontconfig warning: "/etc/fonts/conf.d/50-user.conf", line 9: reading configurations from ~/.fonts.conf is deprecated.
#
#   warnings.warn("".join(errors),RuntimeWarning)

# %% [markdown]
# # 2 mode networks: disciplines and techniques

# %%
from networkx.algorithms import bipartite as bi

# %%
tx = ml.discipline_techniques_graph(df)

# %%
tx.size()
disciplines = df.SC_l.unique()
techniques = {det  for de in df.topics if de is not nan for det in de}

# %%
df.SC_l
# Out:
# 0                         computer science; engineering
# 1                                      computer science
# 2                                      computer science
# 3                         computer science; engineering
# 4                       engineering; telecommunications
# 5     automation & control systems; computer science...
# 6     automation & control systems; computer science...
# 7     automation & control systems; computer science...
# 8                         computer science; engineering
# 9                      biophysics; engineering; physics
# 10                     biophysics; engineering; physics
# 11                     biophysics; engineering; physics
# 12          business & economics; public administration
# 13          business & economics; public administration
# 14                                     computer science
# ...
# 23225                                     computer science
# 23226                 computer science; telecommunications
# 23227                                     computer science
# 23228                        computer science; engineering
# 23229                                     computer science
# 23230                                     computer science
# 23231                                     computer science
# 23232                                     computer science
# 23233                                     computer science
# 23234                                     computer science
# 23235    computer science; mathematical & computational...
# 23236    computer science; mathematical & computational...
# 23237                                     computer science
# 23238                                     computer science
# 23239    computer science; mathematical & computational...
# Name: SC_l, Length: 23240, dtype: object

# %%
len(techniques)
# Out:
# 28477

# %%
disc = bi.projected_graph(tx, g2.nodes())

# %%
sorted(disc.degree().iteritems(), key= operator.itemgetter(1))
# Out:
# [('discernibility relation', 1),
#  ('genbank', 1),
#  ('embl', 1),
#  ('centroid-list', 1),
#  ('medical laboratory technology; pathology', 1),
#  ('format binding', 1),
#  ('reduct', 1),
#  ('match algorithm', 1),
#  ('ddbj', 1),
#  ('feature-list', 1),
#  ('nsga ii', 1),
#  ('metroplis algorithm', 1),
#  ('multi objective ga', 1),
#  ('physical geography', 1),
#  ('pharmacology & pharmacy', 1),
#  ('dbscan technique', 1),
#  ('search & retrieve algorithm', 1),
#  ('distinction table', 1),
#  ('youtube', 1),
#  ('biochemistry & molecular biology', 1),
#  ('computer science; medical informatics; nursing', 2),
#  ('engineering; instruments & instrumentation; optics', 2),
#  ('materials science', 2),
#  ('engineering; radiology, nuclear medicine & medical imaging', 2),
#  ('engineering; nuclear science & technology', 2),
#  ('instruments & instrumentation; spectroscopy', 2),
#  ('agriculture; computer science', 2),
#  ('biochemistry & molecular biology; optics; radiology, nuclear medicine & medical imaging',
#   2),
#  ('cell biology', 2),
#  ('microscopy', 3),
#  ('boosting', 3),
#  ('rough set', 3),
#  ('algorithms', 3),
#  ('adaboost', 3),
#  ('automation & control systems; computer science; engineering; mathematical & computational biology; robotics',
#   4),
#  ('semi-supervised learning', 4),
#  ('computer science; engineering; robotics', 4),
#  ('robotics; remote sensing; imaging science & photographic technology', 4),
#  ('engineering; robotics', 4),
#  ('mathematics; physics', 4),
#  ('automation & control systems; computer science', 4),
#  ('automation & control systems; engineering', 4),
#  ('ophthalmology; optics; physics', 4),
#  ('automation & control systems; engineering; metallurgy & metallurgical engineering',
#   4),
#  ('engineering; optics; imaging science & photographic technology', 4),
#  ('biochemistry & molecular biology; chemistry; pharmacology & pharmacy', 4),
#  ('computer science; engineering; imaging science & photographic technology',
#   4),
#  ('automation & control systems; agriculture; engineering', 4),
#  ('neurosciences & neurology', 4),
#  ('engineering; mathematics; mechanics', 4),
#  ('automation & control systems; computer science; engineering; telecommunications',
#   4),
#  ('robotics', 4),
#  ('automation & control systems; robotics', 4),
#  ('telecommunications', 4),
#  ('classifiers', 4),
#  ('computer science; psychology; social sciences - other topics', 4),
#  ('automation & control systems; engineering; optics', 4),
#  ('automation & control systems; computer science; robotics', 4),
#  ('neurosciences & neurology; physiology', 4),
#  ('automation & control systems', 4),
#  ('automation & control systems; computer science; engineering', 4),
#  ('life sciences & biomedicine - other topics', 4),
#  ('general & internal medicine', 5),
#  ('computer science; medical informatics', 5),
#  ('engineering; environmental sciences & ecology', 5),
#  ('health care sciences & services; medical informatics', 5),
#  ('neurosciences & neurology; psychiatry; psychology', 5),
#  ('computer science; engineering; medical informatics', 6),
#  ('computer science; health care sciences & services; medical informatics', 6),
#  ('clustering', 6),
#  ('engineering; materials science', 6),
#  ('computer science; robotics', 6),
#  ('engineering', 6),
#  ('engineering; instruments & instrumentation', 6),
#  ('mathematics', 6),
#  ('physical geography; geology; remote sensing; imaging science & photographic technology',
#   7),
#  ('engineering; optics; imaging science & photographic technology; spectroscopy',
#   7),
#  ('optics; imaging science & photographic technology', 7),
#  ('life sciences & biomedicine - other topics; mathematical & computational biology',
#   7),
#  ('environmental sciences & ecology; remote sensing; imaging science & photographic technology',
#   7),
#  ('energy & fuels; geology', 7),
#  ('engineering; geology; remote sensing', 7),
#  ('environmental sciences & ecology; physical geography', 7),
#  ('engineering; telecommunications', 7),
#  ('physical geography; geology', 7),
#  ('geochemistry & geophysics; engineering; remote sensing', 7),
#  ('geology; remote sensing; optics', 7),
#  ('physical geography; remote sensing; imaging science & photographic technology',
#   7),
#  ('geology; remote sensing', 7),
#  ('environmental sciences & ecology; meteorology & atmospheric sciences', 7),
#  ('engineering; computer science; remote sensing; optics', 7),
#  ('public, environmental & occupational health', 7),
#  ('environmental sciences & ecology; remote sensing; optics', 7),
#  ('forestry', 7),
#  ('water resources', 7),
#  ('remote sensing; optics', 7),
#  ('remote sensing', 7),
#  ('computer science; engineering; operations research & management science',
#   9),
#  ('environmental sciences & ecology', 9),
#  ('psychology', 10),
#  ('pattern recognition', 10),
#  ('computer science', 11),
#  ('prediction', 17),
#  ('computer science; engineering', 17),
#  ('computer science; mathematics', 17),
#  ('neural network', 21),
#  ('pca', 27),
#  ('feature extraction', 34),
#  ('chemistry; science & technology - other topics; materials science; physics',
#   34),
#  ('feature selection', 38),
#  ('data mining', 46),
#  ('classification', 49),
#  ('computer vision', 50),
#  ('support vector machine', 60),
#  ('decision tree', 63)]

# %% [markdown]
# ## Retrieving further literature if needed from WoS

# %%
## generate searches that can be run back against WoS - it says it will take up to 5000 terms!

'"'+'" or "'.join([de for de,val in de_counts_sorted if val > 90 and val < 200]) + '"'
# Out:
# '"bioinformatics" or "reinforcement learning" or "genetic algorithm" or "feature extraction" or "decision tree" or "prediction" or "natural language processing" or "boosting" or "artificial neural networks" or "knowledge discovery" or "knowledge acquisition" or "text mining" or "kernel methods" or "genetic programming" or "information retrieval" or "algorithms" or "semi-supervised learning" or "optimization" or "supervised learning" or "regression" or "pattern classification" or "bayesian networks" or "information extraction" or "text classification" or "image processing" or "artificial neural network" or "random forest" or "intrusion detection" or "learning" or "fuzzy logic" or "rough sets" or "dimensionality reduction" or "computer vision" or "support vector regression" or "rough set" or "inductive logic programming"'

# %% [markdown]
# ## Building a topic model

# %%
# <markdowncell>

# # The corpus of ML

# <codecell>

ti_ab = df.TI + df.AB
mlt = nltk.TextCollection([nltk.tokenize.word_tokenize(t) for t in ti_ab.dropna()])

# <markdowncell>
mlt.tokens[0:20]
# Out:
# ['Detecting',
#  'Spam',
#  'in',
#  'Chinese',
#  'Microblogs',
#  '-',
#  'A',
#  'study',
#  'on',
#  'Sina',
#  'WeiboSina',
#  'Weibo',
#  'is',
#  'the',
#  'most',
#  'popular',
#  'and',
#  'fast',
#  'growing',
#  'microblogging',
#  'social',
#  'network',
#  'in',
#  'China.',
#  'However',
#  ',',
#  'more',
#  'and',
#  'more',
#  'spam',
#  'messages',
#  'are',
#  'also',
#  'emerging',
#  'on',
#  'Sina',
#  'Weibo.',
#  'How',
#  'to',
#  'detect',
#  'these',
#  'spam',
#  'is',
#  'essential',
#  'for',
#  'the',
#  'social',
#  'network',
#  'security.',
#  'While',
#  'most',
#  'previous',
#  'studies',
#  'attempt',
#  'to',
#  'detect',
#  'the',
#  'microblogging',
#  'spam',
#  'by',
#  'identifying',
#  'spammers',
#  ',',
#  'in',
#  'this',
#  'paper',
#  ',',
#  'we',
#  'want',
#  'to',
#  'exam',
#  'whether',
#  'we',
#  'can',
#  'detect',
#  'the',
#  'spam',
#  'by',
#  'each',
#  'single',
#  'Weibo',
#  'message',
#  ',',
#  'because',
#  'we',
#  'notice',
#  'that',
#  'more',
#  'and',
#  'more',
#  'spam',
#  'Weibos',
#  'are',
#  'posted',
#  'by',
#  'normal',
#  'users',
#  'or',
#  'even',
#  'popular']

# %% [markdown]
# ## The cited references

# %%
df.NR.hist(bins=200)

# %% [markdown]
# # Keywords of interest

# %%
plt.figure(figsize=(14,6))

key1 = 'generalization'
k1 = ml.keyword_years(df, key1)
plt.subplot(141)
plt.hist(k1.PY, bins=20)
plt.title(key1)

key2 = 'error'
k2 = ml.keyword_years(df, key2)
plt.subplot(142)
plt.hist(k2.PY, bins=20)
plt.title(key2)

key3 = 'bootstrap'
k3 = ml.keyword_years(df, key3)
plt.subplot(143)
plt.hist(k3.PY, bins=20)
plt.title(key3)

key4 = 'bagging'
k4 = ml.keyword_years(df, key4)
plt.subplot(144)
plt.hist(k4.PY, bins=20)
plt.title(key4)
