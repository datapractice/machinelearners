# %%
# %load_ext autoreload
# %autoreload 2

# %%
import ml_lit_anal as ml
import re
import nltk
import pickle
import operator
import google_scholar_parser as gs
import pandas as pd
import networkx as nx
import itertools
matplotlib.use('WXAgg')
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
def sorted_map(map): return sorted(map.iteritems(), key=lambda (k,v): (-v,k))

# %%
df = ml.load_records('data/machine_learning_WOS/')
print('There are %s records in the dataset'%df.shape[0])

#clean topics
df = ml.clean_topics(df)
# Out:
# There are 23240 records in the dataset

# %% [markdown]
# # Co-word analysis of the machine learning literature

# %%
#choose the set of keywords to use
de_all = [d for de in df.topics.dropna() for d in de]
de_set = set(de_all)
de_counts = {de:de_all.count(de) for de in de_set}
	#de_counts_sorted = sorted(de_counts.iteritems(), key = operator.itemgetter(1), reverse=True)

# %%
	# choose top 500 keywords
keys = [t[0] for t in de_counts.items() if t[1] > 10]
print('there are %s keywords' % len(keys))
# Out:
# there are 623 keywords

# %%
# construct the coword matrix by counting how often keywords appear with each other
cow_df = ml.coword_matrix(df,keys)

# %% [markdown]
# For co-word analysis, calculate a matrix of equivalence scores and look for largest values. I'm drawing on Callon M, Courtial JP and Laville F (1991) Co-word analysis as a tool for describing the network of interactions between basic and technological research: The case of polymer chemsitry. _Scientometrics_, 22(1), 155–205 for this.
#
# They write:
#
# > The calculation of all coefficients between all possible word pairs (even if the
# value of these coefficients is often equal to zero) generates a considerable number of
# links - far too many to able to represent graphically. This is why we have developed
# algorithms for generating sub-groups that can be more easily visualized and
# interpreted. 161
#
# Much of their method is devoted to better ways of dealing with the proliferation of links. I'm not sure we have the same problem today, because of machine learning.

# %%
eqcow_df = ml.equivalence_matrix(cow_df, de_counts)
eq2 = eqcow_df.unstack().copy()
eq2.sort(ascending=False)
eq2[:100:2]
# Out:
# independent component analysis          blind signal separation                   0.430976
# methods: statistical                    methods: data analysis                    0.350877
# machine learning for signal processing  blind signal separation                   0.260870
# resource management                     sensor networks                           0.210526
# experimentation                         algorithms                                0.204070
# mild cognitive impairment               alzheimer's disease                       0.193939
# resource management                     control                                   0.190476
# machine learning for signal processing  learning theory                           0.163496
# sensor networks                         control                                   0.160401
# experimentation                         measurement                               0.145690
# software metrics                        software quality                          0.142857
# collaborative filtering                 recommender systems                       0.132719
# surveys                                 methods: data analysis                    0.126316
# artificial immune system                airs                                      0.115315
# independent component analysis          machine learning for signal processing    0.112429
# experimentation                         performance                               0.109195
# performance                             algorithms                                0.104832
# brain-computer interface (bci)          electroencephalogram (eeg)                0.103896
# imputation                              missing data                              0.098814
# mass spectrometry                       proteomics                                0.097959
# computational molecular biology         markov chains                             0.095238
# performance                             languages                                 0.094737
# design                                  performance                               0.092935
# sentiment analysis                      opinion mining                            0.092571
# experimentation                         design                                    0.091333
# sequence analysis                       computational molecular biology           0.087912
# genomics                                proteomics                                0.080201
# human factors                           experimentation                           0.078818
# boosting                                bagging                                   0.077114
# network security                        intrusion detection                       0.074062
# xcs                                     learning classifier systems               0.073964
# protein                                 secondary structure                       0.072398
# performance                             measurement                               0.071053
# virtual screening                       drug discovery                            0.069717
# magnetic resonance imaging              alzheimer's disease                       0.064103
# co-training                             semi-supervised learning                  0.063894
# resource management                     evolutionary algorithm                    0.058824
# optimisation                            probabilistic graphical models            0.058442
# emotion recognition                     affective computing                       0.057870
# mammography                             computer-aided diagnosis                  0.055804
# information visualization               visual analytics                          0.053571
# chemometrics                            metabolomics                              0.053571
# genetics-based machine learning         learning classifier systems               0.053419
# probabilistic graphical models          evolution                                 0.051136
# reinforcement learning                  q-learning                                0.050208
# software quality                        metrics                                   0.050000
# chemometrics                            raman spectroscopy                        0.050000
# information retrieval                   learning to rank                          0.050000
# raman spectroscopy                      chemometrics                              0.050000
# evolutionary algorithm                  sensor networks                           0.049536
# dtype: float64

# %%
eq2.hist(bins=500)

# %% [markdown]
# Classic coword analysis looks for clusters using thresholds.

# %%
eqnx = nx.from_numpy_matrix(eqcow_df.as_matrix())

# %%
eqnx.number_of_nodes()
nx.draw_spring(eqnx, node_size=30)

# %% [markdown]
# ## Development analysis
#
# The problem is that I'm keeping 25 years of research together. There is no chance of looking at development, or seeing relationships.
# Before 1990, there are very few machine learning papers (less than 100). So the first snapshot could be 1990

# %%
df_pre = df[df.PY <=1990]

print('There are %s papers by the end of 1990'%df_pre.shape[0])
# Out:
# There are 109 papers by the end of 1990

# %% [markdown]
# There are very few abstracts in this collection, and as we will see, not too many keywords. So might need to use titles

# %%
df.TI.drop_duplicates()
# Out:
# 0     Detecting Spam in Chinese Microblogs - A study...
# 1     Electric Appliance Classification Based on Dis...
# 2     NETWORK TRAFFIC ON-LINE CLASSIFICATION USING D...
# 3     Machine Learning Approach for Brain Tumor Dete...
# 4     Creep Test Material Rupture Prediction by Neur...
# 5     Emotion Detection Using Average Relative Ampli...
# 6     Document Categorizer Agent based on ACM Hierarchy
# 7     A Comparative Study of Reduced Error Pruning M...
# 8     Feature Selection for Machine Learning Based A...
# 9     Service Discovery Framework Supported by EM Al...
# 10    Predicting Protein - RNA Binding sites using s...
# 11    Remotely Sensed Percent Tree Cover Mapping Usi...
# 12    A Machine Learning Approach for English Senten...
# 13    A New Pruning Method for Associative Classific...
# 14    DRFLogitBoost: A Double Randomized Decision Fo...
# ...
# 23223    Application of feature subset selection based ...
# 23224    A novel SVM-based method for moving video obje...
# 23225    An evolutionary approach to inverse gray level...
# 23226    EviRank: An Evidence Based Content Trust Model...
# 23227    Predicting the political sentiment of web log ...
# 23228    'You are sooo cool, valentina!' recognizing so...
# 23230    An investigation into the interaction between ...
# 23231     Constraint-based mining of web page associations
# 23232    Automated intelligent abundance analysis of sc...
# 23233     Automatic sapstain detection in processed timber
# 23234    Categorizing software engineering knowledge us...
# 23235    Music expression understanding based on a join...
# 23236    Tonal harmony analysis: A supervised sequentia...
# 23237    New heuristics in feature selection for high d...
# 23238    Solving and learning a tractable class of soft...
# Name: TI, Length: 23052, dtype: object

# %%
pre_90_keys = ml.keyword_counts(df_pre)
pre_90_keys
# Out:
# {'artificial intelligence': 1,
#  'assembly automation': 1,
#  'commutative dfa': 1,
#  'computational learning theory': 1,
#  'decision-making': 1,
#  'experimental design': 1,
#  'expert system': 1,
#  'expert systems': 1,
#  'induction': 1,
#  'inductive inference': 2,
#  'information compression': 1,
#  'intelligent decision-making': 1,
#  'intelligent manufacturing': 1,
#  'inverse resolution': 1,
#  'knowledge acquisition': 1,
#  'learning': 2,
#  'logic programming': 1,
#  'machine learning': 6,
#  'manufacturing operation planning': 1,
#  'mistake bound model': 1,
#  'neural network': 1,
#  'nonmonotonic reasoning': 1,
#  'pac learning model': 1,
#  'polynomial-time complexity': 1,
#  'predicate invention': 1,
#  'robotics': 1,
#  'simulation': 1}

# %% [markdown]
# The problem is that most of the literature before 1990 have no keywords. They were not keyworded by anyone. But for those that are:

# %%
print('The number of pre-1990 references that have keyword: %s'%df_pre.topics.count())
cow_df1 = ml.coword_matrix(df_pre, pre_90_keys.keys())
cow_df1.head()
pre_90_nx = nx.from_numpy_matrix(cow_df1.as_matrix())
cols = cow_df1.columns.tolist()

labels = {cols.index(l):l for l in cols}
pos = nx.spring_layout(pre_90_nx)
fig = plt.gcf()
fig.set_size_inches(12.5,12.5)
fig.set_label('Pre-1990 keywords and their relations')

nx.draw(pre_90_nx, pos=pos, alpha=0.5, node_size=50, with_labels=True, labels=labels)
#nx.draw_networkx_labels(pre_90_nx, pos=pos,labels = labels, font_size=9)
# Out:
# The number of pre-1990 references that have keyword: 8

# %% [markdown]
# What is slightly interesting here are the two different networks around learning and machine learning. But this is all based on a handful of references, so there is little point going further with it.
#
# # How do things go after 1990? The 1990- 1995 analysis

# %%
df_pre2 = df[(df.PY <= 1995) & (df.PY >1990)]
keys_90_95 = ml.keyword_counts(df_pre2)
fig = plt.gcf()
print('There are %s keywords in the 1990-95 literature' % len(keys_90_95))
net = ml.draw_network_by_years(df, 1990,1995, True, 12)
# Out:
# There are 970 keywords in the 1990-95 literature
# Calculating co-word matrix
# drawing the network ....

# %%
coword_net = net
pos = nx.spring_layout(coword_net)
labels = nx.get_node_attributes(coword_net, 'keyword')
nx.draw(coword_net, pos=pos, alpha=0.5, 
        node_size=50, 
        with_labels=True, labels=labels)

# %%
nx.draw(coword_net, pos=pos, alpha=0.5, 
        with_labels=True, labels=labels)

# %% [markdown]
# This is a much more complicated structure. This couple of dozen keywords have morphed into hundres and there is some degree of structure here.

# %%
degree_c = nx.degree_centrality(pre_95_nx)
degree_cs = sorted_map(degree_c)
degree_cs
# Out:
# [(169, 0.6398348813209493),
#  (872, 0.10010319917440659),
#  (192, 0.08565531475748193),
#  (673, 0.06811145510835913),
#  (695, 0.05572755417956656),
#  (48, 0.054695562435500514),
#  (307, 0.054695562435500514),
#  (124, 0.03611971104231166),
#  (895, 0.03611971104231166),
#  (879, 0.03508771929824561),
#  (17, 0.033023735810113516),
#  (46, 0.03095975232198142),
#  (320, 0.03095975232198142),
#  (164, 0.029927760577915373),
#  (382, 0.029927760577915373),
#  (427, 0.029927760577915373),
#  (881, 0.028895768833849325),
#  (887, 0.028895768833849325),
#  (605, 0.026831785345717233),
#  (231, 0.025799793601651185),
#  (460, 0.024767801857585137),
#  (221, 0.021671826625386994),
#  (76, 0.02063983488132095),
#  (204, 0.0020639834881320948),
#  (210, 0.0020639834881320948),
#  (211, 0.0020639834881320948),
#  (219, 0.0020639834881320948),
#  (226, 0.0020639834881320948),
#  (230, 0.0020639834881320948),
#  (245, 0.0020639834881320948),
#  (262, 0.0020639834881320948),
#  (264, 0.0020639834881320948),
#  (267, 0.0020639834881320948),
#  (268, 0.0020639834881320948),
#  (274, 0.0020639834881320948),
#  (296, 0.0020639834881320948),
#  (303, 0.0020639834881320948),
#  (306, 0.0020639834881320948),
#  (317, 0.0020639834881320948),
#  (352, 0.0020639834881320948),
#  (391, 0.0020639834881320948),
#  (392, 0.0020639834881320948),
#  (394, 0.0020639834881320948),
#  (405, 0.0020639834881320948),
#  (411, 0.0020639834881320948),
#  (412, 0.0020639834881320948),
#  (420, 0.0020639834881320948),
#  (438, 0.0020639834881320948),
#  (440, 0.0020639834881320948),
#  (442, 0.0020639834881320948),
#  (449, 0.0020639834881320948),
#  (456, 0.0020639834881320948),
#  (458, 0.0020639834881320948),
#  (472, 0.0020639834881320948),
#  (477, 0.0020639834881320948),
#  (479, 0.0020639834881320948),
#  (480, 0.0020639834881320948),
#  (522, 0.0020639834881320948),
#  (524, 0.0020639834881320948),
#  (534, 0.0020639834881320948),
#  (539, 0.0020639834881320948),
#  (574, 0.0020639834881320948),
#  (582, 0.0020639834881320948),
#  (585, 0.0020639834881320948),
#  (588, 0.0020639834881320948),
#  (598, 0.0020639834881320948),
#  (606, 0.0020639834881320948),
#  (617, 0.0020639834881320948),
#  (622, 0.0020639834881320948),
#  (628, 0.0020639834881320948),
#  (643, 0.0020639834881320948),
#  (645, 0.0020639834881320948),
#  (647, 0.0020639834881320948),
#  (658, 0.0020639834881320948),
#  (675, 0.0020639834881320948),
#  (687, 0.0020639834881320948),
#  (692, 0.0020639834881320948),
#  (702, 0.0020639834881320948),
#  (705, 0.0020639834881320948),
#  (713, 0.0020639834881320948),
#  (752, 0.0020639834881320948),
#  (757, 0.0020639834881320948),
#  (763, 0.0020639834881320948),
#  (780, 0.0020639834881320948),
#  (801, 0.0020639834881320948),
#  (806, 0.0020639834881320948),
#  (845, 0.0020639834881320948),
#  (849, 0.0020639834881320948),
#  (851, 0.0020639834881320948),
#  (869, 0.0020639834881320948),
#  (877, 0.0020639834881320948),
#  (900, 0.0020639834881320948),
#  (901, 0.0020639834881320948),
#  (912, 0.0020639834881320948),
#  (925, 0.0020639834881320948),
#  (928, 0.0020639834881320948),
#  (945, 0.0020639834881320948),
#  (967, 0.0020639834881320948),
#  (37, 0.0010319917440660474),
#  (177, 0.0010319917440660474),
#  (238, 0.0010319917440660474),
#  (342, 0.0010319917440660474),
#  (419, 0.0010319917440660474),
#  (503, 0.0010319917440660474),
#  (648, 0.0010319917440660474),
#  (790, 0.0010319917440660474),
#  (858, 0.0010319917440660474),
#  (873, 0.0010319917440660474),
#  (916, 0.0010319917440660474)]

# %%
pre_95_nx_trim = ml.trim_degrees(pre_95_nx, 12)
len(pre_95_nx_trim.nodes())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-875cfbf69652> in <module>()
# ----> 1 pre_95_nx_trim = ml.trim_degrees(pre_95_nx, 12)
#       2 len(pre_95_nx_trim.nodes())
#
# NameError: name 'pre_95_nx' is not defined

# %%
labels_trimmed = {n:labels[n] for n in pre_95_nx_trim.nodes()}
len(labels_trimmed)
# Out:
# 51

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(14.5,14.5)
nx.draw_graphviz(pre_95_nx_trim,  alpha=0.5, node_size=50, with_labels=True, labels= labels_trimmed)

# %% [markdown]
# Not entirely clear what is happening here, a couple of things stand out. There are all the database-mining, bridge design(!), knowledge-discovery, image-processing, fault diagnosis, information retrieval, as well as quite a lot on the epistemology of learning -- inductive inference, learning from examples, etc. Pattern recognition and decision support are quite important.
# In terms of particular techniques, neural networks, decision trees and interestingly id3 (need to check that one out).  As well as some that would seem odd now -- genetic algorithms, self-organization and fuzzy sets.

# %% [markdown]
# The presence of these particular algorithms -- neural networks, decision tree and id3 would be worth tracking more over time. These techniques might need to be treat in their own right.

# %% [markdown]
# ## From 1995-2000: the emergence of SVM?

# %%
ml_2000 = ml.draw_network_by_years(df,1995, 2000, False, 0)
ml_2000.number_of_nodes()
# Out:
# Calculating co-word matrix
# 2211

# %%
ml.trim_draw_network(ml_2000, 30)
# Out:
# drawing the network ....

# %% [markdown]
# ## 2000-2005

# %%
ml_net_2002 = ml.draw_network_by_years(df, 2000, 2002, False, 0)
# Out:
# Calculating co-word matrix

# %%
ml_net_2004 = ml.draw_network_by_years(df, 2002, 2004, False, 0)
# Out:
# Calculating co-word matrix

# %%
df_sample = df.ix[random.sample(df.index, 5000)]

# %%
ml_net_2008 = ml.draw_network_by_years(df_sample, 2006, 2008, False, 0)
# Out:
# Calculating co-word matrix

# %%
len(ml_net_2008.nodes())
# Out:
# 1827

# %%
ml_net_2008.nodes()[1]
# Out:
# 1

# %%
ml_net_2008_tr = ml.trim_draw_network(ml_net_2008, 30)
# Out:
# drawing the network ....

# %%
ml_net_2010 = ml.draw_network_by_years(df, 2008, 2010, False, 0)

# %%
ml_net_2012 = ml.draw_network_by_years(df, 2010, 2012, False, 0)

# %%
ml_net_2006 = ml.draw_network_by_years(df, 2004, 2006, False, 0)
# Out:
# Calculating co-word matrix

# %%
ml_net_2002_tr = ml.trim_draw_network(ml_net_2002, 20)
# Out:
# drawing the network ....

# %%
ml_net_2004_tr = ml.trim_draw_network(ml_net_2004, 30)
# Out:
# drawing the network ....

# %%
ml_net_2006_tr = ml.trim_draw_network(ml_net_2006, 50)
# Out:
# drawing the network ....

# %% [markdown]
# # Can't remember what this section was meant to do ...

# %%
print(cow_df2.ix[1:4,1:4])
c2 = cow_df2.unstack().copy()
c2.describe()
c2[c2>1].hist(bins=200)
# Out:
#                            decision tree classifiers  sequence alignment  \
# decision tree classifiers                          1                   0
# sequence alignment                                 0                   1
# credit assignment                                  0                   0
#
#                            credit assignment
# decision tree classifiers                  0
# sequence alignment                         0
# credit assignment                          1

# %%
c2.index[1]
G = nx.Graph()
c2.index[0]
[G.add_edge(st[0], st[1], weight =w)  for (st, w) in zip(c2.index, c2)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-12b39f9b196f> in <module>()
#      12
#      13 # edges
# ---> 14 nx.draw_networkx_edges(G,pos,edgelist=elarge,
#      15                     width=6)
#      16 nx.draw_networkx_edges(G,pos,edgelist=esmall,
#
# NameError: name 'elarge' is not defined

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(12.5,12.5)

elarge=[(u,v) for (u,v,d) in G.edges(data=True) if d['weight'] >=2]
esmall=[(u,v) for (u,v,d) in G.edges(data=True) if d['weight'] <=1]

pos=nx.spring_layout(G) # positions for all nodes


# nodes
nx.draw_networkx_nodes(G,pos,node_size=70)

# edges
nx.draw_networkx_edges(G,pos,edgelist=elarge, width=6)
#nx.draw_networkx_edges(G,pos,edgelist=esmall,width=6,alpha=0.5,edge_color='b',style='dashed')

# labels
l = nx.draw_networkx_labels(G,pos,font_size=9,font_family='sans-serif')

# %%
#construct node list for all edges with weight greater than 1
nodel =[[e[0], e[1]] for e in G.edges_iter(data=True) if e[2]['weight'] >2 ]
nodes = list({v for i in nodel for v in i})

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(12.5,12.5)

elarge=[(u,v) for (u,v,d) in G.edges(data=True) if d['weight'] >=2]
#esmall=[(u,v) for (u,v,d) in G.edges(data=True) if d['weight'] <=1]

pos=nx.spring_layout(G) # positions for all nodes


# nodes
nx.draw_networkx_nodes(G,pos,node_size=70, nodelist=nodes)

# edges
nx.draw_networkx_edges(G,pos,edgelist=elarge, width=2)
#nx.draw_networkx_edges(G,pos,edgelist=esmall,width=6,alpha=0.5,edge_color='b',style='dashed')

# labels
l = nx.draw_networkx_labels(G,pos,font_size=9,font_family='sans-serif')

# %% [markdown]
# TBC: look at the development of keywords over later years

# %% [markdown]
# ## 1995- 2000 keywords

# %%
df_pre3 = df[(df.PY > 1995) & (df.PY <= 2000)]
keys_pre_2000 = ml.keyword_counts(df_pre3)
print('There are %s keywords in the 1995-2000 literature' % len(keys_pre_2000))
# Out:
# There are 2274 keywords in the 1995-2000 literature

# %%
cow_df3 = ml.coword_matrix(df_pre2,keys_pre_2000.keys())

# %%
arry = cow_df3.as_matrix()
np.fill_diagonal(arry, 0)
pre_2000_nx = nx.from_numpy_matrix(arry)
cols = cow_df3.columns.tolist()

# %%
nx.draw(pre_2000_nx)

# %%
pre_2000_nx_trim = ml.trim_degrees(pre_2000_nx, 1)
len(pre_2000_nx_trim.nodes())
# Out:
# 223

# %% [markdown]
# ## Digression: Support Vector Machine & Neural Networks over time
#
# I wanted to see how these two techniques have changed over time.

# %%
##beginning of svm

nn_df = ml.keyword_years(df, 'neural network')
nn_df.PY.hist(bins=23, alpha=0.5)
svm_df = ml.keyword_years(df, 'support vector machine')
svm_df.PY.hist(bins=15,alpha=0.7)
dt_df = ml.keyword_years(df, 'decision tree')
dt_df.PY.hist(bins=23)

# %%
svm_df_full = df.ix[svm_df.index]
print(svm_df_full.shape)
svm_keys = ml.keyword_counts(svm_df_full)
print('There are %d keywords associated with "support vector machine"' % len(svm_keys))
# Out:
# (1438, 61)
# There are 3614 keywords associated with "support vector machine"

# %%
svm_keys
# Out:
# {"'hard' and 'soft' variables": 1,
#  '(1)spectrum absorption': 1,
#  '(crm)': 1,
#  '(modis)': 1,
#  '1-d gel electrophoresis': 1,
#  '1-norm': 1,
#  '1-rule': 1,
#  '1-vs-set machine': 1,
#  '3-d human body shapes': 1,
#  '360 degree assessmen': 1,
#  '3d avatars': 1,
#  '3d graphical environment': 1,
#  '3d graphical models': 1,
#  '3d image reconstruction algorithm styling': 1,
#  '3d trunk modeling': 1,
#  '5-ht1a receptor': 1,
#  'a posteriori snr': 1,
#  'a priori snr': 1,
#  'abc-transporter': 1,
#  'abcb1': 1,
#  'abnormality detection': 2,
#  'access control': 1,
#  'accumbens': 1,
#  'acetylcholinesterase': 1,
#  'acetylcholinesterase (ache)': 1,
#  'acid mine drainage': 1,
#  'acid rock drainage': 1,
#  'acoustic emission': 1,
#  'active appearance models': 1,
#  'active compound': 1,
#  'active learning': 10,
#  'active learning (subject-specific adaptation)': 1,
#  'activity of daily living (adl)': 1,
#  'acupuncture': 1,
#  'acute myelogenous leukaemia': 1,
#  'acute promyelocytic leukaemia': 1,
#  'ad-hoc network': 1,
#  'adaboost': 12,
#  'adaboost loss function': 1,
#  'adaboost.m1': 1,
#  'adaptation': 1,
#  'adapted filter banks': 2,
#  'adaptive': 1,
#  'adaptive boosting': 2,
#  'adaptive classifiers': 1,
#  'adaptive network based fuzzy inference system': 1,
#  'adaptive neuro-fuzzy inference system': 1,
#  'adaptive neuro-fuzzy system': 1,
#  'adaptive sketch recognition': 1,
#  'adaptive support vector machine': 2,
#  'additive noise': 3,
#  'adenocarcinoma': 1,
#  'adenosine receptor': 1,
#  'adme-tox': 1,
#  'admet': 2,
#  'admissible kernel': 1,
#  'admixture': 1,
#  'adverse drug events': 1,
#  'aerosol optical depth (aod)': 1,
#  'affinity fingerprint': 1,
#  'affinity measure': 1,
#  'agent-based modeling': 1,
#  'agents': 1,
#  'aggregation': 1,
#  'aggregator': 1,
#  'aging': 2,
#  'agnostic learning': 1,
#  'agonist': 1,
#  'agricultural data': 1,
#  'agriculture': 1,
#  'aho search direction': 1,
#  'air pollutant': 1,
#  'air pollution': 1,
#  'air pollution modeling': 1,
#  'air-core reactor': 1,
#  'akaike information criterion': 1,
#  'algorithm design and analysis': 1,
#  'algorithm efficiency': 1,
#  'algorithms': 2,
#  'allergenic proteins': 1,
#  'alluvial channels': 1,
#  'alternative splicing': 2,
#  'altman': 1,
#  "alzheimer's": 1,
#  "alzheimer's disease": 7,
#  "alzheimer's disease (ad)": 1,
#  'ameriflux': 2,
#  'amino acid': 2,
#  'amino acid composition': 3,
#  'amino acid mutation': 1,
#  'amino acid pairs': 1,
#  'amino acid property': 1,
#  'amino acids property': 1,
#  'amino-acid sequence': 1,
#  'amphibian calls': 1,
#  'amplicon length heterogeneity': 1,
#  'amyloid fibrils': 1,
#  'analog circuit': 2,
#  'analog circuits': 1,
#  'analog to digital conversion': 1,
#  'analog vlsi': 1,
#  'analogy': 1,
#  'analysis of kinematics': 1,
#  'analytic center': 1,
#  'analytical hierarchy process': 1,
#  'and remote sensing': 1,
#  'androgenicity': 1,
#  'animal activity recognition': 1,
#  'ann': 1,
#  'anomaly': 1,
#  'anomaly detection': 5,
#  'answer validation': 1,
#  'ant colony network': 2,
#  'ant colony optimization': 4,
#  'antagonist': 2,
#  'antagonists': 1,
#  'anti-money laundering': 1,
#  'antibody-antigen complexes': 1,
#  'anticancer mechanism': 1,
#  'anticoagulation': 1,
#  'antimicrobial peptides': 1,
#  'antiviral activity': 1,
#  'aphasia': 1,
#  'approximation methods': 1,
#  'approximation performance': 1,
#  'approximation theory': 1,
#  'aquatic weed': 1,
#  'aqueous': 2,
#  'arabian peninsula': 1,
#  'architecture of learning machine': 1,
#  'architectures': 1,
#  'arctic': 1,
#  'area search table': 1,
#  'area under the curve (auc)': 1,
#  'arm impedance': 1,
#  'aromatic amines': 1,
#  'array antenna': 1,
#  'arrhythmia classification': 1,
#  'arrhythmia cordis': 1,
#  'articular cartilage segmentation': 1,
#  'articulation': 1,
#  'artificial bee colony (abc) algorithm': 2,
#  'artificial fish algorithm': 1,
#  'artificial immune algorithm': 2,
#  'artificial immune system': 1,
#  'artificial immune systems': 1,
#  'artificial intelligence': 13,
#  'asl perfusion fmri': 1,
#  'aspect': 1,
#  'assessment': 1,
#  'association rule': 1,
#  'association rule based classifier': 1,
#  'association rule mining': 2,
#  'association rules': 2,
#  'associative classifiers': 2,
#  'asymptotic minimax risk': 1,
#  'atherosclerosis': 1,
#  'atmospheric forecasts': 1,
#  'atom pairs': 1,
#  'atomic parameters': 1,
#  'atp binding': 1,
#  'atp competitive src inhibitors': 1,
#  'atp-binding site': 1,
#  'attack graph': 1,
#  'attribute reduction': 2,
#  'attribute selection': 1,
#  'attributes selecting': 1,
#  'audio databases': 1,
#  'audio thump detection': 1,
#  'audiovisual fusion': 1,
#  'auditory brainstem responses': 2,
#  'auditory cortex': 1,
#  'ault-proneness': 1,
#  'authentication': 2,
#  'authorship identification': 1,
#  'authorship mining': 1,
#  'autistic spectrum disorder': 1,
#  'auto covariance': 1,
#  'auto-correlation': 1,
#  'auto-cross covariance transformation': 1,
#  'autocorrelated data': 1,
#  'autocorrelation': 1,
#  'autocorrelation kernel': 1,
#  'automated diagnosis': 1,
#  'automated feature extraction': 1,
#  'automated modeling': 1,
#  'automated quantification': 1,
#  'automated seizure detection': 2,
#  'automated visual inspection system': 1,
#  'automatic facial image analysis': 1,
#  'automatic folder allocation': 1,
#  'automatic image annotation': 1,
#  'automatic rule generation': 1,
#  'automatic visual inspection': 1,
#  'autonomous navigation': 2,
#  'autoregressive model': 3,
#  'average perceptron': 1,
#  'back-propagation (bp)': 1,
#  'back-propagation network': 1,
#  'back-propagation neural network': 1,
#  'back-propagation neural networks': 2,
#  'backbreak': 1,
#  'backpropagation neural networks': 1,
#  'backpropagation neural networks (bpnns)': 1,
#  'bacterial pathogens': 1,
#  'bag-of-features': 2,
#  'bagging': 6,
#  'banking': 1,
#  'bankruptcy': 3,
#  'bankruptcy prediction': 4,
#  'batch-wise classification': 1,
#  'battery health prognostics': 1,
#  'bayes': 1,
#  'bayes classifier': 1,
#  'bayes covariant discriminant': 1,
#  'bayes formula': 1,
#  'bayes rule': 1,
#  'bayesian': 3,
#  'bayesian adaptation': 1,
#  'bayesian approach': 1,
#  'bayesian belief network': 1,
#  'bayesian classification': 1,
#  'bayesian classifier': 3,
#  'bayesian classifiers': 1,
#  'bayesian data integration': 1,
#  'bayesian filter': 1,
#  'bayesian inference': 1,
#  'bayesian learning': 1,
#  'bayesian model': 1,
#  'bayesian modeling': 2,
#  'bayesian network': 3,
#  'bayesian networks': 4,
#  'bayesian neural network': 1,
#  'bayesian theorem': 1,
#  'bayesian updating method': 1,
#  'bch coding': 1,
#  'bcs': 1,
#  'bddcs': 1,
#  'bearing fault diagnosis': 1,
#  'belief networks': 1,
#  'bench-mark window': 1,
#  'benchmark': 1,
#  'benchmarking': 1,
#  'benders decomposition': 1,
#  'best linear unbiased prediction': 1,
#  'beta-barrels': 1,
#  'beta-lactamase': 1,
#  'beta-sheet formation': 1,
#  'biased support vector machine': 1,
#  'big data': 1,
#  'bigrams': 1,
#  'bilinear constraints': 1,
#  'binary classification': 10,
#  'binary classifier': 1,
#  'binary decision': 1,
#  'binary particle swarm optimization': 1,
#  'binary to multi-class classifiers': 1,
#  'binaural interaction': 1,
#  'binding affinity': 1,
#  'binding affinity prediction': 1,
#  'binding peptides prediction': 1,
#  'binding site prediction': 1,
#  'binning': 1,
#  'biochemical oxygen demand': 1,
#  'biodiversity': 1,
#  'biofuel (biodiesel, bioethanol, ethanol-gasoline fuel)': 1,
#  'bioimage analysis': 1,
#  'bioinformatics': 24,
#  'biological feature selection': 1,
#  'biological features': 1,
#  'biological sequence data': 1,
#  'biological text': 1,
#  'biomarker': 3,
#  'biomarker discovery': 1,
#  'biomarkers': 3,
#  'biomass': 2,
#  'biomedical electronics': 1,
#  'biomedical information retrieval': 1,
#  'biomedical mri': 1,
#  'biomedical text classification': 1,
#  'biometric': 1,
#  'biometric score fusion': 1,
#  'biometrics': 2,
#  'biomimetic pattern recognition': 1,
#  'biophysiochemical properties': 1,
#  'biosensors': 1,
#  'biostatistics': 1,
#  'biovolume': 1,
#  'bipolar disorder': 1,
#  'bird calls': 1,
#  'birth defects': 1,
#  'bis-piperazines': 1,
#  'bit correct ratio (bcr)': 2,
#  'bk-channels activity': 1,
#  'black box': 1,
#  'black box system': 1,
#  'black tea': 1,
#  'blackout': 1,
#  'blasting': 3,
#  'blind source separation': 1,
#  'blizzard': 1,
#  'blogs': 1,
#  'blood and bone marrow cell': 1,
#  'blood brain barrier': 1,
#  'blosum62': 1,
#  'blosum62 substitution matrix': 1,
#  'boiler': 1,
#  'bolted': 1,
#  'bond rating prediction': 2,
#  'boolean function': 1,
#  'boosting': 11,
#  'boosting algorithm': 1,
#  'bootstrap': 1,
#  'bootstrapping': 1,
#  'borderline': 1,
#  'bouligand influence function': 1,
#  'box-counting method': 1,
#  'bp neural network': 1,
#  'bpnn': 1,
#  'bradley-terry model': 1,
#  'brain computer interface': 1,
#  'brain computer interfaces': 1,
#  'brain computer interfaces (bcis)': 1,
#  'brain image analysis': 2,
#  'brain morphometry': 1,
#  'brain segmentation': 2,
#  'brain-computer interface': 2,
#  'branching competitive learning': 1,
#  'branching structure': 1,
#  'breakdown point': 1,
#  'breast cancer': 6,
#  'breast cancer diagnosis': 5,
#  'breast cancer prognosis': 1,
#  'breast cancer resistance protein (bcrp)': 1,
#  'breast imaging': 1,
#  'breath': 1,
#  'brine': 1,
#  'broiler': 1,
#  'budget algorithm': 1,
#  'building type': 1,
#  'bullwhip effect': 1,
#  'bunsetsu elimination': 1,
#  'bus travel time': 1,
#  'business development': 1,
#  'business failure prediction': 1,
#  'business intelligence': 1,
#  'c-src': 1,
#  'c4.5': 1,
#  'c4.5 decision tree': 2,
#  'cable stayed bridge': 1,
#  'cache replacement': 1,
#  'cad': 1,
#  'calcium channel antagonists': 1,
#  'calculation': 1,
#  'calpain': 1,
#  'cancer': 3,
#  'cancer classification': 2,
#  'cancer diagnosis': 1,
#  'cancer prognosis': 1,
#  'cancer treatment': 1,
#  'cancer-causing variants': 1,
#  'canopy': 1,
#  'capacity control': 1,
#  'capillary lc/ms/ms': 1,
#  'captcha': 1,
#  'carbohydrate binding sites': 1,
#  'carbon': 1,
#  'carcinogenicity': 1,
#  'card-sharing': 1,
#  'cardiac cycle': 1,
#  'cardiovascular disease': 1,
#  'carrier protein domain, inspect': 1,
#  'cart': 1,
#  'cascade classifier': 1,
#  'cascaded classifier': 1,
#  'cascaded evaluation': 1,
#  'case simulation': 1,
#  'case-based reasoning': 2,
#  'cat swarm optimization': 1,
#  'catalytic residue prediction': 1,
#  'catalytic site prediction': 1,
#  'cath': 1,
#  'cb513': 1,
#  'cell cycle kinases': 1,
#  'cell density': 1,
#  'cellular automata': 1,
#  'cellular neural network': 1,
#  'cement soil': 1,
#  'central auditory processing disorder (capd)': 1,
#  'central nervous system': 1,
#  'centre of a polytope': 1,
#  'centroid': 1,
#  'centroid based approach': 1,
#  'centroid based dimensionality reduction': 1,
#  "cereals' foliar diseases": 1,
#  'cervical cancer': 1,
#  'change detection': 4,
#  'change point': 1,
#  'channel': 1,
#  'channel equalization': 1,
#  'channel estimation': 1,
#  'channelized hotelling observer (cho)': 1,
#  'chaos': 1,
#  'chaos games representation': 1,
#  'chaotic time series prediction': 1,
#  'character recognition': 1,
#  'charge state': 1,
#  'chemical composition': 2,
#  'chemical shift': 1,
#  'chemical structure': 1,
#  'cheminformatics': 2,
#  'chemo & bioinformatics': 1,
#  'chemometrics': 2,
#  'chernobyl': 1,
#  'chinese female facial beauty': 1,
#  'chinese knowledge and information processing': 2,
#  'chinese sentiment analysis': 1,
#  'chinese web filtering': 1,
#  'chlor-alkali': 1,
#  'chlorophyll': 1,
#  'chlorophyll-a': 1,
#  'choice models': 1,
#  'cholesky factorization': 1,
#  "chou's pseudo amino acid composition": 1,
#  'cirrhosis': 1,
#  'citation screening': 1,
#  'cities': 1,
#  'class association rules': 1,
#  'class imbalance': 2,
#  'class imbalance learning (cil)': 1,
#  'class of separability': 2,
#  'class variance matrices': 1,
#  'class-imbalanced learning': 1,
#  'class-incremental learning': 1,
#  'classiffication': 1,
#  'classification': 118,
#  'classification accuracy': 1,
#  'classification analysis': 1,
#  'classification and classifier design': 1,
#  'classification and multi-classification problems': 1,
#  'classification and regression tree': 1,
#  'classification libsupport vector machine optimization regression support vector machine support vector machine': 1,
#  'classification model': 1,
#  'classification of earthquake images': 1,
#  'classification problems': 1,
#  'classification rate': 1,
#  'classification rules': 1,
#  'classification techniques': 2,
#  'classification tree': 1,
#  'classification trees': 5,
#  'classifier': 6,
#  'classifier combination': 1,
#  'classifier complexity reduction': 1,
#  'classifier ensemble': 1,
#  'classifier ensembles': 1,
#  'classifier fusion': 3,
#  'classifier optimization': 1,
#  'classifiers': 5,
#  'clay': 1,
#  'cleavage site': 1,
#  'climatic region': 1,
#  'clinical data': 1,
#  'clinical data representation': 1,
#  'clinical decision support system': 1,
#  'clinical decision support system (cdss)': 1,
#  'clinical screening': 1,
#  'clinical trial enrichment': 1,
#  'clock': 1,
#  'cloud detection': 1,
#  'cloud physics lidar (cpl)': 1,
#  'cluster': 1,
#  'cluster analysis': 3,
#  'cluster-merging': 1,
#  'clustered microcalcifications': 1,
#  'clustering': 12,
#  'clustering algorithm': 1,
#  'clustering k-nn (k-nearest neighbor) support vector machine (cksupport vector machine)': 1,
#  'clustering methods': 1,
#  'clustering-launched classification': 2,
#  'cme': 2,
#  'cmes prediction': 1,
#  'co concentration': 1,
#  'co-evolution': 1,
#  'co-training': 1,
#  'coagulation': 1,
#  'coal and gas outburst': 1,
#  'coal mine gas': 1,
#  'coarse-to-fine classifier': 1,
#  'code division multiple access': 1,
#  'coding': 1,
#  'cognitive architecture': 1,
#  'cognitive radio': 1,
#  'cognitive style': 1,
#  'coherence': 1,
#  'coincidence of the solutions': 1,
#  'collaboration': 1,
#  'collagen': 1,
#  'collective behavior': 1,
#  'colonoscopy': 1,
#  'color adjustment': 1,
#  'color coherence vector (ccv)': 1,
#  'color deconvolution': 1,
#  'color formulation': 1,
#  'color histogram': 1,
#  'color image segmentation': 1,
#  'color separation': 1,
#  'color space': 1,
#  'color-space transformation': 1,
#  'colorectal cancer': 2,
#  'colour': 2,
#  'column generation': 1,
#  'combinational clustering': 1,
#  'combinatorial optimization': 1,
#  'combined classifier': 1,
#  'combined kernels': 1,
#  'combustion optimization': 1,
#  'common spatial pattern filter': 1,
#  'communication network': 1,
#  'communication networks': 1,
#  'compact architectures': 1,
#  'compact support vector machine support vector machine': 1,
#  'comparative modeling': 1,
#  'comparative molecular moment descriptors': 1,
#  'comparison': 2,
#  'competition': 1,
#  'competitive learning network': 1,
#  'compiler optimization': 1,
#  'completed local binary pattern (clbp)': 1,
#  'complex protein mixtures': 1,
#  'complex support vector machine': 1,
#  'complex systems': 1,
#  'complex traits': 1,
#  'component': 1,
#  'component classifier': 1,
#  'component: proteins': 1,
#  'composite kernel': 1,
#  'composite kernels': 1,
#  'compound identification': 1,
#  'compressed convex hull': 1,
#  'compressive sampling': 1,
#  'computational biology': 3,
#  'computational complexity': 2,
#  'computational cost': 1,
#  'computational efficiency': 1,
#  'computational geometry': 2,
#  'computational intelligence': 5,
#  'computational modeling': 1,
#  'computational screening': 1,
#  'computational semantics': 1,
#  'computed tomography': 1,
#  'computer aided diagnosis': 3,
#  'computer aided diagnostics (cad)': 1,
#  'computer aided drug design': 3,
#  'computer aided test and diagnosis': 1,
#  'computer assisted diagnosis': 1,
#  'computer forensic': 1,
#  'computer numerical control': 1,
#  'computer vision': 2,
#  'computer-aided analysis': 1,
#  'computer-aided detection': 2,
#  'computer-aided detection cad': 1,
#  'computer-aided diagnosis': 8,
#  'computer-assisted drug design': 2,
#  'computer-assisted sperm analysis': 1,
#  'computerised diagnosis': 1,
#  'concealed information test (cit)': 1,
#  'concentration estimation': 1,
#  'conceptual reduction': 1,
#  'concordance index': 1,
#  'concrete structural component': 1,
#  'condition information': 1,
#  'condition monitoring': 1,
#  'condition residual life': 1,
#  'conditional access': 1,
#  'conditional learning': 1,
#  'conditional random field (crf)': 1,
#  'conditional random fields': 4,
#  'conditional simulation': 1,
#  'conductometric immunosensor': 1,
#  'conformal prediction': 1,
#  'confusion matrix': 1,
#  'conic programming': 1,
#  'conjoint triad feature': 1,
#  'conjugate duality under uncertainty': 1,
#  'consensus model': 1,
#  'conservation reserve program': 1,
#  'consistency': 1,
#  'constrained nonlinear system': 1,
#  'constrained similarity measure': 1,
#  'constraints': 1,
#  'constructed treatment wetland': 1,
#  'construction safety': 1,
#  'constructive algorithm': 1,
#  'contact map prediction': 1,
#  'content-based image retrieval': 2,
#  'content-based image retrieval (cbir)': 2,
#  'content-based indexing': 1,
#  'context-aware applications': 1,
#  'context-dependent kernels': 1,
#  'context-free kernels': 1,
#  'continuous': 1,
#  'continuous health monitoring': 1,
#  'continuous optimization': 4,
#  'continuous state space': 1,
#  'continuous-density hidden markov models (cdhmms)': 1,
#  'control chart': 1,
#  'control charts': 1,
#  'convergence': 1,
#  'convex analysis': 1,
#  'convex hull': 3,
#  'convex layer': 1,
#  'convex optimization': 5,
#  'convex polyhedron': 1,
#  'convex polytope': 1,
#  'convex risk minimization': 1,
#  'convolution': 1,
#  'convolutional codes': 1,
#  'cooperative coevolution': 1,
#  'cooperative learning': 1,
#  'coordinate descent': 1,
#  'coordinate metrology': 1,
#  'core generator': 1,
#  'core vector machine': 1,
#  'core vector machines': 1,
#  'coronary artery disease': 1,
#  'coronary disease': 1,
#  'corporate credit rating': 1,
#  'corporate governance': 1,
#  'corporate rating': 1,
#  'correction': 1,
#  'correlated mutation analysis': 1,
#  'correlation analysis': 1,
#  'correlation coefficient': 1,
#  'correlation optimization warping': 1,
#  'correlation structure': 1,
#  'correlations': 1,
#  'corrosion prediction': 1,
#  'cortical thickness': 1,
#  'cost estimation': 1,
#  'cost sensitive support vector machine': 1,
#  'cost-sensitive learning': 1,
#  'cost-sensitive support vector machine (sc-support vector machine)': 1,
#  'coupling': 1,
#  'covariate shift': 1,
#  'covering algorithm': 1,
#  'cpar': 1,
#  'cpg': 1,
#  'cpg island': 1,
#  'cpg islands (cgis)': 1,
#  'cpt': 1,
#  'crack localization': 1,
#  'crackle detection': 1,
#  'crater detection': 1,
#  'credit assessment': 1,
#  'credit default swaps': 1,
#  'credit derivatives': 1,
#  'credit rating analysis': 2,
#  'credit risk': 4,
#  'credit risk analysis': 1,
#  'credit scoring': 5,
#  'credit scoring model': 1,
#  'credit screening': 1,
#  'creep': 1,
#  'crf01_ae': 1,
#  'crm': 1,
#  'cross validation': 3,
#  'cross-correlation': 1,
#  'cross-document structure theory (cst)': 1,
#  'cross-market analysis': 1,
#  'cross-validation': 4,
#  'crosswise propagation (cp)': 1,
#  'ct': 1,
#  'ctl epitopes': 1,
#  'cuda': 1,
#  'currency crises': 1,
#  'curvature discrimination': 1,
#  'customer': 1,
#  'customer churn': 1,
#  'customer data classification': 1,
#  'customer relationship management': 1,
#  'cut': 1,
#  'cyclic alternating pattern': 1,
#  'cylindricity evaluation': 1,
#  'cysteine knot motif': 1,
#  'cytochrome p-450': 1,
#  'cytochrome p450': 2,
#  'cytochrome p450 enzyme': 1,
#  'daily peak load': 1,
#  'dais data': 1,
#  'damage assessment': 1,
#  'damage classification': 1,
#  'dark field microscopy': 1,
#  'data analysis': 1,
#  'data classification': 1,
#  'data clustering': 2,
#  'data corruption': 1,
#  'data distribution': 1,
#  'data envelope analysis (dea)': 1,
#  'data fusion': 3,
#  'data grid models': 1,
#  'data imbalance': 1,
#  'data incompleteness': 1,
#  'data intelligence': 1,
#  'data linkage': 1,
#  'data merger': 1,
#  'data mining': 50,
#  'data mining (dm)': 1,
#  'data mining preprocessing': 1,
#  'data noise': 1,
#  'data preprocessing': 2,
#  'data representations': 1,
#  'data selection': 1,
#  'data transformation': 1,
#  'data visualization': 1,
#  'data-driven': 1,
#  'databank accession number': 1,
#  'dbscan': 1,
#  'ddos dataset': 1,
#  'death cell discrimination': 1,
#  'debris flow': 1,
#  'decision based fusion and classifier ensemble': 1,
#  'decision directed acyclic graph': 1,
#  'decision feedback support vector machine': 1,
#  'decision fusion': 1,
#  'decision support': 3,
#  'decision support system': 3,
#  'decision support systems': 6,
#  'decision surface mapping': 2,
#  'decision tree': 27,
#  'decision tree algorithm': 1,
#  'decision tree induction': 1,
#  'decision trees': 19,
#  'decision trees (dt)': 1,
#  'decision trees classifier': 1,
#  'decision visualization': 1,
#  'decision with reject option': 1,
#  'decision-based fusion model': 1,
#  'decision-tree': 1,
#  'decoding': 1,
#  'decomposition': 2,
#  'decomposition method': 2,
#  'decomposition methods': 1,
#  'defect detection': 1,
#  'defect prediction': 1,
#  'defect signal': 1,
#  'defect-prone modules': 1,
#  'degradation': 1,
#  'delaunay triangulation': 1,
#  'denial of service': 1,
#  'denial of service (dos)': 1,
#  'denoised p300': 1,
#  'denoising': 1,
#  'denox catalyst': 1,
#  'density clustering': 1,
#  'density level detection': 1,
#  'density-based clustering algorithm': 1,
#  'dental x-rays': 1,
#  'depression': 1,
#  'derivative-free optimization': 1,
#  'dermoscopy': 1,
#  'design of experiments (doe)': 1,
#  'detection': 1,
#  'detection and classification': 1,
#  'detection rate (dr)': 1,
#  'detrending': 1,
#  'diabetes mellitus': 1,
#  'diabetic nephropathy': 1,
#  'diabetic retinopathy': 2,
#  'diagnoses': 1,
#  'diagnosis': 5,
#  'diagnosis diaseses': 1,
#  'diagnosis of myocardial infarction': 1,
#  'diagnostic algorithm': 2,
#  'diagnostic classification': 1,
#  'diagnostic measures': 1,
#  'diagnostic prediction': 1,
#  'diet': 1,
#  'different error costs': 2,
#  'differential evolution': 2,
#  'differential evolution algorithm (de)': 1,
#  'differential expression': 1,
#  'differential protein expression': 1,
#  'diffuse large b-cell lymphoma': 1,
#  'diffuse lung disease': 1,
#  'digital cervigrams': 1,
#  'digital elevation model (dem)': 1,
#  'digital forensics': 1,
#  'digital imaging': 1,
#  'digital tv': 1,
#  'digital video broadcasting': 1,
#  'digital watermarking': 1,
#  'dihydrofolate reductase inhibitor': 1,
#  'dimension reduction': 1,
#  'dimensional reduction': 1,
#  'dimensionality reduction': 5,
#  'dipeptide composition': 1,
#  'direct inverse control': 1,
#  'direct kernel methods': 1,
#  'direct marketing': 2,
#  'directed acyclic graphs': 1,
#  'directed evolution': 2,
#  'disambiguation': 1,
#  'disclosure': 1,
#  'discordant tree topologies': 1,
#  'discrete': 2,
#  'discrete cosine transform (dct)': 1,
#  'discrete support vector machine': 2,
#  'discrete vector field': 1,
#  'discrete wavelet transform': 1,
#  'discrete wavelet transform (dwt)': 3,
#  'discrete-dipole approximation': 1,
#  'discretization': 2,
#  'discriminant': 1,
#  'discriminant analysis': 2,
#  'discriminant decision': 1,
#  'discriminant function': 1,
#  'discrimination': 1,
#  'discrimination analysis': 1,
#  'discriminative classifiers': 1,
#  'discriminative learning': 1,
#  'discriminative neighborhood preserving constraints': 1,
#  'disease classification': 1,
#  'disease diagnosis': 1,
#  'disease risk prediction': 1,
#  'diseases': 1,
#  'diseases classification': 1,
#  'displacement': 1,
#  'disruption predictor simulator': 1,
#  'dissimilarity based classifiers': 1,
#  'dissolved gas analysis(dga)': 1,
#  'dissolved gases analysis': 1,
#  'distance': 3,
#  'distance measure': 1,
#  'distance measures': 1,
#  'distillation column': 1,
#  'distortion correction': 1,
#  'distributed classification': 1,
#  'distributed computing': 2,
#  'distributed decision making': 1,
#  'distributed machine learning': 1,
#  'distributed quad-lut (dq-lut)': 1,
#  'distribution difference': 1,
#  'disulfide bridges': 2,
#  'diversity': 2,
#  'divisional training': 1,
#  'dna': 1,
#  'dna chip': 1,
#  'dna mapping rules': 1,
#  'dna methylation': 1,
#  'dna microarray': 1,
#  'dna microarrays': 1,
#  'dna or rna-binding site prediction': 1,
#  'dna sequence analysis': 1,
#  'dna-binding protein': 1,
#  'dna-binding residues': 1,
#  'docking': 2,
#  'document categorization': 1,
#  'document classification': 5,
#  'document layout analysis': 1,
#  'document mining': 1,
#  'document object model (dom)': 1,
#  'document recognition': 1,
#  'document understanding': 1,
#  'domain driven data mining(d3m)': 1,
#  'domain intelligence': 1,
#  'domain knowledge': 2,
#  'domain knowledge utilization': 1,
#  'domain of applicability': 3,
#  'doppler heart sounds': 1,
#  'dos/ddos': 2,
#  'downscaling': 1,
#  'drayage': 1,
#  'driver behavior': 1,
#  'driver fatigue': 1,
#  'drosophila': 1,
#  'drowsine': 1,
#  'drug activity': 1,
#  'drug design': 3,
#  'drug discovery': 5,
#  'drug safety': 2,
#  'drug target': 2,
#  'drug targets': 1,
#  'drug-target interaction': 1,
#  'drugability': 1,
#  'dss': 1,
#  'dual membership values': 1,
#  'dual-tree complex wavelet transform': 1,
#  'duality': 1,
#  'duality theory': 1,
#  'duplicate samples': 1,
#  'dynamic analysisx': 1,
#  'dynamic evolving fuzzy inference system': 1,
#  'dynamic interacting network analysis': 1,
#  'dynamic modeling': 1,
#  'dynamic security assessment': 1,
#  'dynamic systems': 1,
#  'dynamic time alignment': 1,
#  'dynamic time warping': 2,
#  'dynamical system': 1,
#  'e-learning platform': 1,
#  'e-mail': 2,
#  'e-mail classification': 1,
#  'earning announcements': 1,
#  'earthquake prediction': 1,
#  'earthworm microarray': 1,
#  'ecg arrhythmia': 1,
#  'ecg-derived respiration (edr)': 1,
#  'ecoinformatics': 1,
#  'economic growth': 1,
#  'ecosystem community patterns': 1,
#  'eddy current testing (ect)': 1,
#  'eddy currents': 1,
#  'eeg': 2,
#  'efficient set': 1,
#  'effluent standards': 1,
#  'egovernment': 1,
#  'egypt': 1,
#  'eigenvalues': 2,
#  'eigenvalues and eigenvectors': 1,
#  'eigenvectors': 1,
#  'elastic net': 1,
#  'elderly': 1,
#  'electrical capacitance tomography': 3,
#  'electrical load forecasting': 1,
#  'electricity reference price forecasting': 1,
#  'electro-optic modulation': 1,
#  'electrocardiogram': 1,
#  'electrochemical immunoassay': 1,
#  'electroencephalogram': 3,
#  'electroencephalogram (eeg)': 2,
#  'electroencephalogram signals': 1,
#  'electroencephalography': 1,
#  'electrolysis': 1,
#  'electromyography (emg)': 2,
#  'electron-ion interaction potential': 1,
#  'electronic nose': 3,
#  'ellipsoid method': 1,
#  'embedded strain gauge sensor': 1,
#  'emergent computing': 1,
#  'emission line stars': 1,
#  'emotion': 2,
#  'emotion semantics': 1,
#  'emphysema': 1,
#  'empirical model': 1,
#  'empirical process theory': 1,
#  'empirical risk minimization': 1,
#  'empirical risk minimization(erm)': 1,
#  'empirical validation': 1,
#  'employee churn': 1,
#  'encoding scheme': 2,
#  'endocardial electrograms': 1,
#  'endocardial signals': 1,
#  'energy analysis': 1,
#  'energy to shannon entropy ratio': 1,
#  'engine torque': 1,
#  'enhanced multi class support vector machine (emcsupport vector machine)': 1,
#  'ensemble': 6,
#  'ensemble approach': 1,
#  'ensemble based method': 1,
#  'ensemble classification': 1,
#  'ensemble classifier': 1,
#  'ensemble classifiers': 2,
#  'ensemble feature selection': 1,
#  'ensemble learning': 4,
#  'ensemble method': 2,
#  'ensemble methods': 5,
#  'ensemble network': 1,
#  'ensemble of classifiers': 4,
#  'ensemble of classifiers, support vector machine': 1,
#  'ensemble of support vector machine': 2,
#  'ensembles': 2,
#  'ensembles of classifiers': 1,
#  'entity resolution': 1,
#  'entrepreneurial intentions': 1,
#  'entropy': 2,
#  'enumeration': 1,
#  'environment': 1,
#  'environmental and economic systems': 1,
#  'environmental modelling': 1,
#  'enzyme': 1,
#  'enzyme function prediction': 1,
#  'enzymes': 1,
#  'eog': 1,
#  'epilepsy': 4,
#  'epsilon-insensitive bound': 1,
#  'epst': 1,
#  'eqp(elongated quinary pattern)': 1,
#  'equalization': 1,
#  'equipment malfunctions': 1,
#  'eress': 1,
#  'error analysis': 1,
#  'error bar': 3,
#  'error bars': 1,
#  'error bounds': 1,
#  'error correcting output codes': 2,
#  'error correcting output codes (ecoc)': 1,
#  'error correction codes': 1,
#  'error estimation': 3,
#  'error-correcting output codes': 1,
#  'errors': 1,
#  'erythemato-squamous': 1,
#  'erythemato-squamous diseases': 1,
#  'escherichia coli promoter gene sequence dataset': 1,
#  'espi': 1,
#  'essential protein': 1,
#  'estimation': 1,
#  'estrogen receptor-beta': 1,
#  'estrogen-like chemicals': 1,
#  'eucalyptus globulus': 1,
#  'eukaryotic gene regulation': 1,
#  'evaluation': 5,
#  'evapotranspiration (et)': 1,
#  'event detection': 1,
#  'event extraction': 1,
#  'evolution strategies': 2,
#  'evolutionaly algorithm': 1,
#  'evolutionary algorithms': 7,
#  'evolutionary computing': 1,
#  'evolutionary conservation': 1,
#  'evolutionary information descriptors': 1,
#  'evolutionary programming': 1,
#  'evolutionary strategy': 1,
#  'evolutionary support vector machine': 1,
#  'exact algorithms': 1,
#  'exact nonparametric statistics': 1,
#  'exchange method': 1,
#  'experimentation': 2,
#  'expert diagnosis system': 1,
#  'expert systems': 4,
#  'explanation-based learning': 1,
#  'exponential convergence': 1,
#  'exponential smoothing method': 1,
#  'expressed protein sequence tags': 1,
#  'extended binary phase shift keying': 1,
#  'extreme learning machine': 1,
#  'extreme learning machine (elm)': 1,
#  'extreme learning machines': 1,
#  'extreme machine learning (elm)': 2,
#  'exudate': 2,
#  'eye movements': 1,
#  'f-test': 1,
#  'face detection': 4,
#  'face identification': 1,
#  'face recognition': 6,
#  'face verification': 1,
#  'facial action coding': 2,
#  'facial action coding system (facs)': 1,
#  'facial action unit': 1,
#  'facial beauty classification': 1,
#  'facial expression': 3,
#  'facial expression classification': 1,
#  'facial expression recognition': 4,
#  'facial expression shape model (fesm)': 1,
#  'facial expressions': 2,
#  'facial recognition': 1,
#  'factor xa (fxa)': 1,
#  'factorial experiment': 1,
#  'false alarm rate (far)': 1,
#  'false positive reduction': 1,
#  'fast error estimation': 1,
#  'fast support vector regression': 1,
#  'fat-shattering dimension': 1,
#  'fathead minnow': 1,
#  'fatigue crack': 1,
#  'fault classification': 2,
#  'fault detection': 1,
#  'fault detection and identification': 1,
#  'fault diagnosis': 15,
#  'fault diagnosistic': 1,
#  'fault dictionary': 1,
#  'fault identification': 1,
#  'fault prediction': 2,
#  'feacture selelction': 1,
#  'feature': 1,
#  'feature based morphometry': 1,
#  'feature construction': 1,
#  'feature extraction': 16,
#  'feature extraction and selection': 2,
#  'feature interactions': 1,
#  'feature mapping': 1,
#  'feature ranking': 1,
#  'feature reduction': 2,
#  'feature scaling': 1,
#  'feature selection': 69,
#  'feature selection algorithm': 1,
#  'feature selection. pattern recoamtion': 1,
#  'feature significance': 1,
#  'feature subset selection': 1,
#  'feature vector': 1,
#  'feature vector selection': 1,
#  'feature weight': 1,
#  'feature weighting': 2,
#  'features': 1,
#  'features extraction': 1,
#  'feed forward neural network': 1,
#  'feed-forward neural networks': 3,
#  'feedback': 1,
#  'feedforward neural networks': 1,
#  'female labor force participation': 2,
#  'ferritic steels': 1,
#  'field programmable gate array': 1,
#  'field programmable gate array (fpga)': 1,
#  'field-programmable gate array (fpga)': 1,
#  'file carving': 1,
#  'file fragment classification': 1,
#  'film editing/making': 1,
#  'filter banks': 1,
#  'filtering': 1,
#  'financial decision support': 1,
#  'financial forecasting': 1,
#  'financial prediction': 1,
#  'financial ratio': 1,
#  'financial time series': 1,
#  'financial time series forecasting': 1,
#  'fingerprinting': 1,
#  'fingerprints': 1,
#  'finite element': 1,
#  'fire smoke detection': 1,
#  'fish': 1,
#  'fisher discriminant analysis': 1,
#  'fisher discriminant analysis(fda)': 1,
#  'fisher linear discriminant': 2,
#  'fisher scores': 1,
#  "fisher's linear discriminant (fld)": 1,
#  'flare': 1,
#  'flood forecasting': 2,
#  "florida's red tides": 1,
#  'flow regime identification': 3,
#  'flowcam': 1,
#  'fluid filled cable': 1,
#  'fluorescence microscopy': 1,
#  'fluorescence two-dimensional difference gel electrophoresis': 1,
#  'flyrock': 1,
#  'fmri': 6,
#  'fmri prediction': 1,
#  'fmri preprocessing': 1,
#  'fold assignment': 1,
#  'fold recognition': 1,
#  'folksonomy': 1,
#  'food safety machine vision inspection': 1,
#  'forecast': 2,
#  'forecasting': 8,
#  'forecasting performance': 1,
#  'foreground-background segmentation': 1,
#  'forensic document analysis': 1,
#  'forest fuel': 1,
#  'forward kinematics': 1,
#  'fourier descriptor (fd)': 1,
#  'fourier transform infrared spectroscopy': 1,
#  'fourier transforms': 1,
#  'fractal dimension': 1,
#  'fractals': 1,
#  'fragile x syndrome': 1,
#  'fragments': 1,
#  'fragrance property': 1,
#  'frames': 3,
#  'framework': 1,
#  'frameworks': 1,
#  'frank-wolfe optimization': 1,
#  'fraud detection': 1,
#  'freight': 1,
#  'frequency response': 1,
#  'freshwater ecosystem': 1,
#  'frontal': 1,
#  'fruit vinegar': 1,
#  'fsm-adm': 1,
#  'fully mechanized mining face': 1,
#  'fully-mechanized coal driving workface': 1,
#  'function': 1,
#  'function annotation': 1,
#  'function approximation': 4,
#  'function regression': 3,
#  'functional consequences': 1,
#  'functional gene network': 1,
#  'functional genomic': 1,
#  'functional genomics': 1,
#  'functional magnetic resonance imaging': 5,
#  'functional magnetic resonance imaging (fmri)': 2,
#  'functional magnetic resonance imaging data analysis': 5,
#  'functional networks': 1,
#  'functional residues': 1,
#  'fungicidal activity': 1,
#  'fusion': 2,
#  'fusion of classifiers': 1,
#  'fuzzy': 2,
#  'fuzzy association rules': 1,
#  'fuzzy c-means': 2,
#  'fuzzy c-means clustering': 2,
#  'fuzzy class label': 1,
#  'fuzzy classifier': 1,
#  'fuzzy clustering': 1,
#  'fuzzy controller': 1,
#  'fuzzy data classification': 1,
#  'fuzzy discretization': 1,
#  'fuzzy expert system': 1,
#  'fuzzy logic': 4,
#  'fuzzy membership': 2,
#  'fuzzy model': 1,
#  'fuzzy modeling': 1,
#  'fuzzy precompensator': 1,
#  'fuzzy rule based systems': 1,
#  'fuzzy support vector machine': 6,
#  'fuzzy support vector machine (fsupport vector machine)': 1,
#  'fuzzy support vector machine learning': 1,
#  'fuzzy systems': 1,
#  'fuzzy theory': 1,
#  'fuzzy-rough feature selection': 1,
#  'fuzzy-support vector machine mixture models (fsmms)': 1,
#  'fx carry': 1,
#  'g protein-coupled receptor': 1,
#  'gabor filter': 1,
#  'gabor wavelet': 1,
#  'gait': 1,
#  'gait classification': 1,
#  'gait event detection': 1,
#  'galapagos islands': 1,
#  'gamma-secretase inhibitors': 1,
#  'gamma-turn prediction': 1,
#  'gas': 1,
#  'gas emission': 1,
#  'gas identification': 1,
#  'gas sensor': 1,
#  'gaussian approximation': 1,
#  'gaussian circuit': 1,
#  'gaussian kernel': 3,
#  'gaussian mixture models': 1,
#  'gaussian mixtures': 1,
#  'gaussian process': 6,
#  'gaussian processes': 3,
#  'gaussian radial basis function (rbf) kernel': 1,
#  'gearbox fault detection': 1,
#  'gender classification': 1,
#  'gender identification': 1,
#  'gender recognition': 2,
#  'gene': 2,
#  'gene expression': 6,
#  'gene expression analysis': 1,
#  'gene expression classification': 2,
#  'gene expression data': 1,
#  'gene expression data analysis': 1,
#  'gene expression pattern': 1,
#  'gene expression profile': 1,
#  'gene mention recognition': 2,
#  'gene normalisation': 1,
#  'gene ontology': 1,
#  'gene selection': 5,
#  'gene-environment networks': 1,
#  'gene-gene interaction': 2,
#  'general discriminant analysis': 1,
#  'general linear model': 1,
#  'general regression neural network': 1,
#  'generalization': 4,
#  'generalization ability': 1,
#  'generalization accuracy': 1,
#  'generalization bound': 1,
#  'generalization error': 1,
#  'generalization performance': 2,
#  'generalized additive models': 2,
#  'generalized eigenvalue problem': 1,
#  'generalized eigenvalues': 2,
#  'generalized eigenvalues problem': 1,
#  'generalized gamma': 1,
#  'generalized information table': 1,
#  'generalized linear mixed models': 1,
#  'generalized linear models': 2,
#  'generalized semi-infinite programming': 1,
#  'generative classifiers': 1,
#  'generic model control (gmc)': 1,
#  'genes': 1,
#  'genetic algorithm': 22,
#  'genetic algorithm (ga)': 3,
#  'genetic algorithms': 18,
#  'genetic algorithms (gas)': 1,
#  'genetic disorder': 1,
#  'genetic function algorithm': 1,
#  'genetic fuzzy system (gfs)': 1,
#  'genetic programming': 2,
#  'genetic programming (gp)': 1,
#  'genetic simulated annealing algorithm': 1,
#  'genome': 1,
#  'genome sequence analysis': 1,
#  'genome-wide association studies': 1,
#  'genome-wide association study': 1,
#  'genome-wide dataset': 1,
#  'genomes': 1,
#  'genotoxicity': 2,
#  'genre classification': 1,
#  'geographic information systems': 1,
#  'geologic facies': 1,
#  'geometric algebra': 1,
#  'geometric algorithm': 1,
#  'geometric approach': 1,
#  'geometric dilution of precision (gdop)': 1,
#  'geometry learning': 1,
#  'geostatistics': 4,
#  'geotechnical earthquake engineering': 1,
#  "gilbert's algorithm": 1,
#  'glioma grading': 1,
#  'global alignment': 1,
#  'global optimization': 2,
#  'global positioning system (gps)': 1,
#  'goal programming': 2,
#  'government-and-binding theory': 1,
#  'gpcr interacting protein': 1,
#  'gps-x': 1,
#  'gpu': 1,
#  'gradient descent search': 1,
#  'gradient projection': 1,
#  'grain recognition': 1,
#  'gram-negative bacteria': 1,
#  'grammar inference': 1,
#  'granular computing': 3,
#  'granular support vector machine': 1,
#  'granules': 1,
#  'granuriatical inference': 1,
#  'graph kernel': 2,
#  'graph-based method': 1,
#  'graph-based models': 1,
#  'graphical models': 1,
#  'graphical probabilistic models': 1,
#  'graphical processing unit': 1,
#  'gravitational search algorithm': 1,
#  'greece': 1,
#  'greedy algorithm': 1,
#  'grid computing': 1,
#  'grid resource': 1,
#  'grid scheme (gs)': 1,
#  'grid search': 1,
#  'grid search and cross validation': 1,
#  'grid-search': 2,
#  'grinding': 1,
#  'gross primary production': 1,
#  'gross tumour volume': 1,
#  'gross tumour volume (gtv)': 1,
#  'ground coupled heat pump performance': 1,
#  'group': 1,
#  'group analysis': 1,
#  'group of frame': 1,
#  'growing': 2,
#  'gtv': 1,
#  'gulf of mexico': 1,
#  'gynecology': 1,
#  'h1n1 influenza virus': 1,
#  'haar wavelets transformation': 1,
#  'hadamard matrix': 1,
#  'halophiles': 1,
#  'halophilic adaptation': 1,
#  'hamming clustering': 3,
#  'hamming codes': 1,
#  'handwritten character recognition': 1,
#  'handwritten chinese character': 1,
#  'hard drive failure prediction': 1,
#  'harden ability': 1,
#  'hardware-friendly algorithm': 1,
#  'harmful algal bloom': 1,
#  'hartmann-shack images': 1,
#  'hashed transduction': 1,
#  'hausdorff distance': 1,
#  'hazard assessment': 1,
#  'hdac': 1,
#  'head movements': 1,
#  'head pose': 1,
#  'health care': 1,
#  'health monitoring': 1,
#  'health smart home': 1,
#  'heart disease': 1,
#  'heart disease dataset': 1,
#  'heart disorder classification': 1,
#  'heart failure': 1,
#  'heart rate variability': 1,
#  'heart rate variability (hrv)': 1,
#  'heat diffusion': 1,
#  'heavy tails': 1,
#  'hepatitis c virus': 1,
#  'hepatitis disease diagnosis': 1,
#  'hepatocellular carcinoma(hcc)': 1,
#  'heterogeneous vision-based sensor network': 1,
#  'heterogeneous wireless networks': 1,
#  'heuristic method': 2,
#  'heuristic method (hm)': 1,
#  'hidden markov model': 2,
#  'hidden markov models': 3,
#  'hierarchical architecture': 1,
#  'hierarchical classification': 1,
#  'hierarchical clustering': 1,
#  'hierarchical decision tree': 1,
#  'hierarchical phrase search': 1,
#  'hierarchical support vector regression': 1,
#  'hierarchical taxonomy': 1,
#  'high dimensional data': 2,
#  'high range resolution (hrr) radar': 1,
#  'high throughput screening': 2,
#  'high throughput synapse detection': 1,
#  'high-dimensional bermudian-american options': 1,
#  'high-dimensional descriptive geometry': 1,
#  'high-dimensional feature space': 2,
#  'high-resolution computed tomography': 1,
#  'high-resolution multispectral': 1,
#  'high-throughput screening': 4,
#  'high-throughput screening (hts)': 1,
#  'high-throughput synthesis': 1,
#  'higher education quality': 1,
#  'higher order learning': 1,
#  'higher order moments': 1,
#  'higher order naive bayes': 1,
#  'higher order support vector machine': 1,
#  'hippocampal segmentation': 1,
#  'hippocampus': 2,
#  'histogram of oriented gradients': 1,
#  'hit': 1,
#  'hiv-1 coreceptor': 1,
#  'hiv-1 protease': 1,
#  'hj-1b': 1,
#  'hkm search direction': 1,
#  'hla-a*0201': 2,
#  'hmm': 1,
#  'hock burn': 1,
#  'home security': 1,
#  'homo-dimer': 1,
#  'homo-hexamer': 1,
#  'homo-tetramer': 1,
#  'homo-trimer': 1,
#  'homology transfer': 1,
#  'honey bee': 1,
#  'hormone-sensitive lipase': 1,
#  'hospital quality': 1,
#  'hospital referral': 1,
#  'hot-rolling parameters': 1,
#  'hotspot detection': 1,
#  'html document analysis': 1,
#  'hughes phenomenon': 1,
#  'human': 2,
#  'human action classification': 1,
#  'human amphiphysin-1 sh3 domain': 1,
#  'human chromosome 11': 1,
#  'human chromosome 21': 1,
#  'human disease': 1,
#  'human ether-a-go-go related gene': 1,
#  'human intelligence': 1,
#  'human microrna precursors': 1,
#  'human migration': 1,
#  'human oral absorption': 1,
#  'human serum': 1,
#  "huntington's disease": 1,
#  'hybrid': 2,
#  'hybrid asr': 1,
#  'hybrid automatic speech recognition (asr)': 1,
#  'hybrid generative/discriminative methods': 1,
#  'hybrid intelligent system': 1,
#  'hybrid intelligent systems': 1,
#  'hybrid methods': 1,
#  'hybrid models': 1,
#  'hybrid systems': 2,
#  'hybrid wavelet kernel': 1,
#  'hydrogen exchange': 1,
#  'hydroinformatics': 1,
#  'hydrophobicity matrix': 1,
#  'hydroturbine generating units (hgu)': 1,
#  'hyper geometric distribution (hgd)': 1,
#  'hyperactivation': 1,
#  'hyperion': 1,
#  'hyperspectral': 2,
#  'hyperspectral data': 1,
#  'hyperspectral image': 1,
#  'hyperspectral image classification': 2,
#  'hyperspectral imagery': 2,
#  'hyperspectral imaging': 1,
#  'hysteresis': 1,
#  'identification': 3,
#  'identification of nonlinear systems': 1,
#  'identification, soft-sensor modeling': 1,
#  'identifying critical positions': 1,
#  'identity snowball': 1,
#  'ieee 802.11': 1,
#  'ill-posed problems': 1,
#  'illumination': 1,
#  'image and character recognition': 1,
#  'image annotation': 2,
#  'image calibration': 1,
#  'image categorization': 1,
#  'image classification': 9,
#  'image compression': 1,
#  'image feature classification': 1,
#  'image medical analysis': 1,
#  'image ocr': 1,
#  'image processing': 11,
#  'image quality': 1,
#  'image registration': 2,
#  'image representation': 2,
#  'image retrieval': 6,
#  'image segmentation': 7,
#  'image similarity': 1,
#  'imbalance data': 1,
#  'imbalance problem': 1,
#  'imbalanced data': 2,
#  'imbalanced datasets': 2,
#  'impedance plethysmography': 1,
#  'implicit relevance feedback': 1,
#  'implicit surfaces': 1,
#  'improved particle swarm optimization': 1,
#  'imputation': 1,
#  'imputation methods': 1,
#  'in silico': 1,
#  'in silico modeling': 1,
#  'incomplete data': 1,
#  'incremental learning': 8,
#  'incremental learning algorithm': 1,
#  'incremental support vector machine': 1,
#  'indefinite kernel': 1,
#  'independent component analysis': 3,
#  'independent components analysis': 1,
#  'index properties': 1,
#  'individual classification': 1,
#  'indoor location': 1,
#  'inductive logic programming': 1,
#  'inductive loop detectors': 1,
#  'inductive machine learning': 1,
#  'industrial design': 1,
#  'industrial quality text passages': 1,
#  'inference system': 1,
#  'inferential sensing': 1,
#  'infinite kernel learning': 1,
#  'infinite programming': 3,
#  'infinity': 1,
#  'influence function': 2,
#  'information extraction': 4,
#  'information fusion': 1,
#  'information gain': 2,
#  'information geometry': 1,
#  'information hiding': 1,
#  'information retrieval': 8,
#  'information retrieval (ir)': 1,
#  'information security': 1,
#  'information systems': 1,
#  'information technology (it) based decision support systems': 1,
#  'information visualization': 1,
#  'informative gene selection': 1,
#  'infrared images': 1,
#  'infrared spectra of proteins': 1,
#  'infrared spectrum': 1,
#  'inhibitor': 2,
#  'inhibitors': 1,
#  'input feature': 1,
#  'input variable contribution analysis': 1,
#  'inside-bark volume': 1,
#  'instance-based learning': 1,
#  'instrument recognition': 1,
#  'insula': 1,
#  'integer programming': 1,
#  'integrated circuits': 1,
#  'intelligent decoding': 1,
#  'intelligent grasping': 1,
#  'intelligent shoes': 1,
#  'intelligent system': 2,
#  'intelligent systems': 1,
#  'inter-cluster distance': 1,
#  'interacting position': 1,
#  'interactive genetic algorithm': 1,
#  'interest region description': 1,
#  'interharmonic': 2,
#  'interior point methods': 1,
#  'interior-point methods': 1,
#  'intermediate frequency demodulator': 1,
#  'internal model control': 1,
#  'internal representation': 1,
#  'internet attack': 1,
#  'internet information filtering': 1,
#  'interval neutrosophic sets': 1,
#  'intervals': 1,
#  'intestinal drug absorption': 1,
#  'intra-class graph': 1,
#  'intrinsic solubility': 1,
#  'intrusion detection': 9,
#  'intrusion detection dataset': 1,
#  'intrusion detection system': 3,
#  'intrusion detection system (ids)': 2,
#  'intrusion detection systems (ids)': 2,
#  'inverse dynamic system': 1,
#  'inverse dynamics control': 1,
#  'inverse problems': 1,
#  'ischemia': 1,
#  'isi': 1,
#  'isomap': 1,
#  'istanbul': 1,
#  'jab establishment panel': 1,
#  'jackknife cross-validation test': 1,
#  'jackknife technique': 1,
#  'jackknife test': 2,
#  'jackknifing': 1,
#  'jet tokamak': 1,
#  'jgss': 1,
#  'joint': 1,
#  'juvenile myoclonic epilepsy': 1,
#  'k nearest neighbors': 1,
#  'k-fold cross validation': 2,
#  'k-means': 3,
#  'k-means algorithm': 1,
#  'k-means clustering': 3,
#  'k-nearest neigbour (k-nn)': 1,
#  'k-nearest neighbor': 3,
#  'k-nearest neighbors': 5,
#  'k-nearest neighbors (knn)': 1,
#  'k-nearest neighbours': 1,
#  'k-nearest neighbours (knn)': 1,
#  'k-nearest-neighbor': 1,
#  'k-nearest-neighbors': 1,
#  'k-nn': 2,
#  'k.brevis': 1,
#  'kalman filter': 1,
#  'kdd cup 1999': 1,
#  'kernel': 6,
#  'kernel caching': 1,
#  'kernel canonical correlation analysis': 2,
#  'kernel classifier': 1,
#  'kernel clustering': 1,
#  'kernel density estimation': 2,
#  'kernel design': 2,
#  'kernel distance': 1,
#  'kernel f-score feature selection': 1,
#  'kernel function': 20,
#  'kernel functions': 2,
#  'kernel granular support vector machine': 1,
#  'kernel integration': 1,
#  'kernel learning': 1,
#  'kernel learning method': 1,
#  'kernel logistic regression': 3,
#  'kernel machine': 2,
#  'kernel machines': 5,
#  'kernel matching pursuit': 1,
#  'kernel matching reduction algorithms': 1,
#  'kernel matrix': 2,
#  'kernel matrix selection': 1,
#  'kernel method': 2,
#  'kernel methods': 38,
#  'kernel optimization': 2,
#  'kernel parameter': 3,
#  'kernel polarization': 3,
#  'kernel principal component analysis': 1,
#  'kernel ridge regression (krr)': 1,
#  'kernel space': 1,
#  'kernel transformations': 1,
#  'kernel trick': 1,
#  'kernel-based learning approach': 1,
#  'kernel-based method': 1,
#  'kernel-based methods': 1,
#  'kernel-based wilcoxon regressor (kwr)': 1,
#  'kernel-pls': 1,
#  'kernelization': 1,
#  'kernels': 5,
#  'keystroke': 1,
#  'keystroke dynamics': 1,
#  'keywords extraction': 1,
#  'kinase inhibitor': 1,
#  'kinase substrate prediction': 1,
#  'knee joint vibration signals': 1,
#  'knee kinematic': 1,
#  'knee kinematics': 2,
#  'knn algorithm': 1,
#  'knowledge': 1,
#  'knowledge acquisition': 1,
#  'knowledge modeling': 1,
#  'knowledge representation': 1,
#  "kohonen's self-organizing map (som)": 1,
#  'kriging': 1,
#  'krylov-space methods': 1,
#  'kstar': 1,
#  'kth nearest neighboring': 1,
#  'l(1)-norm support vector machine': 1,
#  'l(2)-regularization': 2,
#  'l-grammar': 1,
#  'labeled and unlabeled patterns': 1,
#  'labview': 2,
#  'lagrange constraint': 1,
#  'land cover': 2,
#  'land cover/use mapping': 1,
#  'land mine data': 1,
#  'land suitability appraisal': 1,
#  'land surface temperature (lst)': 1,
#  'land use change': 1,
#  'landmark arrangement': 1,
#  'landmarks': 1,
#  'landsat': 1,
#  'landslide susceptibility': 1,
#  'landslide susceptibility mapping': 1,
#  'landslides': 2,
#  'language impairment': 1,
#  'language independence': 1,
#  'languages': 1,
#  'laplacian': 1,
#  'laplacian eigenmaps': 1,
#  'laplacian support vector machine': 3,
#  'laplacian-modified naive bayesian': 1,
#  'large data sets': 1,
#  'large linear classification': 1,
#  'large margin': 2,
#  'large margin classifiers': 1,
#  'large scale optimization': 2,
#  'large scale problems': 1,
#  'large-scale data classification': 1,
#  'large-scale learning': 1,
#  'large-scale linear classification': 1,
#  'large-scale machine learning': 1,
#  'laser scanner': 1,
#  'laser-induced fluorescence': 1,
#  'lasso': 3,
#  'latent class model': 1,
#  'latent variable models': 1,
#  'lateral gene transfer': 1,
#  'lateral spreading': 1,
#  'lattice constant': 1,
#  'lc-ms/ms': 1,
#  'learning': 2,
#  'learning (artificial intelligence)': 1,
#  'learning algorithm': 1,
#  'learning algorithms': 1,
#  'learning diagnosis': 1,
#  'learning kernels': 2,
#  'learning machines': 1,
#  'learning systems': 2,
#  'learning the kernel': 1,
#  'learning the kernels': 1,
#  'learning theory': 1,
#  'learning through contradiction': 1,
#  'learning to rank': 1,
#  'learning vector quantisation (lvq)': 1,
#  'learning vector quantization': 1,
#  'learning vector quantization (lvq)': 1,
#  'learning with structured data': 1,
#  'least envelope zone': 1,
#  'least square': 1,
#  'least square regression': 3,
#  'least square support vector machine': 6,
#  'least square support vector machine (ls-support vector machine)': 2,
#  'least square support vector machine (lssupport vector machine)': 1,
#  'least square transduction support vector machine': 1,
#  'least squares classifiers': 1,
# ...
#  'six sigma': 1,
#  'size spectra': 1,
#  'sizing': 1,
#  'skeletal muscles': 1,
#  'skin color detection': 1,
#  'skin perfusion': 1,
#  'skin sensitization': 1,
#  'slam': 1,
#  'slate': 1,
#  'slate classification': 1,
#  'sleep': 1,
#  'slip detection': 1,
#  'slope': 1,
#  'slt': 1,
#  'small-data-set learning': 1,
#  'smart protective relays': 1,
#  'smart sensors': 1,
#  'smo': 1,
#  'smooth piecewise function': 1,
#  'smoothing': 2,
#  'smos': 1,
#  'snmp': 2,
#  'snp': 1,
#  'snrna': 1,
#  'sobolev space': 1,
#  'social intelligence': 1,
#  'social tagging': 1,
#  'soft computing': 2,
#  'soft convex hulls': 1,
#  'soft rock engineering': 1,
#  'soft sensor': 4,
#  'soft-decoding': 1,
#  'soft-sensor': 1,
#  'software cost estimation': 1,
#  'software engineering': 1,
#  'software metrics': 2,
#  'software project risk': 1,
#  'software quality': 1,
#  'software reliability models': 1,
#  'software testing': 1,
#  'soil moisture': 1,
#  'soil moisture deficit': 1,
#  'solar flares': 1,
#  'solubility': 2,
#  'solution path': 1,
#  'solution paths': 2,
#  'solvent accessibility': 1,
#  'sonicir': 1,
#  'sorting signals': 1,
#  'soungun copper mine': 1,
#  'soungun iron mine': 1,
#  'southern brown bandicoot': 1,
#  'space trajectory design': 1,
#  'space weather': 2,
#  'spam': 2,
#  'spam classification': 1,
#  'spam filtering': 2,
#  'spam recognition': 1,
#  'span bound': 1,
#  'span of support vectors': 1,
#  'sparse': 1,
#  'sparse approximation': 2,
#  'sparse classifier': 1,
#  'sparse data': 1,
#  'sparse gaussian process': 1,
#  'sparse matrices': 1,
#  'sparsest cut': 1,
#  'sparsity': 1,
#  'spatial context': 1,
#  'spatial decomposition': 1,
#  'spatial distribution modelling': 1,
#  'spatial downscaling of aggregate data': 1,
#  'spatial filters': 1,
#  'spatial interpolation': 1,
#  'spatial learning': 1,
#  'spatial prediction': 2,
#  'spatial-spectral integration': 1,
#  'spatially continuous variable': 1,
#  'spatio-temporal and attribute correlations': 1,
#  'spatiotemporal': 1,
#  'speaker identification': 1,
#  'speaker recognitio': 1,
#  'speaker recognition': 2,
#  'speaker verification': 1,
#  'specificity': 1,
#  'speckle patterns': 1,
#  'spect images dataset': 1,
#  'spectral clustering': 1,
#  'spectral space': 1,
#  'spectral unmixing': 1,
#  'speech coding': 1,
#  'speech enhancement': 1,
#  'speech intelligibility': 1,
#  'speech recognition': 3,
#  'speech transmission index': 1,
#  'speed identification': 1,
#  'speedup of support vector machine': 1,
#  'sperm capacitation': 1,
#  'sperm motility and transport': 1,
#  'spherical self-organizing maps': 1,
#  'spleen tyrosine kinase (syk)': 1,
#  'splice site': 1,
#  'splice site prediction': 1,
#  'splice site prediction using support vector machine with bayes kernel': 1,
#  'spoken language understanding (slu)': 1,
#  'sports video classifications': 1,
#  'spt': 1,
#  'sqp': 1,
#  'squamous cell carcinoma (scc)': 1,
#  'src': 1,
#  'src kinase inhibitors': 1,
#  'stability': 1,
#  'stability region': 1,
#  'stacked generalization': 2,
#  'stakeholder classification': 1,
#  'standard automated perimetry': 1,
#  'standardized excitation approach (sea)': 1,
#  'starca basin': 1,
#  'static security': 2,
#  'statistic learning theory': 2,
#  'statistical analysis': 1,
#  'statistical and neuro-fuzzy classifiers': 1,
#  'statistical confidence': 1,
#  'statistical downscaling': 1,
#  'statistical features': 1,
#  'statistical inference': 1,
#  'statistical learning': 3,
#  'statistical learning theory': 11,
#  'statistical machine learning': 4,
#  'statistical machine translation (smt)': 1,
#  'statistical methods': 1,
#  'statistical modeling': 2,
#  'statistical pattern recognition': 1,
#  'statistical potentials': 1,
#  'statistical process control': 2,
#  'statistical regression analysis': 1,
#  'statistical relational learning': 1,
#  'statistical shape model': 1,
#  'statistical similarity matching': 1,
#  'statistics learning theory': 1,
#  'statpac': 1,
#  'steel quenching degree': 1,
#  'steganalysis': 1,
#  'stem cell image': 1,
#  'stewart platform': 1,
#  'stochastic dual coordinate ascent': 1,
#  'stochastic gradient descent': 1,
#  'stochastic language models': 1,
#  'stochastic processes': 1,
#  'stochastic simulation': 1,
#  'stock bbs': 1,
#  'stock market': 1,
#  'stock market forecasting': 1,
#  'stock prices': 1,
#  'straightness error evaluation': 1,
#  'streamflow prediction': 1,
#  'strength': 1,
#  'stress echocardiography': 1,
#  'string kernel': 1,
#  'string kernels': 3,
#  'string representation': 1,
#  'strip miner (tm)': 1,
#  'stroke': 3,
#  'strong duality': 1,
#  'structural bioinformaticsl': 1,
#  'structural classification of proteins (scop)': 1,
#  'structural conservation': 1,
#  'structural credit risk models': 1,
#  'structural granularity': 1,
#  'structural health monitoring': 4,
#  'structural information': 2,
#  'structural information of data': 1,
#  'structural kernels': 2,
#  'structural mri': 1,
#  'structural profile': 1,
#  'structural risk minimization': 2,
#  'structural risk minimization (srm)': 1,
#  'structural risk minimization principle': 1,
#  'structural risk minimization(srm)': 1,
#  'structural stability': 1,
#  'structural support vector machine': 1,
#  'structure activity relationship': 1,
#  'structure risk minimization': 4,
#  'structure-activity relationship': 2,
#  'structure-activity relationship analysis': 1,
#  'structure-activity relationships': 1,
#  'structure-function relationship': 1,
#  'structured data': 1,
#  'structured hierarchical output': 1,
#  'structures': 1,
#  'sub-cellular image': 1,
#  'sub-cellular protein localization': 1,
#  'subban decompositions': 1,
#  'subcellular localization': 2,
#  'subgraph': 1,
#  'substrate': 2,
#  'substrate cleavage site': 1,
#  'substrate specificity': 2,
#  'substructure pattern recognition': 1,
#  'subthreshold circuit': 1,
#  'successive linearization algorithm': 1,
#  'sudden oak death': 1,
#  'sugar content': 1,
#  'sulfur dioxide': 1,
#  'summary of product characteristics': 1,
#  'supervised classification': 5,
#  'supervised learning': 7,
#  'supervised machine learning': 4,
#  'supervised template update': 1,
#  'supplier selection': 1,
#  'supply chain': 1,
#  'supply chain management': 3,
#  'support function': 1,
#  'support vector': 1,
#  'support vector automatic detection': 1,
#  'support vector classification': 1,
#  'support vector classification (svc)': 1,
#  'support vector clustering method': 1,
#  'support vector data description': 1,
#  'support vector domain description': 1,
#  'support vector machine': 1184,
#  'support vector machine (smv)': 1,
#  'support vector machine (support vector machine)': 40,
#  'support vector machine [support vector machine]': 2,
#  'support vector machine automatic coding': 1,
#  'support vector machine classifier': 2,
#  'support vector machine ensemble': 1,
#  'support vector machine kernel': 1,
#  'support vector machine learning': 4,
#  'support vector machine learning and classification': 1,
#  'support vector machine parameter optimization': 2,
#  'support vector machine preference ranking': 1,
#  'support vector machine recursive feature elimination': 1,
#  'support vector machine regression': 4,
#  'support vector machine support vector machine': 117,
#  'support vector machine support vector machine classification': 1,
#  'support vector machine support vector machine simulation of the land use change parameter kernel functions': 1,
#  'support vector machine vector machine': 7,
#  'support vector machine, support vector machine': 1,
#  'support vector machine-plus (support vector machine plus )': 1,
#  'support vector machine.': 1,
#  'support vector machine/hmm': 1,
#  'support vector regression': 10,
#  'support vector regression (svr)': 2,
#  'support vector selection and adaptation': 1,
#  'support vectors': 1,
#  'supporting design': 1,
#  'surface coal mine': 1,
#  'surface electromyogram': 1,
#  'surface electromyography (semg)': 1,
#  'surface emg sensors': 1,
#  'surface modeling': 1,
#  'surface myoelectric signal (smes)': 1,
#  'surface roughness': 3,
#  'surrounding rock displacement': 1,
#  'surveillance system': 1,
#  'survival analysis': 2,
#  'suspended solids': 1,
#  'swarm intelligence': 2,
#  'swarm intelligence (si)': 1,
#  'swiss-prot database': 2,
#  'synaptophysin staining': 1,
#  'synchronous generator': 1,
#  'syntactic features': 2,
#  'syntactic information': 1,
#  'synthetic data': 2,
#  'system diagnosis': 1,
#  'system identification': 1,
#  'system modeling and identification': 1,
#  'system-on-chip (soc)': 1,
#  't-cell acute lymphoblastic leukaemia': 1,
#  't-cell epitope prediction': 1,
#  't-test': 1,
#  'taboo box': 1,
#  'tabu search': 1,
#  'tactile sensing': 1,
#  'tactile sensor': 1,
#  'tag-agent': 1,
#  'taguchi mehtod': 1,
#  'taihu lake': 1,
#  'tandem mass spectrometry': 1,
#  'target decoy strategy': 1,
#  'target identification': 1,
#  'target recognition': 2,
#  'target-selectivity': 1,
#  'task based image evaluation': 1,
#  'taxonomy learning': 1,
#  'tea': 1,
#  'teleost': 1,
#  'template optimisation': 1,
#  'temporal compacting': 1,
#  'temporal compression': 1,
#  'tense': 1,
#  'tensor kernel': 1,
#  'terminal conditions': 1,
#  'terrain mapping': 1,
#  'tertiary classifier': 1,
#  'tetrahymena pyriformis toxicity': 1,
#  'text analysis': 1,
#  'text categorisation': 1,
#  'text categorization': 7,
#  'text classification': 12,
#  'text detection': 2,
#  'text mining': 8,
#  'text region': 1,
#  'textline': 1,
#  'textual entailment': 1,
#  'textural features': 1,
#  'texture': 1,
#  'texture analysis': 2,
#  'texture classification': 1,
#  'texture descriptors': 4,
#  'texture features': 1,
#  'thalassemias screening': 1,
#  'the data-strip mining': 1,
#  'the heuristic method': 1,
#  'the model fits': 1,
#  'the standard data mining': 1,
#  'the support vector machine support vector machine': 1,
#  'the tertiary classifier': 1,
#  'theme-based learning': 1,
#  'threshold adjustment': 1,
#  'thrombotic disease': 1,
#  'thyroid disease diagnosis': 1,
#  'tight turns': 1,
#  'time embedding technique': 1,
#  'time latency and support vector machine': 1,
#  'time series': 5,
#  'time series analysis': 3,
#  'time series classification': 4,
#  'time series features': 1,
#  'time series forecasting': 4,
#  'time series kernels': 1,
#  'time series prediction': 3,
#  'time series predictions': 1,
#  'time-frequency and time-scale analysis': 1,
#  'time-lapse imaging': 1,
#  'time-series': 1,
#  'time-series forecasting': 1,
#  'time-varying': 1,
#  'tissue classification': 1,
#  'tissue-specific targeting peptide': 1,
#  'tissue/blood partition coefficients': 1,
#  'tnf-alpha converting enzyme (tace)': 1,
#  'tool breakage detection': 1,
#  'topo-climatic mapping': 1,
#  'topological machine learning': 1,
#  'topology prediction': 1,
#  'tornado prediction': 1,
#  'total brain-to-plasma concentration ratio': 1,
#  'total perfusion deficit': 1,
#  'total sediment load': 1,
#  'total variation': 1,
#  'tourism demand forecasting': 1,
#  'toxic chemicals': 1,
#  'tracheal intubation prediction': 1,
#  'tracking': 2,
#  'traffic analysis': 1,
#  'traffic classification': 1,
#  'traffic sign detection': 1,
#  'training': 1,
#  'training algorithm': 1,
#  'training method': 1,
#  'transcription factor binding motifs': 1,
#  'transcriptome': 1,
#  'transdermal peptide': 1,
#  'transduction': 2,
#  'transductive inference': 1,
#  'transductive learning': 3,
#  'transductive learning machine': 1,
#  'transductive support vector machine': 1,
#  'transfer learning': 2,
#  'transformer': 2,
#  'transient security': 1,
#  'transient stability analysis': 1,
#  'transient stability assessment': 2,
#  'transient stability prediction': 2,
#  'translasome': 1,
#  'transmembrane': 1,
#  'transmembrane helices': 1,
#  'transmembrane protein': 1,
#  'transmembrane proteins': 1,
#  'transmissible spongiform encephalopathy': 1,
#  'transportation': 1,
#  'transporter': 1,
#  'transposable elements': 1,
#  'transrectal ultrasound (trus)': 1,
#  'travel time prediction': 1,
#  'tri-axial accelerometer data': 1,
#  'triangle area': 1,
#  'triangle area feature represention': 1,
#  'triangulation': 1,
#  'trickle bed reactors': 1,
#  'triplets of amino acid composition (trio aac)': 1,
#  'trna': 1,
#  'tumor class': 1,
#  'tumours': 1,
#  'tunnel': 1,
#  'turbo pump rotor': 1,
#  'turku event extraction system': 1,
#  'turn classification': 1,
#  'twin support vector machine': 5,
#  'two-degree of freedom robot manipulator': 1,
#  'two-phase flow': 2,
#  'two-stage classifier': 1,
#  'type-2 fls': 1,
#  'ubiquitous computing': 1,
#  'ubiquitous intelligence': 1,
#  'uci data set': 1,
#  'uci hepatitis database': 1,
#  'ultrasound': 1,
#  'unbalanced data': 1,
#  'unbalanced datasets': 1,
#  'unbound brain-to-plasma concentration ratio': 1,
#  'uncertainty': 2,
#  'uncertainty assessment': 1,
#  'uncertainty sources': 1,
#  'unconstrained optimization': 1,
#  'underground engineer': 1,
#  'underground mining': 1,
#  'understanding': 1,
#  'underwater detection systems': 1,
#  'underwriting process': 1,
#  'unexploded ordnance (uxo)': 2,
#  'unified medical language system': 1,
#  'uniform design': 1,
#  'universum support vector machine': 1,
#  'unmixing-based feature extraction': 1,
#  'unsolicited commercial e-mail': 1,
#  'unsupervised learning': 2,
#  'unsupervised model': 1,
#  'unsupervised support vector machine': 1,
#  'unwanted sms message': 1,
#  'updating': 1,
#  'upper bound': 1,
#  'upper gi endoscopy': 1,
#  'urban areas': 1,
#  'urban ecology': 1,
#  'urban growth': 1,
#  'urban monitoring': 1,
#  'urbanization': 1,
#  'urbanization landsat tm': 1,
#  'user command': 1,
#  'user interest focusing degree': 1,
#  'user profiling': 1,
#  'uses of text categorisation': 1,
#  'uwb': 2,
#  'v - support vector regression': 1,
#  'v-fold cross validation': 1,
#  'v-mc-support vector machine': 1,
#  'v-support vector machine': 1,
#  'v3 amino acid sequences': 1,
#  'validation': 1,
#  'value added services': 1,
#  'valvular heart disease': 1,
#  'variable selection': 2,
#  'variance shift': 1,
#  'vascular disease': 1,
#  'vasodilators': 1,
#  'vector quantisation': 1,
#  'vector quantization': 1,
#  'vegetable (plant) oil': 1,
#  'vegetation classification': 1,
#  'vegetation mapping': 1,
#  'vehicle classification': 2,
#  'ventricular fibrillation detection': 1,
#  'version space': 1,
#  'vertebral column': 1,
#  'vertical search engines': 1,
#  'vhse descriptor': 1,
#  'viability': 1,
#  'vibration': 1,
#  'vibration arthrometry': 1,
#  'vibrational spectroscopy (infrared, near-infrared, and raman)': 1,
#  'video classification': 2,
#  'video indexing': 1,
#  'video ocr': 1,
#  'video processing': 1,
#  'video retrieval': 1,
#  'video signal processing': 1,
#  'vine variety discrimination': 1,
#  'virtual colonoscopy': 1,
#  'virtual genetic code': 1,
#  'virtual high throughput screening': 1,
#  'virtual human': 1,
#  'virtual organization': 1,
#  'virtual screening': 6,
#  'virulent proteins': 2,
#  'visual attention': 1,
#  'visual based location': 1,
#  'visual features': 1,
#  'visual words': 1,
#  'visualization': 3,
#  'viterbi decoder': 1,
#  'vo extraction': 1,
#  'vocabulary building': 1,
#  'voice activity detection': 3,
#  'voltage sag': 1,
#  'warping': 1,
#  'wastewater treatment': 1,
#  'watermarking': 2,
#  'wave prediction': 1,
#  'wavecluster': 1,
#  'waveform recognition': 1,
#  'wavelet': 2,
#  'wavelet analysis': 5,
#  'wavelet decomposition': 1,
#  'wavelet denoising': 1,
#  'wavelet kernel function': 1,
#  'wavelet package decomposition': 1,
#  'wavelet packet': 1,
#  'wavelet packet transform': 1,
#  'wavelet support vector machine': 1,
#  'wavelet transform': 3,
#  'wavelet transforms': 1,
#  'wavelets': 7,
#  'wear rate prediction': 1,
#  'wearable robot': 1,
#  'weather forecasting': 1,
#  'web analysis': 1,
#  'web caching': 1,
#  'web filtering': 1,
#  'web information extraction': 1,
#  'web logs': 1,
#  'web mining': 3,
#  'web opinion mining': 1,
#  'web page classification': 2,
#  'web page filtering': 1,
#  'web server': 1,
#  'web-based learning': 1,
#  'weblog': 1,
#  'weighted automata': 1,
#  'weighted kernel fusion': 1,
#  'weighted support vector machine': 4,
#  'weka': 4,
#  'wheel inspection': 1,
#  'wheelchair tilt and recline': 1,
#  'white matter lesion segmentation': 1,
#  'whitelist': 1,
#  'wilcoxon learning machine': 1,
#  'wind speed prediction': 1,
#  'winding ac resistance': 1,
#  'wireless capsule endoscopic (wce)': 1,
#  'wireless monitoring': 1,
#  'wireless sensor networks': 3,
#  'wisconsin breast cancer diagnosis data': 1,
#  'within-class scatter': 1,
#  'word sense disambiguation': 2,
#  'wordnet': 1,
#  'worldview-2': 1,
#  'wrapper': 1,
#  'wrist angle': 1,
#  'wsd': 1,
#  'x-ray ct': 1,
#  'xbrl': 1,
#  'xml': 1,
#  'xylanase': 1,
#  'yarn quality': 2,
#  'z statistic': 1,
#  'zeolites': 1,
#  'zinc binding group': 1}

# %% [markdown]
# This is pretty amazing -- only 14000 of the 23000 references have keywords, so if 1400 or so have svm as a keyword, then it is a heavily used technique. Also there are lots of keywords associated with svm.

# %% [markdown]
# Compare with this with neural networks:

# %%
nn_df_full = df.ix[nn_df.index]
print(nn_df_full.shape)
nn_keys = ml.keyword_counts(nn_df_full)
print('There are %d keywords associated with "neural network"' % len(nn_keys))
# Out:
# (1220, 61)
# There are 3400 keywords associated with "neural network"

# %% [markdown]
# I guess the picture is much the same. What about the 'decision tree?'

# %%
dt_df_full = df.ix[dt_df.index]
print(dt_df_full.shape)
dt_keys = ml.keyword_counts(dt_df_full)
print('There are %d keywords associated with "decision tree"' % len(dt_keys))
# Out:
# (513, 61)
# There are 1374 keywords associated with "decision tree"

# %% [markdown]
# Ok, for decision tree, a much older technique, things look different. Still quite a few keywords, but the less than half for the other techniques. This is not to say that decision trees are not incredibly widely used. But they are not being relayed in the same way through the literature.
#
# To deal too many keywords, break into a couple of time periods.

# %%
svm_keys_pre_2000 = ml.keyword_counts(svm_df_full[svm_df_full.PY<2001])
svm_keys_pre_2000
# Out:
# {'classification': 1,
#  'data mining': 1,
#  'decision feedback support vector machine': 1,
#  'isi': 1,
#  'kernels': 1,
#  'linear programming': 1,
#  'machine learning': 1,
#  'nonlinear equalization': 1,
#  'randomness': 1,
#  'support vector machine': 3,
#  'transduction': 1}

# %%
cow_svm = ml.coword_matrix(svm_df_full[svm_df_full.PY<2001],svm_keys_pre_2000.keys())
arry = cow_svm.as_matrix()
arry.shape

svm_nx = nx.from_numpy_matrix(arry)
cols = cow_svm.columns.tolist()

# %%
cols
# Out:
# ['decision feedback support vector machine',
#  'transduction',
#  'randomness',
#  'support vector machine',
#  'classification',
#  'kernels',
#  'linear programming',
#  'machine learning',
#  'isi',
#  'nonlinear equalization',
#  'data mining']

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(8.5,8.5)
labels = {cols.index(l):l for l in cols}
nx.draw_spring(svm_nx, with_labels=True, labels = labels, font_size=10,font_family='sans-serif')

# %% [markdown]
# Between 2000- 2005, there is much growth.

# %%
svm_keys_2001_on = ml.keyword_counts(svm_df_full[(svm_df_full.PY >= 2001) & (svm_df_full.PY <2003)])
cow_svm = ml.coword_matrix(svm_df_full[(svm_df_full.PY >= 2001) & (svm_df_full.PY <2003)],svm_keys_2001_on.keys())
arry = cow_svm.as_matrix()
arry.shape

svm_nx = nx.from_numpy_matrix(arry)
cols = cow_svm.columns.tolist()

# %%
fig = matplotlib.pyplot.gcf()
fig.set_size_inches(12.5,14.5)
labels = {cols.index(l):l for l in cols}
nx.draw_spring(svm_nx, with_labels=True, labels = labels, font_size=9,font_family='sans-serif')
