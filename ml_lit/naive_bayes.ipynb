# %% [markdown]
# # From Naive Bayes to ...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import ml_lit_anal as ml
import re
import nltk
import pickle
import operator
import google_scholar_parser as gs
import pandas as pd
import networkx as nx
import graph_tool.all as gt
import itertools
import matplotlib.pyplot as plt
import numpy as np
import collections
import IPython.display
import seaborn
import ggplot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-250e228e96f3> in <module>()
# ----> 1 import ml_lit_anal as ml
#       2 import re
#       3 import nltk
#       4 import pickle
#       5 import operator
#
# /home/mackenza/Documents/data_intensive/book/ml_lit/ml_lit_anal.py in <module>()
#      11 import math
#      12 import itertools
# ---> 13 import matplotlib.pyplot as plt
#      14 import requests
#      15 from lxml import etree
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.py in <module>()
#      96
#      97 from matplotlib.backends import pylab_setup
# ---> 98 _backend_mod, new_figure_manager, draw_if_interactive, _show = pylab_setup()
#      99
#     100
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/backends/__init__.pyc in pylab_setup()
#      26     # imports. 0 means only perform absolute imports.
#      27     backend_mod = __import__(backend_name,
# ---> 28                              globals(),locals(),[backend_name],0)
#      29
#      30     # Things we pull in from all backends
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/backends/backend_wx.py in <module>()
#      51         import wxversion
#      52     except ImportError:
# ---> 53         raise ImportError(missingwxversion)
#      54
#      55     # Some early versions of wxversion lack AlreadyImportedError.
#
# ImportError: Matplotlib backend_wx and backend_wxagg require wxversion, which was not found.

# %% [markdown]
# ## Loading the WoScience records
#
# I downloaded from Thomson ISI Web of Science all the references returned by the query 'naive bayes.' I also downloaded the cited references.

# %%
df = ml.load_records('data/naive_bayes_WOS/')
print('There are %s records in the dataset'%df.shape[0])

#clean topics
df = ml.clean_topics(df)
df = ml.clean_fields(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-88568974ce6c> in <module>()
# ----> 1 df = ml.load_records('data/naive_bayes_WOS/')
#       2 print('There are %s records in the dataset'%df.shape[0])
#       3
#       4 #clean topics
#       5 df = ml.clean_topics(df)
#
# NameError: name 'ml' is not defined

# %%
print('%s topic fields are null'%sum(df.topics.isnull()))
print('%s abstract fields are null'%sum(df.AB.isnull()))
print('%s keywords Plus fields are null'%sum(df.ID.isnull()))
print('%s author fields are null'%sum(df.AF.isnull()))
# Out:
# 1008 topic fields are null
# 8 abstract fields are null
# 1194 keywords Plus fields are null
# 1 author fields are null

# %%
plt.figure(figsize=(8,4))
plt.title('Naive Bayes (Web of Science)')

df.PY.hist(bins=len(df.PY.unique()), color='g')
plt.box(on=False)

# %% [markdown]
# ## Fields of research in the 'naive bayes' literature

# %%
all_fields = sorted([e  for el in df.fields.dropna() for e in el])
fields_set = set(all_fields)
field_counts = {e:all_fields.count(e) for e in fields_set}
print('%s different fields appear in the naive bayes literature'%len(fields_set))
field_counts_s = sorted(field_counts.iteritems(), key=lambda(k,v):(-v,k))
field_counts_s[0:30]
# Out:
# 101 different fields appear in the machine learning literature
# [('computer science', 2020),
#  ('engineering', 731),
#  ('biochemistry & molecular biology', 144),
#  ('mathematical & computational biology', 141),
#  ('mathematics', 138),
#  ('telecommunications', 128),
#  ('medical informatics', 115),
#  ('automation & control systems', 108),
#  ('imaging science & photographic technology', 87),
#  ('operations research & management science', 86),
#  ('biotechnology & applied microbiology', 82),
#  ('information science & library science', 58),
#  ('radiology, nuclear medicine & medical imaging', 44),
#  ('chemistry', 42),
#  ('health care sciences & services', 40),
#  ('robotics', 39),
#  ('science & technology - other topics', 31),
#  ('neurosciences & neurology', 29),
#  ('genetics & heredity', 28),
#  ('linguistics', 26),
#  ('optics', 26),
#  ('instruments & instrumentation', 25),
#  ('acoustics', 23),
#  ('biophysics', 23),
#  ('materials science', 23),
#  ('remote sensing', 23),
#  ('business & economics', 19),
#  ('pharmacology & pharmacy', 18),
#  ('physics', 18),
#  ('life sciences & biomedicine - other topics', 17)]

# %%
## Citation practices

# %%
df[['AU', 'TI', 'TC', 'PY', 'ID', 'DE']][df.TC>200].sort('TC', ascending=False)
# Out:
#                                                     AU  \
# 500                                Kohavi, R; John, GH
# 501              Friedman, N; Geiger, D; Goldszmidt, M
# 502                        Peng, HC; Long, FH; Ding, C
# 503                    Yang, ZH; Wong, WSW; Nielsen, R
# 504                                Bauer, E; Kohavi, R
# 505   Chawla, NV; Bowyer, KW; Hall, LO; Kegelmeyer, WP
# 506      Nigam, K; McCallum, AK; Thrun, S; Mitchell, T
# 507  Brudey, K; Driscoll, JR; Rigouts, L; Prodinger...
# 508                              Pond, SLK; Frost, SDW
# 509  Wu, XD; Kumar, V; Quinlan, JR; Ghosh, J; Yang,...
# 510                  Pang, B; Lee, L; Vaithyanathan, S
# 511                          Wulfsohn, MS; Tsiatis, AA
# 512  Moore, JH; Gilbert, JC; Tsai, CT; Chiang, FT; ...
# 513                                       Friedman, JH
# 514    Cohen, I; Sebe, N; Garg, A; Chen, LS; Huang, TS
# 515                                 Rogers, D; Hahn, M
#
#                                                     TI    TC    PY  \
# 500              Wrappers for feature subset selection  1831  1997
# 501                       Bayesian network classifiers  1023  1997
# 502  Feature selection based on mutual information:...   929  2005
# 503  Bayes empirical Bayes inference of amino acid ...   767  2005
# 504  An empirical comparison of voting classificati...   740  1999
# 505  SMOTE: Synthetic minority over-sampling technique   738  2002
# 506  Text classification from labeled and unlabeled...   636  2000
# 507  Mycobacterium tuberculosis complex genetic div...   430  2006
# 508  Not so different after all: A comparison of me...   394  2005
# 509                   Top 10 algorithms in data mining   273  2008
# 510  Thumbs up? Sentiment classification using mach...   258  2002
# 511  A joint model for survival and longitudinal da...   242  1997
# 512  A flexible computational framework for detecti...   237  2006
# 513  On bias, variance, 0/1 - Loss, and the curse-o...   232  1997
# 514  Facial expression recognition from video seque...   221  2003
# 515                 Extended-Connectivity Fingerprints   218  2010
#
#                                                     ID  \
# 500                    LEARNING ALGORITHMS; IRRELEVANT
# 501  PROBABILISTIC NETWORKS; MISSING DATA; KNOWLEDG...
# 502                                   WRAPPERS; CANCER
# 503  CODON-SUBSTITUTION MODELS; ADAPTIVE EVOLUTION;...
# 504                                               BIAS
# 505                                                NaN
# 506                                            SAMPLES
# 507  DIRECT REPEAT LOCUS; TANDEM DNA REPEATS; VARIA...
# 508  MAXIMUM-LIKELIHOOD-ESTIMATION; POSITIVELY SELE...
# 509  NEAREST NEIGHBOR RULES; ASSOCIATION RULES; CLA...
# 510                                                NaN
# 511                                         TIME; AIDS
# 512  MULTIFACTOR-DIMENSIONALITY REDUCTION; DRIVEN C...
# 513                                                NaN
# 514  SPEECH RECOGNITION; OPTICAL-FLOW; NETWORK; TRA...
# 515  SIGNATURE MOLECULAR DESCRIPTOR; THROUGHPUT SCR...
#
#                                                     DE
# 500  classification; feature selection; wrapper; fi...
# 501                  Bayesian networks; classification
# 502  feature selection; mutual information; minimal...
# 503  positive selection; codon-substitution models;...
# 504  classification; boosting; Bagging; decision tr...
# 505                                                NaN
# 506  text classification; Expectation-Maximization;...
# 507                                                NaN
# 508  positive and negative selection; codon substit...
# 509                                                NaN
# 510                                                NaN
# 511  EM algorithm; longitudinal data; repeated meas...
# 512  gene-gene interactions; constructive induction...
# 513  classification; bias; variance; curse-of-dimen...
# 514                                                NaN
# 515                                                NaN
#
# [16 rows x 6 columns]

# %% [markdown]
# ### Who has been cited most in the references cited by the naive bayes literature?

# %%
all_refs = [ref for refs in df.cited_refs for ref in refs]
ref_collection = collections.Counter(all_refs)
ref_collection.most_common(n=50)
# Out:
# [('domingos p, 1997, mach learn, v29, p103, doi 10.1023/a:1007413511361', 287),
#  ('mitchell t.m., 1997, machine learning', 281),
#  ('friedman n, 1997, mach learn, v29, p131, doi 10.1023/a:1007465528199', 278),
#  ('witten ih, 2005, data mining practica', 273),
#  ('quinlan j.r., 1993, c4 5 programs machin', 246),
#  ('duda r., 1973, pattern classificati', 164),
#  ('pearl j., 1988, probabilistic reason', 135),
#  ('yang y., 1997, p 14 int c mach lear, p412', 109),
#  ('witten i.h., 2000, data mining practica', 108),
#  ('sebastiani f, 2002, acm comput surv, v34, p1, doi 10.1145/505282.505283',
#   104),
#  ('fayyad u.m., 1993, p 13 int joint c art, p1022', 103),
#  ('duda r.o., 2001, pattern classificati', 101),
#  ('dempster ap, 1977, j roy stat soc b met, v39, p1', 96),
#  ('blake c. l., 1998, uci repository machi', 95),
#  ('breiman l, 1996, mach learn, v24, p123, doi 10.1023/a:1018054314350', 95),
#  ('kohavi r, 1997, artif intell, v97, p273, doi 10.1016/s0004-3702(97)00043-x',
#   93),
#  ('vapnik v., 1995, nature stat learning', 92),
#  ('langley p., 1992, p 10 nat c art int, p223', 92),
#  ('breiman l., 1984, classification regre', 91),
#  ('vapnik v., 1998, stat learning theory', 88),
#  ('breiman l, 2001, mach learn, v45, p5, doi 10.1023/a:1010933404324', 84),
#  ('webb gi, 2005, mach learn, v58, p5, doi 10.1007/s10994-005-4258-6', 79),
#  ('quinlan j. r., 1986, machine learning, v1, doi 10.1023/a:1022643204877',
#   73),
#  ('nigam k, 2000, mach learn, v39, p103, doi 10.1023/a:1007692713085', 72),
#  ('john gh, 1995, p 11 c unc art int, p338', 70),
#  ('kohavi r., 1996, p 2 int c knowl disc, p202', 68),
#  ('aha dw, 1991, mach learn, v6, p37, doi 10.1023/a:1022689900470', 66),
#  ('langley p., 1994, p 10 c unc art int, p399', 65),
#  ('chow ck, 1968, ieee t inform theory, v14, p462, doi 10.1109/tit.1968.1054142',
#   65),
#  ('dougherty j., 1995, p 12 int c mach lear, p194', 63),
#  ('hand dj, 2001, int stat rev, v69, p385, doi 10.2307/1403452', 63),
#  ('demsar j, 2006, j mach learn res, v7, p1', 63),
#  ('cooper gf, 1992, mach learn, v9, p309, doi 10.1007/bf00994110', 62),
#  ('joachims t., 1998, p 10 eur c mach lear, p137', 60),
#  ('guyon i., 2003, journal of machine learning research, v3, doi 10.1162/153244303322753616',
#   56),
#  ('cortes c, 1995, mach learn, v20, p273, doi 10.1023/a:1022627411411', 55),
#  ('mccallum a, 1998, aaai 98 worksh learn', 53),
#  ('bradley ap, 1997, pattern recogn, v30, p1145, doi 10.1016/s0031-3203(96)00142-2',
#   51),
#  ('golub tr, 1999, science, v286, p531, doi 10.1126/science.286.5439.531', 51),
#  ('asuncion a., 2007, uci machine learning', 50),
#  ('zheng zj, 2000, mach learn, v41, p53, doi 10.1023/a:1007613203719', 50),
#  ('cristianini n., 2000, intro support vector', 47),
#  ('chang c.c., 2001, libsvm lib support v', 47),
#  ('witten i.h., 1999, data mining practica', 46),
#  ('hastie t. j., 2001, elements stat learni', 45),
#  ('duda r. o., 2000, pattern classificati', 45),
#  ('forman g., 2003, journal of machine learning research, v3, doi 10.1162/153244303322753670',
#   45),
#  ('yang y., 1999, p 22 ann int acm sig, p42, doi 10.1145/312624.312647', 43),
#  ('keogh e., 1999, p 7 int worksh art i, p225', 43),
#  ('burges cjc, 1998, data min knowl disc, v2, p121, doi 10.1023/a:1009715923555',
#   42)]
